# %% [markdown]
# # Предикативная аналитика

# %% [markdown]
# ## Задача 1

# %% [markdown]
# ### Фреймворк

# %% [markdown]
# Фреймворк - 'каркас', предназначенный для облегчения процесса объединения компонентов при написании программы.

# %% [markdown]
# ### Фреймворк машинного обучения

# %% [markdown]
# Фреймворк - 'каркас', предназначенный для облегчения процесса объединения компонентов при создании алгоритмов, кодов, программ в области машинного обучения.

# %% [markdown]
# ### Фреймворк квантового машинного обучения

# %% [markdown]
# Фреймворк - 'каркас', предназначенный для облегчения процесса объединения компонентов при создании алгоритмов, кодов, программ в области машинного обучения с использованием параллелизма квантовых компьютеров.

# %% [markdown]
# ### Обосновать почему задачи машинного обучения хорошо подходят для решения на квантовых компьютерах

# %% [markdown]
# Главное преимущество вычислений на квантовых машинах - скорость. Но ускорение происходит не по причине увеличения вычислительных мощностей на каждый процесс, а благодаря взаимодействию кубитов, за счет чего обеспечивается возможность одновременной работы нескольких процессов. Параллелизм очень хорошо себя зарекомендовал в задачах тренировки глубоких нейронных сетей. Поэтому задачи машинного обучения хорошо подходят для решения на квантовых компьютерах.

# %% [markdown]
# ## Задача 2

# %% [markdown]
# Задачи:
#
# - Построить математические модели для вибрации трёх подшипников, используя очевидные и скрытые зависимости.
#
# - Сравнить и проанализировать показания разных датчиков, подумать, как лучше их использовать.
#
# - Обосновать использование или неиспользование каждого параметра в математической модели

# %% [markdown]
# Схема компрессора
#
# <img src="image.png">

# %% [markdown]
# Загрузка данных

# %%
import pandas as pd

# %%
df = pd.read_excel('Data.xlsx')

# %% [markdown]
# Просмотр данных

# %%
df.head(5)
# Out:
#          Дата и время    Обороты 1    Обороты 2    Обороты 3  \
# 0 2016-09-02 00:10:00  5258.662931  5258.780949  5255.826839
# 1 2016-09-02 00:20:00  5277.254228  5277.860518  5274.922677
# 2 2016-09-02 00:30:00  5331.892912  5332.584639  5329.195142
# 3 2016-09-02 00:40:00  5330.082210  5329.813639  5327.209481
# 4 2016-09-02 00:50:00  5296.671570  5296.561670  5294.262691
#
#    Вибрация Подшипник 1  Вибрация Подшипник 2  Вибрация Подшипник 3  \
# 0             53.798579             28.936931             45.781854
# 1             54.173565             28.835001             45.525913
# 2             55.400938             28.720065             45.859280
# 3             56.015260             28.387437             46.192262
# 4             54.256911             28.309788             46.751371
#
#    Сдвиг Подшипник 1  Сдвиг Подшипник 2  Сдвиг Подшипник 3  \
# 0          -0.041063          -0.031354           0.004203
# 1          -0.043171          -0.031549           0.000496
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11004 entries, 0 to 11003
# Data columns (total 17 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Дата и время                               11004 non-null  datetime64[ns]
#  1   Обороты 1                                  11004 non-null  float64
#  2   Обороты 2                                  11004 non-null  float64
#  3   Обороты 3                                  11004 non-null  float64
#  4   Вибрация Подшипник 1                       11004 non-null  float64
#  5   Вибрация Подшипник 2                       11004 non-null  float64
#  6   Вибрация Подшипник 3                       11004 non-null  float64
#  7   Сдвиг Подшипник 1                          11004 non-null  float64
#  8   Сдвиг Подшипник 2                          11004 non-null  float64
# ...

# %% [markdown]
# Проверка на пропуски в данных

# %%
df.isnull().sum()
# Out:
# Дата и время                                 0
# Обороты 1                                    0
# Обороты 2                                    0
# Обороты 3                                    0
# Вибрация Подшипник 1                         0
# Вибрация Подшипник 2                         0
# Вибрация Подшипник 3                         0
# Сдвиг Подшипник 1                            0
# Сдвиг Подшипник 2                            0
# Сдвиг Подшипник 3                            0
# Давление масла 1 (кПа)                       0
# Давление масла 2 (кПа)                       0
# Температура масла (С)                        0
# Температура газа На входе компрессора        0
# Температура газа На выходе компрессора       0
# Давление газа На входе компрессора (кПа)     0
# Давление газа На выходе компрессора (МПа)    0
# dtype: int64

# %% [markdown]
# Пропусков в данных нет

# %% [markdown]
# Описательная статистика

# %%
df.describe()
# Out:
#           Обороты 1     Обороты 2     Обороты 3  Вибрация Подшипник 1  \
# count  11004.000000  11004.000000  11004.000000          11004.000000
# mean    5552.085572   5551.951317   5549.390565             65.103002
# std      178.874828    178.841944    178.830382              6.275282
# min     5000.158690   5000.626625   4998.185228             47.533153
# 25%     5457.742330   5457.586679   5455.275482             61.234763
# 50%     5595.420369   5595.210789   5592.671716             65.490397
# 75%     5693.970754   5693.800836   5691.240462             70.270891
# max     5852.693693   5852.791303   5849.808789             77.482260
#
#        Вибрация Подшипник 2  Вибрация Подшипник 3  Сдвиг Подшипник 1  \
# count          11004.000000          11004.000000       11004.000000
# mean              29.033050             46.199555          -0.020231
# std                0.617651              0.655033           0.018524
# ...

# %% [markdown]
# Списиок названий столбцов

# %%
list(df)
# Out:
# ['Дата и время',
#  'Обороты 1',
#  'Обороты 2',
#  'Обороты 3',
#  'Вибрация Подшипник 1',
#  'Вибрация Подшипник 2',
#  'Вибрация Подшипник 3',
#  'Сдвиг Подшипник 1',
#  'Сдвиг Подшипник 2',
#  'Сдвиг Подшипник 3',
#  'Давление масла 1 (кПа)',
#  'Давление масла 2 (кПа)',
#  'Температура масла (С)',
#  'Температура газа На входе компрессора',
#  'Температура газа На выходе компрессора',
#  'Давление газа На входе компрессора (кПа)',
#  'Давление газа На выходе компрессора (МПа)']

# %% [markdown]
# Выделение пространства ответов и признаков в отдельные data frame

# %%
df_Y = df[['Вибрация Подшипник 1',
           'Вибрация Подшипник 2',
           'Вибрация Подшипник 3']]
df_Y.head(3)
# Out:
#    Вибрация Подшипник 1  Вибрация Подшипник 2  Вибрация Подшипник 3
# 0             53.798579             28.936931             45.781854
# 1             54.173565             28.835001             45.525913
# 2             55.400938             28.720065             45.859280

# %%
df_X = df[['Дата и время',
    'Обороты 1',
 'Обороты 2',
 'Обороты 3',
 'Сдвиг Подшипник 1',
 'Сдвиг Подшипник 2',
 'Сдвиг Подшипник 3',
 'Давление масла 1 (кПа)',
 'Давление масла 2 (кПа)',
 'Температура масла (С)',
 'Температура газа На входе компрессора',
 'Температура газа На выходе компрессора',
 'Давление газа На входе компрессора (кПа)',
 'Давление газа На выходе компрессора (МПа)']]
df_X.head(3)
# Out:
#          Дата и время    Обороты 1    Обороты 2    Обороты 3  \
# 0 2016-09-02 00:10:00  5258.662931  5258.780949  5255.826839
# 1 2016-09-02 00:20:00  5277.254228  5277.860518  5274.922677
# 2 2016-09-02 00:30:00  5331.892912  5332.584639  5329.195142
#
#    Сдвиг Подшипник 1  Сдвиг Подшипник 2  Сдвиг Подшипник 3  \
# 0          -0.041063          -0.031354           0.004203
# 1          -0.043171          -0.031549           0.000496
# 2          -0.040885          -0.032023          -0.000016
#
#    Давление масла 1 (кПа)  Давление масла 2 (кПа)  Температура масла (С)  \
# 0                0.344716                0.340869              35.467580
# 1                0.344712                0.340852              35.456034
# 2                0.344361                0.340497              35.528870
#
#    Температура газа На входе компрессора  \
# 0                              23.744987
# 1                              23.127557
# 2                              23.599861
#
# ...

# %% [markdown]
# Построение графиков Вибрации от времени

# %% [markdown]
# <img src="newplot.png">

# %% [markdown]
# <img src="newplot(1).png">

# %% [markdown]
# Матрица корреляций

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
feature = list(df_X)
feature = feature[1:]
feature
# Out:
# ['Обороты 1',
#  'Обороты 2',
#  'Обороты 3',
#  'Сдвиг Подшипник 1',
#  'Сдвиг Подшипник 2',
#  'Сдвиг Подшипник 3',
#  'Давление масла 1 (кПа)',
#  'Давление масла 2 (кПа)',
#  'Температура масла (С)',
#  'Температура газа На входе компрессора',
#  'Температура газа На выходе компрессора',
#  'Давление газа На входе компрессора (кПа)',
#  'Давление газа На выходе компрессора (МПа)']

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(df_X[feature].corr(), annot = True, vmin=-1, vmax=1, center= 0)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Уберем обороты 2,3 и давление масла 2

# %%
df_X = df_X[['Дата и время',
    'Обороты 1',
 'Сдвиг Подшипник 1',
 'Сдвиг Подшипник 2',
 'Сдвиг Подшипник 3',
 'Давление масла 1 (кПа)',
 'Температура масла (С)',
 'Температура газа На входе компрессора',
 'Температура газа На выходе компрессора',
 'Давление газа На входе компрессора (кПа)',
 'Давление газа На выходе компрессора (МПа)']]

# %%
fig, ax = plt.subplots(figsize=(7,7))
sns.heatmap(df_X.corr(), annot = True, vmin=-1, vmax=1, center= 0, )
# Out:
# <AxesSubplot:>

# %%
feature = list(df_X)
feature = feature[1:]
feature
# Out:
# ['Обороты 1',
#  'Сдвиг Подшипник 1',
#  'Сдвиг Подшипник 2',
#  'Сдвиг Подшипник 3',
#  'Давление масла 1 (кПа)',
#  'Температура масла (С)',
#  'Температура газа На входе компрессора',
#  'Температура газа На выходе компрессора',
#  'Давление газа На входе компрессора (кПа)',
#  'Давление газа На выходе компрессора (МПа)']

# %% [markdown]
# ### Статистический подход

# %% [markdown]
# ### Вибрация 1-ого подшипника

# %%
train_data = df_X.drop(labels = 'Дата и время', axis = 1)

# %%
train_data.head(3)
# Out:
#      Обороты 1  Сдвиг Подшипник 1  Сдвиг Подшипник 2  Сдвиг Подшипник 3  \
# 0  5258.662931          -0.041063          -0.031354           0.004203
# 1  5277.254228          -0.043171          -0.031549           0.000496
# 2  5331.892912          -0.040885          -0.032023          -0.000016
#
#    Давление масла 1 (кПа)  Температура масла (С)  \
# 0                0.344716              35.467580
# 1                0.344712              35.456034
# 2                0.344361              35.528870
#
#    Температура газа На входе компрессора  \
# 0                              23.744987
# 1                              23.127557
# 2                              23.599861
#
#    Температура газа На выходе компрессора  \
# 0                              105.907962
# 1                              104.946009
# 2                              106.309756
#
#    Давление газа На входе компрессора (кПа)  \
# 0                                 38.161112
# ...

# %%
train_labels = df_Y['Вибрация Подшипник 1']

# %%
train_labels.head(3)
# Out:
# 0    53.798579
# 1    54.173565
# 2    55.400938
# Name: Вибрация Подшипник 1, dtype: float64

# %%
import statsmodels.api as sm
import statsmodels as statsmodels

# %%
train_data = sm.add_constant(train_data)

# %%
train_data.head(3)
# Out:
#    const    Обороты 1  Сдвиг Подшипник 1  Сдвиг Подшипник 2  \
# 0    1.0  5258.662931          -0.041063          -0.031354
# 1    1.0  5277.254228          -0.043171          -0.031549
# 2    1.0  5331.892912          -0.040885          -0.032023
#
#    Сдвиг Подшипник 3  Давление масла 1 (кПа)  Температура масла (С)  \
# 0           0.004203                0.344716              35.467580
# 1           0.000496                0.344712              35.456034
# 2          -0.000016                0.344361              35.528870
#
#    Температура газа На входе компрессора  \
# 0                              23.744987
# 1                              23.127557
# 2                              23.599861
#
#    Температура газа На выходе компрессора  \
# 0                              105.907962
# 1                              104.946009
# 2                              106.309756
#
#    Давление газа На входе компрессора (кПа)  \
# 0                                 38.161112
# ...

# %%
import statsmodels.api as sm
import statsmodels as statsmodels
model = sm.OLS(train_labels, train_data)

# %%
fit = model.fit()

# %%
g = fit.summary()
g
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ...
# Dep. Variable:     Вибрация Подшипник 1   R-squared:                       0.730
# Model:                              OLS   Adj. R-squared:                  0.729
# Method:                   Least Squares   F-statistic:                     2966.
# Date:                  Sun, 27 Sep 2020   Prob (F-statistic):               0.00
# Time:                          15:37:21   Log-Likelihood:                -28627.
# No. Observations:                 11004   AIC:                         5.728e+04
# Df Residuals:                     10993   BIC:                         5.736e+04
# Df Model:                            10
# Covariance Type:              nonrobust
# ...
#                                                 coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# Reset-тест

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
statsmodels.stats.diagnostic.linear_reset(fit, power=2)
# Out:
# <class 'statsmodels.stats.contrast.ContrastResults'>
# <Wald test (chi2): statistic=[[593.8079765]], p-value=3.7207027650545315e-131, df_denom=1>

# %% [markdown]
# Нулевая гипотеза – спецификация модели адекватна (квадраты).
# P-значение = 3.7207027650545315e-131.
# Значит нулевая гипотеза отвергается на всех стандартных уровнях значимости. Спецификация модели неадекватна

# %% [markdown]
# #### Feature mining

# %%
df['N_gas_in'] = df_X['Давление газа На входе компрессора (кПа)']/df_X['Температура газа На входе компрессора']
df['N_gas_out'] = df_X['Давление газа На выходе компрессора (МПа)']/df_X['Температура газа На выходе компрессора']
df['N_oil'] = df_X['Давление масла 1 (кПа)']/df_X['Температура масла (С)']

df_X['N_gas_in'] = df['N_gas_in']
df_X['N_gas_out'] = df['N_gas_out']
df_X['N_oil'] = df['N_oil']

# %%
feature = [
 'Обороты 1',
 'Сдвиг Подшипник 1',
 'Сдвиг Подшипник 2',
 'Сдвиг Подшипник 3',
 'N_gas_in',
 'N_gas_out',
 'N_oil']

# %%
import seaborn as sns

# %%
import seaborn as sns; sns.set_theme(color_codes=True)
#sns.set(rc={'axes.facecolor':'black',
            #'figure.facecolor':'black',
            #'axes.labelcolor':'white',
            #'xtick.color':'white',
            #'ytick.color':'white'})
ax = sns.regplot(x=feature[0],
                 y="Вибрация Подшипник 1",
                 data=df,
                 scatter_kws={'s':7, "color": "black", 'alpha':0.5},
                 line_kws={"color": "red"}, order = 1)

# %%
ax = sns.regplot(x=feature[1],
                 y="Вибрация Подшипник 1",
                 data=df,
                 scatter_kws={'s':7, "color": "black", 'alpha':0.5},
                 line_kws={"color": "red"}, order =1)

# %%
ax = sns.regplot(x=feature[2],
                 y="Вибрация Подшипник 1",
                 data=df,
                 scatter_kws={'s':7, "color": "black", 'alpha':0.5},
                 line_kws={"color": "red"}, order = 2)

# %%
ax = sns.regplot(x=feature[3],
                 y="Вибрация Подшипник 1",
                 data=df,
                 scatter_kws={'s':7, "color": "black", 'alpha':0.5},
                 line_kws={"color": "red"}, order = 1)

# %%
ax = sns.regplot(x=feature[4],
                 y="Вибрация Подшипник 1",
                 data=df,
                 scatter_kws={'s':7, "color": "black", 'alpha':0.5},
                 line_kws={"color": "red"}, order = 1)

# %%
ax = sns.regplot(x=feature[5],
                 y="Вибрация Подшипник 1",
                 data=df,
                 scatter_kws={'s':7, "color": "black", 'alpha':0.5},
                 line_kws={"color": "red"}, order = 1)

# %%
ax = sns.regplot(x=feature[6],
                 y="Вибрация Подшипник 1",
                 data=df,
                 scatter_kws={'s':7, "color": "black", 'alpha':0.5},
                 line_kws={"color": "red"}, order = 1)

# %%
train_data = df_X[feature]
train_labels.head(3)
train_data = sm.add_constant(train_data)

# %%
train_data.head(3)
# Out:
#    const    Обороты 1  Сдвиг Подшипник 1  Сдвиг Подшипник 2  \
# 0    1.0  5258.662931          -0.041063          -0.031354
# 1    1.0  5277.254228          -0.043171          -0.031549
# 2    1.0  5331.892912          -0.040885          -0.032023
#
#    Сдвиг Подшипник 3  N_gas_in  N_gas_out     N_oil
# 0           0.004203  1.607123   0.033591  0.009719
# 1           0.000496  1.689633   0.033472  0.009722
# 2          -0.000016  1.654256   0.033482  0.009692

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(df_X[feature].corr(), annot = True, vmin=-1, vmax=1, center= 0)
# Out:
# <AxesSubplot:>

# %%
train_labels.head(3)
# Out:
# 0    53.798579
# 1    54.173565
# 2    55.400938
# Name: Вибрация Подшипник 1, dtype: float64

# %%
model = sm.OLS(train_labels, train_data)
fit = model.fit()
g = fit.summary()
g
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ...
# Dep. Variable:     Вибрация Подшипник 1   R-squared:                       0.722
# Model:                              OLS   Adj. R-squared:                  0.722
# Method:                   Least Squares   F-statistic:                     4074.
# Date:                  Sun, 27 Sep 2020   Prob (F-statistic):               0.00
# Time:                          15:37:25   Log-Likelihood:                -28786.
# No. Observations:                 11004   AIC:                         5.759e+04
# Df Residuals:                     10996   BIC:                         5.765e+04
# Df Model:                             7
# Covariance Type:              nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
statsmodels.stats.diagnostic.linear_reset(fit, power=2)
# Out:
# <class 'statsmodels.stats.contrast.ContrastResults'>
# <Wald test (chi2): statistic=[[280.31891921]], p-value=6.398795886845253e-63, df_denom=1>

# %% [markdown]
# Нулевая гипотеза – спецификация модели адекватна (квадраты). P-значение = 6.4e-63. Значит нулевая гипотеза отвергается на всех стандартных уровнях значимости. Спецификация модели неадекватна. Стоит отметить значительное увеличение на десятки порядков результата.

# %% [markdown]
# Добавим квадраты переменных

# %%
feature
# Out:
# ['Обороты 1',
#  'Сдвиг Подшипник 1',
#  'Сдвиг Подшипник 2',
#  'Сдвиг Подшипник 3',
#  'N_gas_in',
#  'N_gas_out',
#  'N_oil']

# %%
df['N_gas_in^2'] = df['N_gas_in']*df['N_gas_in']
df['N_gas_out^2'] = df['N_gas_out']*df['N_gas_out']
df['N_oil^2'] = df['N_oil']*df['N_oil']
df['Обороты 1^2'] = df['Обороты 1']*df['Обороты 1']
df['Сдвиг Подшипник 1^2'] = df['Сдвиг Подшипник 1']*df['Сдвиг Подшипник 1']
df['Сдвиг Подшипник 2^2'] = df['Сдвиг Подшипник 2']*df['Сдвиг Подшипник 2']
df['Сдвиг Подшипник 3^2'] = df['Сдвиг Подшипник 3']*df['Сдвиг Подшипник 3']

df_X['N_gas_in^2'] = df['N_gas_in^2']
df_X['N_gas_out^2'] = df['N_gas_out^2']
df_X['N_oil^2'] = df['N_oil^2']
df_X['Обороты 1^2'] = df['Обороты 1^2']
df_X['Сдвиг Подшипник 1^2'] = df['Сдвиг Подшипник 1^2']
df_X['Сдвиг Подшипник 2^2'] = df['Сдвиг Подшипник 2^2']
df_X['Сдвиг Подшипник 3^2'] = df['Сдвиг Подшипник 3^2']

# %%
df.head(3)
# Out:
#          Дата и время    Обороты 1    Обороты 2    Обороты 3  \
# 0 2016-09-02 00:10:00  5258.662931  5258.780949  5255.826839
# 1 2016-09-02 00:20:00  5277.254228  5277.860518  5274.922677
# 2 2016-09-02 00:30:00  5331.892912  5332.584639  5329.195142
#
#    Вибрация Подшипник 1  Вибрация Подшипник 2  Вибрация Подшипник 3  \
# 0             53.798579             28.936931             45.781854
# 1             54.173565             28.835001             45.525913
# 2             55.400938             28.720065             45.859280
#
#    Сдвиг Подшипник 1  Сдвиг Подшипник 2  Сдвиг Подшипник 3  ...  N_gas_in  \
# 0          -0.041063          -0.031354           0.004203  ...  1.607123
# 1          -0.043171          -0.031549           0.000496  ...  1.689633
# 2          -0.040885          -0.032023          -0.000016  ...  1.654256
#
#    N_gas_out     N_oil  N_gas_in^2  N_gas_out^2   N_oil^2   Обороты 1^2  \
# ...

# %%
df_X.head(3)
# Out:
#          Дата и время    Обороты 1  Сдвиг Подшипник 1  Сдвиг Подшипник 2  \
# 0 2016-09-02 00:10:00  5258.662931          -0.041063          -0.031354
# 1 2016-09-02 00:20:00  5277.254228          -0.043171          -0.031549
# 2 2016-09-02 00:30:00  5331.892912          -0.040885          -0.032023
#
#    Сдвиг Подшипник 3  Давление масла 1 (кПа)  Температура масла (С)  \
# 0           0.004203                0.344716              35.467580
# 1           0.000496                0.344712              35.456034
# 2          -0.000016                0.344361              35.528870
#
#    Температура газа На входе компрессора  \
# 0                              23.744987
# 1                              23.127557
# 2                              23.599861
#
#    Температура газа На выходе компрессора  \
# 0                              105.907962
# 1                              104.946009
# 2                              106.309756
#
# ...

# %%
feature = [
 'Обороты 1',
 'Сдвиг Подшипник 1',
 'Сдвиг Подшипник 2',
 'Сдвиг Подшипник 3',
 'N_gas_in',
 'N_gas_out',
 'N_oil',
 'N_gas_in^2',
 'N_gas_out^2',
 'N_oil^2',
 'Обороты 1^2',
 'Сдвиг Подшипник 1^2',
 'Сдвиг Подшипник 2^2',
 'Сдвиг Подшипник 3^2']

# %%
train_data = df_X[feature]
train_labels.head(3)
train_data = sm.add_constant(train_data)

# %%
train_data.head(3)
# Out:
#    const    Обороты 1  Сдвиг Подшипник 1  Сдвиг Подшипник 2  \
# 0    1.0  5258.662931          -0.041063          -0.031354
# 1    1.0  5277.254228          -0.043171          -0.031549
# 2    1.0  5331.892912          -0.040885          -0.032023
#
#    Сдвиг Подшипник 3  N_gas_in  N_gas_out     N_oil  N_gas_in^2  N_gas_out^2  \
# 0           0.004203  1.607123   0.033591  0.009719    2.582844     0.001128
# 1           0.000496  1.689633   0.033472  0.009722    2.854859     0.001120
# 2          -0.000016  1.654256   0.033482  0.009692    2.736562     0.001121
#
#     N_oil^2   Обороты 1^2  Сдвиг Подшипник 1^2  Сдвиг Подшипник 2^2  \
# 0  0.000094  2.765354e+07             0.001686             0.000983
# 1  0.000095  2.784941e+07             0.001864             0.000995
# 2  0.000094  2.842908e+07             0.001672             0.001025
#
#    Сдвиг Подшипник 3^2
# 0         1.766763e-05
# 1         2.464321e-07
# 2         2.649095e-10

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(df_X[feature].corr(), annot = True, vmin=-1, vmax=1, center= 0)
# Out:
# <AxesSubplot:>

# %%
feature = [
 'Обороты 1',
 'Сдвиг Подшипник 1',
 'Сдвиг Подшипник 2',
 'Сдвиг Подшипник 3',
 'N_gas_in',
 'N_gas_out',
 'N_oil',
 'Сдвиг Подшипник 1^2',
    'Сдвиг Подшипник 3^2',]

# %%
train_data = df_X[feature]
train_labels.head(3)
train_data = sm.add_constant(train_data)

# %%
train_data.head(3)
# Out:
#    const    Обороты 1  Сдвиг Подшипник 1  Сдвиг Подшипник 2  \
# 0    1.0  5258.662931          -0.041063          -0.031354
# 1    1.0  5277.254228          -0.043171          -0.031549
# 2    1.0  5331.892912          -0.040885          -0.032023
#
#    Сдвиг Подшипник 3  N_gas_in  N_gas_out     N_oil  Сдвиг Подшипник 1^2  \
# 0           0.004203  1.607123   0.033591  0.009719             0.001686
# 1           0.000496  1.689633   0.033472  0.009722             0.001864
# 2          -0.000016  1.654256   0.033482  0.009692             0.001672
#
#    Сдвиг Подшипник 3^2
# 0         1.766763e-05
# 1         2.464321e-07
# 2         2.649095e-10

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(df_X[feature].corr(), annot = True, vmin=-1, vmax=1, center= 0)
# Out:
# <AxesSubplot:>

# %%
model = sm.OLS(train_labels, train_data)
fit = model.fit()
g = fit.summary()
g
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ...
# Dep. Variable:     Вибрация Подшипник 1   R-squared:                       0.734
# Model:                              OLS   Adj. R-squared:                  0.734
# Method:                   Least Squares   F-statistic:                     3371.
# Date:                  Sun, 27 Sep 2020   Prob (F-statistic):               0.00
# Time:                          15:37:27   Log-Likelihood:                -28537.
# No. Observations:                 11004   AIC:                         5.709e+04
# Df Residuals:                     10994   BIC:                         5.717e+04
# Df Model:                             9
# Covariance Type:              nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...

# %%
statsmodels.stats.diagnostic.linear_reset(fit, power=2)
# Out:
# <class 'statsmodels.stats.contrast.ContrastResults'>
# <Wald test (chi2): statistic=[[151.86374637]], p-value=6.785866850028105e-35, df_denom=1>

# %% [markdown]
# Нулевая гипотеза – спецификация модели адекватна (квадраты).
# P-значение = 6.8e-35.
# Значит нулевая гипотеза отвергается на всех стандартных уровнях значимости.
# Спецификация модели неадекватна.
# Стоит отметить значительное увеличение на десятки порядков результата.

# %% [markdown]
# Добавим обратные величины

# %%
df['Обрат Обороты 1'] = 1/df['Обороты 1']
df['Обрат Сдвиг Подшипник 1'] = 1/df['Сдвиг Подшипник 1']
df['Обрат Сдвиг Подшипник 2'] = 1/df['Сдвиг Подшипник 2']
df['Обрат Сдвиг Подшипник 3'] = 1/df['Сдвиг Подшипник 3']

df_X['Обрат Обороты 1'] = df['Обрат Обороты 1']
df_X['Обрат Сдвиг Подшипник 1'] = df['Обрат Сдвиг Подшипник 1']
df_X['Обрат Сдвиг Подшипник 2'] = df['Обрат Сдвиг Подшипник 2']
df_X['Обрат Сдвиг Подшипник 3'] = df['Обрат Сдвиг Подшипник 3']

# %%
feature = [
 'Обороты 1',
 'Сдвиг Подшипник 1',
 'Сдвиг Подшипник 2',
 'Сдвиг Подшипник 3',
 'N_gas_in',
 'N_gas_out',
 'N_oil',
 'Сдвиг Подшипник 1^2',
    'Сдвиг Подшипник 3^2',
    'Обрат Обороты 1',
    'Обрат Сдвиг Подшипник 1',
    'Обрат Сдвиг Подшипник 2',
    'Обрат Сдвиг Подшипник 3']

# %%
fig, ax = plt.subplots(figsize=(15,15))
sns.heatmap(df_X[feature].corr(), annot = True, vmin=-1, vmax=1, center= 0)
# Out:
# <AxesSubplot:>

# %%
feature = [
 'Обороты 1',
 'Сдвиг Подшипник 1',
 'Сдвиг Подшипник 2',
 'Сдвиг Подшипник 3',
 'N_gas_in',
 'N_gas_out',
 'N_oil',
 'Сдвиг Подшипник 1^2',
    'Сдвиг Подшипник 3^2',
    'Обрат Сдвиг Подшипник 1',
    'Обрат Сдвиг Подшипник 3']

fig, ax = plt.subplots(figsize=(15,15))
sns.heatmap(df_X[feature].corr(), annot = True, vmin=-1, vmax=1, center= 0)
# Out:
# <AxesSubplot:>

# %%
train_data = df_X[feature]
train_labels.head(3)
train_data = sm.add_constant(train_data)

model = sm.OLS(train_labels, train_data)
fit = model.fit()
g = fit.summary()
g
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ...
# Dep. Variable:     Вибрация Подшипник 1   R-squared:                       0.734
# Model:                              OLS   Adj. R-squared:                  0.734
# Method:                   Least Squares   F-statistic:                     2758.
# Date:                  Sun, 27 Sep 2020   Prob (F-statistic):               0.00
# Time:                          15:37:28   Log-Likelihood:                -28537.
# No. Observations:                 11004   AIC:                         5.710e+04
# Df Residuals:                     10992   BIC:                         5.719e+04
# Df Model:                            11
# Covariance Type:              nonrobust
# ...
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# ...

# %%
statsmodels.stats.diagnostic.linear_reset(fit, power=2)
# Out:
# <class 'statsmodels.stats.contrast.ContrastResults'>
# <Wald test (chi2): statistic=[[151.86694162]], p-value=6.774963888289924e-35, df_denom=1>

# %% [markdown]
# Нулевая гипотеза – спецификация модели адекватна (квадраты).
# P-значение = 6.8e-35.
# Значит нулевая гипотеза отвергается на всех стандартных уровнях значимости.
# Спецификация модели неадекватна.
# Для подбора спецификации необходимо более детальное понимание работы устройства.

# %% [markdown]
# ### ML подход

# %% [markdown]
# ### Вибрация 1-ого подшипника.

# %%
feature = ['Дата и время',
 'Обороты 1',
 'Сдвиг Подшипник 1',
 'Сдвиг Подшипник 2',
 'Сдвиг Подшипник 3',
 'Давление масла 1 (кПа)',
 'Температура масла (С)',
 'Температура газа На входе компрессора',
 'Температура газа На выходе компрессора',
 'Давление газа На входе компрессора (кПа)',
 'Давление газа На выходе компрессора (МПа)']

# %%
from sklearn import model_selection
from sklearn import metrics
from sklearn import linear_model

train_data_with_time, test_data_with_time, train_labels, test_labels = model_selection.train_test_split(
    df[feature], df_Y[['Вибрация Подшипник 1']],
    test_size = 0.3, random_state = 0)

# %%
train_data = train_data_with_time.drop(labels = 'Дата и время', axis = 1)
test_data = test_data_with_time.drop(labels = 'Дата и время', axis = 1)

# %%
train_data.head(3)
# Out:
#         Обороты 1  Сдвиг Подшипник 1  Сдвиг Подшипник 2  Сдвиг Подшипник 3  \
# 326   5690.409310          -0.044005          -0.037722          -0.013086
# 9624  5507.845046          -0.026793          -0.031441          -0.005843
# 463   5735.913114          -0.033573          -0.036878          -0.018636
#
#       Давление масла 1 (кПа)  Температура масла (С)  \
# 326                 0.333918              41.436768
# 9624                0.341639              39.529826
# 463                 0.332840              42.050476
#
#       Температура газа На входе компрессора  \
# 326                               32.200254
# 9624                              34.848592
# 463                               30.245932
#
#       Температура газа На выходе компрессора  \
# 326                               116.979284
# 9624                              114.352496
# 463                               118.368103
#
#       Давление газа На входе компрессора (кПа)  \
# ...

# %%
from sklearn.linear_model import LinearRegression

model_LR = LinearRegression()
model_LR.fit(train_data, train_labels)
model_predictions = model_LR.predict(test_data)

# %% [markdown]
# MSE

# %%
metrics.mean_squared_error(test_labels, model_predictions)
# Out:
# 10.490947392829261

# %%
df_model_predictions = pd.DataFrame(data=model_predictions)
df_model_predictions.head(3)
# Out:
#            0
# 0  61.016653
# 1  61.910919
# 2  73.736708

# %%
train_data.head(3)
# Out:
#         Обороты 1  Сдвиг Подшипник 1  Сдвиг Подшипник 2  Сдвиг Подшипник 3  \
# 326   5690.409310          -0.044005          -0.037722          -0.013086
# 9624  5507.845046          -0.026793          -0.031441          -0.005843
# 463   5735.913114          -0.033573          -0.036878          -0.018636
#
#       Давление масла 1 (кПа)  Температура масла (С)  \
# 326                 0.333918              41.436768
# 9624                0.341639              39.529826
# 463                 0.332840              42.050476
#
#       Температура газа На входе компрессора  \
# 326                               32.200254
# 9624                              34.848592
# 463                               30.245932
#
#       Температура газа На выходе компрессора  \
# 326                               116.979284
# 9624                              114.352496
# 463                               118.368103
#
#       Давление газа На входе компрессора (кПа)  \
# ...

# %%
feature = ['Обороты 1',
 'Сдвиг Подшипник 1',
 'Сдвиг Подшипник 2',
 'Сдвиг Подшипник 3',
 'Давление масла 1 (кПа)',
 'Температура масла (С)',
 'Температура газа На входе компрессора',
 'Температура газа На выходе компрессора',
 'Давление газа На входе компрессора (кПа)',
 'Давление газа На выходе компрессора (МПа)']

# %%
for i in range(len(feature)):
    print(feature[i], ' = ', model_LR.coef_[0][i])
# Out:
# Обороты 1  =  0.018609838918690665
# Сдвиг Подшипник 1  =  88.43072913696372
# Сдвиг Подшипник 2  =  -405.4839357921208
# Сдвиг Подшипник 3  =  -34.916594557964174
# Давление масла 1 (кПа)  =  -575.357728619246
# Температура масла (С)  =  0.21420283975863322
# Температура газа На входе компрессора  =  -0.043155062583072466
# Температура газа На выходе компрессора  =  -0.12536324110748437
# Давление газа На входе компрессора (кПа)  =  -0.13006008563293178
# Давление газа На выходе компрессора (МПа)  =  2.1438121126145915

# %% [markdown]
# Другая модель

# %%
feature = ['Дата и время',
 'Обороты 1',
 'Сдвиг Подшипник 1',
 'Сдвиг Подшипник 2',
 'Сдвиг Подшипник 3',
 'N_gas_in',
 'N_gas_out',
 'N_oil',
 'Сдвиг Подшипник 1^2',
 'Сдвиг Подшипник 3^2']

# %%
df[feature].head(3)
# Out:
#          Дата и время    Обороты 1  Сдвиг Подшипник 1  Сдвиг Подшипник 2  \
# 0 2016-09-02 00:10:00  5258.662931          -0.041063          -0.031354
# 1 2016-09-02 00:20:00  5277.254228          -0.043171          -0.031549
# 2 2016-09-02 00:30:00  5331.892912          -0.040885          -0.032023
#
#    Сдвиг Подшипник 3  N_gas_in  N_gas_out     N_oil  Сдвиг Подшипник 1^2  \
# 0           0.004203  1.607123   0.033591  0.009719             0.001686
# 1           0.000496  1.689633   0.033472  0.009722             0.001864
# 2          -0.000016  1.654256   0.033482  0.009692             0.001672
#
#    Сдвиг Подшипник 3^2
# 0         1.766763e-05
# 1         2.464321e-07
# 2         2.649095e-10

# %%
train_data_with_time, test_data_with_time, train_labels, test_labels = model_selection.train_test_split(
    df[feature], df_Y[['Вибрация Подшипник 1']],
    test_size = 0.3, random_state = 0)

# %%
train_data = train_data_with_time.drop(labels = 'Дата и время', axis = 1)
test_data = test_data_with_time.drop(labels = 'Дата и время', axis = 1)

# %%
model_LR = LinearRegression()
model_LR.fit(train_data, train_labels)
model_predictions = model_LR.predict(test_data)

# %% [markdown]
# MSE

# %%
metrics.mean_squared_error(test_labels, model_predictions)
# Out:
# 10.312747516817867

# %%
df_model_predictions = pd.DataFrame(data=model_predictions)
df_model_predictions.head(3)
# Out:
#            0
# 0  62.148483
# 1  63.234531
# 2  74.264729

# %%
feature = feature[1:]
feature
# Out:
# ['Обороты 1',
#  'Сдвиг Подшипник 1',
#  'Сдвиг Подшипник 2',
#  'Сдвиг Подшипник 3',
#  'N_gas_in',
#  'N_gas_out',
#  'N_oil',
#  'Сдвиг Подшипник 1^2',
#  'Сдвиг Подшипник 3^2']

# %%
for i in range(len(feature)):
    print(feature[i], ' = ', model_LR.coef_[0][i])
# Out:
# Обороты 1  =  0.022082801618752146
# Сдвиг Подшипник 1  =  39.88838900898378
# Сдвиг Подшипник 2  =  -420.0004624886363
# Сдвиг Подшипник 3  =  -184.4072024641636
# N_gas_in  =  -0.7578438979205707
# N_gas_out  =  591.4407631363326
# N_oil  =  -5198.487829915386
# Сдвиг Подшипник 1^2  =  -1393.275403920896
# Сдвиг Подшипник 3^2  =  -6955.629332322441

# %% [markdown]
# График наблюдений и расчетных значений

# %%
df_plot = pd.DataFrame({'prediction' : [], 'Дата и время' : [], 'Вибрация Подшипник 1' : []})
df_plot
# Out:
# Empty DataFrame
# Columns: [prediction, Дата и время, Вибрация Подшипник 1]
# Index: []

# %%
test_labels['Вибрация Подшипник 1']
df_model_predictions[0]
test_data_with_time['Дата и время']
# Out:
# 7165    2016-10-21 18:20:00.001
# 10235   2016-11-12 02:00:00.001
# 1121    2016-09-09 19:00:00.000
# 1328    2016-09-11 05:30:00.000
# 3806    2016-09-28 10:30:00.000
#                   ...
# 3359    2016-09-25 08:00:00.000
# 3277    2016-09-24 18:20:00.000
# 8844    2016-11-02 10:10:00.001
# 1589    2016-09-13 01:00:00.000
# 7913    2016-10-26 23:00:00.001
# Name: Дата и время, Length: 3302, dtype: datetime64[ns]

# %%
plt.figure(figsize=(15,5), dpi=80, facecolor='w', edgecolor='k')
ax = plt.gca()  
plt.scatter(test_data_with_time['Дата и время'], test_labels['Вибрация Подшипник 1'], color = 'red', label = 'Real', s = 1)

plt.scatter(test_data_with_time['Дата и время'], df_model_predictions[0], color = 'blue', label = 'Predicted', s=1)
plt.title('Вибрация Подшипник 1', fontsize=14)
plt.legend(loc=2, prop={'size': 14})
plt.show()

# %% [markdown]
# ### Вибрация 2-ого подшипника

# %%
feature = ['Дата и время',
 'Обороты 1',
 'Сдвиг Подшипник 1',
 'Сдвиг Подшипник 2',
 'Сдвиг Подшипник 3',
 'N_gas_in',
 'N_gas_out',
 'N_oil',
 'Сдвиг Подшипник 1^2',
 'Сдвиг Подшипник 3^2']

# %%
from sklearn import model_selection
from sklearn import metrics
from sklearn import linear_model

train_data_with_time, test_data_with_time, train_labels, test_labels = model_selection.train_test_split(
    df_X[feature], df_Y[['Вибрация Подшипник 2']],
    test_size = 0.3, random_state = 0)

# %%
train_data = train_data_with_time.drop(labels = 'Дата и время', axis = 1)
test_data = test_data_with_time.drop(labels = 'Дата и время', axis = 1)

# %%
from sklearn.linear_model import LinearRegression

model_LR = LinearRegression()
model_LR.fit(train_data, train_labels)
model_predictions = model_LR.predict(test_data)

# %% [markdown]
# MSE

# %%
metrics.mean_squared_error(test_labels, model_predictions)
# Out:
# 0.24068057869475804

# %%
df_model_predictions = pd.DataFrame(data=model_predictions)
df_model_predictions.head(3)
# Out:
#            0
# 0  28.942057
# 1  28.857692
# 2  29.595040

# %%
feature = ['Обороты 1',
 'Сдвиг Подшипник 1',
 'Сдвиг Подшипник 2',
 'Сдвиг Подшипник 3',
 'N_gas_in',
 'N_gas_out',
 'N_oil',
 'Сдвиг Подшипник 1^2',
 'Сдвиг Подшипник 3^2']

# %%
for i in range(len(feature)):
    print(feature[i], ' = ', model_LR.coef_[0][i])
# Out:
# Обороты 1  =  -0.0010071441756197346
# Сдвиг Подшипник 1  =  7.235292202916836
# Сдвиг Подшипник 2  =  -79.4681106771712
# Сдвиг Подшипник 3  =  -28.382408301455758
# N_gas_in  =  -0.3653171053537295
# N_gas_out  =  -275.47117767562423
# N_oil  =  -189.6960229404625
# Сдвиг Подшипник 1^2  =  -80.51539897512389
# Сдвиг Подшипник 3^2  =  -69.62301514245112

# %%
plt.figure(figsize=(15,5), dpi=80, facecolor='w', edgecolor='k')
ax = plt.gca()  
plt.scatter(test_data_with_time['Дата и время'], test_labels['Вибрация Подшипник 2'], color = 'red', label = 'Real', s = 1)

plt.scatter(test_data_with_time['Дата и время'], df_model_predictions[0], color = 'blue', label = 'Predicted', s=1)
plt.title('Вибрация Подшипник 2', fontsize=14)
plt.legend(loc=2, prop={'size': 14})
plt.show()

# %% [markdown]
# ### Вибрация 3-ого подшипника

# %%
feature = ['Дата и время',
 'Обороты 1',
 'Сдвиг Подшипник 1',
 'Сдвиг Подшипник 2',
 'Сдвиг Подшипник 3',
 'N_gas_in',
 'N_gas_out',
 'N_oil',
 'Сдвиг Подшипник 1^2',
 'Сдвиг Подшипник 3^2']

# %%
from sklearn import model_selection
from sklearn import metrics
from sklearn import linear_model

train_data_with_time, test_data_with_time, train_labels, test_labels = model_selection.train_test_split(
    df_X, df_Y[['Вибрация Подшипник 3']],
    test_size = 0.3, random_state = 0)

# %%
train_data = train_data_with_time.drop(labels = 'Дата и время', axis = 1)
test_data = test_data_with_time.drop(labels = 'Дата и время', axis = 1)

# %%
model_LR = LinearRegression()
model_LR.fit(train_data, train_labels)
model_predictions = model_LR.predict(test_data)

# %% [markdown]
# MSE

# %%
metrics.mean_squared_error(test_labels, model_predictions)
# Out:
# 0.10263938377695851

# %%
df_model_predictions = pd.DataFrame(data=model_predictions)
df_model_predictions.head(3)
# Out:
#            0
# 0  46.437460
# 1  45.535597
# 2  47.089597

# %%
feature = ['Обороты 1',
 'Сдвиг Подшипник 1',
 'Сдвиг Подшипник 2',
 'Сдвиг Подшипник 3',
 'N_gas_in',
 'N_gas_out',
 'N_oil',
 'Сдвиг Подшипник 1^2',
 'Сдвиг Подшипник 3^2']

for i in range(len(feature)):
    print(feature[i], ' = ', model_LR.coef_[0][i])
# Out:
# Обороты 1  =  0.20041093264245208
# Сдвиг Подшипник 1  =  7.0543534667370125
# Сдвиг Подшипник 2  =  1073.2405310118274
# Сдвиг Подшипник 3  =  -4.000263781187274
# N_gas_in  =  -1084.6581104674299
# N_gas_out  =  8.724051514563145
# N_oil  =  -0.09779370989217187
# Сдвиг Подшипник 1^2  =  -0.6904467062134189
# Сдвиг Подшипник 3^2  =  0.15424350110833873

# %%
plt.figure(figsize=(15,5), dpi=80, facecolor='w', edgecolor='k')
ax = plt.gca()  
plt.scatter(test_data_with_time['Дата и время'], test_labels['Вибрация Подшипник 3'], color = 'red', label = 'Real', s = 1)

plt.scatter(test_data_with_time['Дата и время'], df_model_predictions[0], color = 'blue', label = 'Predicted', s=1)
plt.title('Вибрация Подшипник 3', fontsize=14)
plt.legend(loc=2, prop={'size': 14})
plt.show()

# %% [markdown]
# ### Выводы

# %% [markdown]
# Построены математические модели для вибрации трёх подшипников.
#
# В качестве регрессоров использовались не температуры и давления, а их отношение, что пропорционально концентрации.
#
# Из-за сильной корреляции оборотов в рамках модели был оставлен только один регрессор.
