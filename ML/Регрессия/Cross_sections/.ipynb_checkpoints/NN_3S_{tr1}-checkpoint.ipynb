# %% [markdown]
# # 3S_{tr1}(1) в зависимости от плотности теплоносителя, температуры теплоносителя, температуры топлива и концентрации борной кислоты

# %% [markdown]
# ## 1. Загрузка данных

# %%
import pandas as pd

# %% [markdown]
# Загрузка данных

# %%
df = pd.read_excel('Input/Data.xlsx')
df.head(3)
# Out:
#    \rho(g/cm^3)  T_c(K)  T_f(K)  c_b(ppm)  3S_{tr1}(1)  3S_{tr2}(2)  \
# 0        0.7235   575.0  1027.0     600.0     0.661853     2.568298
# 1        0.7750   448.0  1043.0    1500.0     0.679602     2.874687
# 2        0.9125   370.5  1418.0     750.0     0.727336     3.668742
#
#    \Sigma_{a1}(3)  \Sigma_{a2}(4)  nuS_{f1}(5)  nuS_{f2}(6)  \Sigma_{f1}(7)  \
# 0        0.009376        0.085584     0.006677     0.133250        0.002620
# 1        0.009581        0.098339     0.006723     0.139256        0.002636
# 2        0.009908        0.102815     0.006844     0.153823        0.002681
#
#    \Sigma_{f2}(8)  \Sigma_{1->2}(9)  k_{inf}(10)  \sigma_{a2}^{Xe}  \
# 0        0.054750          0.017392     1.261041         1072970.0
# 1        0.057218          0.018726     1.174265         1141000.0
# 2        0.063203          0.022463     1.249619         1308480.0
#
#    \sigma_{a2}^{Sm}
# 0         35421.398
# 1         36147.801
# 2         39214.000

# %%
names = ['\\rho(g/cm^3)',
 'T_c(K)',
 'T_f(K)',
 'c_b(ppm)',
 '3S_{tr1}(1)']

# %%
df = df[names]
df.head(3)
# Out:
#    \rho(g/cm^3)  T_c(K)  T_f(K)  c_b(ppm)  3S_{tr1}(1)
# 0        0.7235   575.0  1027.0     600.0     0.661853
# 1        0.7750   448.0  1043.0    1500.0     0.679602
# 2        0.9125   370.5  1418.0     750.0     0.727336

# %% [markdown]
# ### 2 Нормализация признаков

# %%
features = ['\\rho(g/cm^3)',
 'T_c(K)',
 'T_f(K)',
 'c_b(ppm)']

# %%
df_features_norm = df.copy()

# %%
for i in range(len(features)):
    df_features_norm[features[i]] = (df[features[i]]-df[features[i]].mean())/df[features[i]].std()

# %%
df_features_norm
# Out:
#      \rho(g/cm^3)    T_c(K)    T_f(K)  c_b(ppm)  3S_{tr1}(1)
# 0       -0.316426  1.416398 -0.039094 -1.035019     0.661853
# 1        0.007922 -0.005506 -0.001946  0.006984     0.679602
# 2        0.873902 -0.873204  0.868693 -0.861352     0.727336
# 3       -0.858058  0.862191 -0.872586  0.875321     0.631943
# 4       -0.425067 -0.439355  0.433373 -1.295520     0.656474
# ..            ...       ...       ...       ...          ...
# 252     -0.844527 -0.886762 -1.539169 -0.603564     0.630867
# 253      0.887433  0.848634  0.202111  1.133108     0.727892
# 254      0.021453 -0.019064  1.072750 -1.471900     0.681217
# 255     -1.710507  1.716332 -0.668529  0.264771     0.586982
# 256     -1.703741 -0.012286  0.535401 -0.746026     0.588713
#
# [257 rows x 5 columns]

# %%
df_features_norm.sample(frac=1)
# Out:
#      \rho(g/cm^3)    T_c(K)    T_f(K)  c_b(ppm)  3S_{tr1}(1)
# 40      -0.912182 -1.469746  1.031937 -1.241249     0.631042
# 92      -0.668625 -1.117245 -0.518888 -0.997029     0.642207
# 247     -1.061022  0.631710 -1.321509 -1.254816     0.619732
# 231     -1.169269  1.174021  0.963920 -0.712106     0.617459
# 228     -0.303290 -1.429073  0.093281  0.156229     0.662915
# ..            ...       ...       ...       ...          ...
# 13       1.090397  0.645267 -0.219606 -1.512604     0.737610
# 9        0.657407  1.079116  1.086353 -1.078436     0.715799
# 77       1.171583  1.160463 -1.716017  1.282353     0.740012
# 134      0.481505 -0.154642  0.555806  0.237637     0.705990
# 232     -0.952774 -1.212148 -0.124380 -1.363358     0.627498
#
# [257 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df_features_norm[['\\rho(g/cm^3)', 'T_c(K)', 'T_f(K)', 'c_b(ppm)']],
                                                    df_features_norm[['3S_{tr1}(1)']],
                                                    test_size=0.33,
                                                    random_state=42)

# %% [markdown]
# # Нейросетевые модели

# %%
# %%time

# Use scikit-learn to grid search the batch size and epochs
import numpy
from sklearn.model_selection import GridSearchCV
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor
import tensorflow as tf

# Function to create model, required for KerasRegressor
def create_model(activation='relu', learn_rate=0.01, momentum=0):
    # create model
    model = Sequential()
    model.add(Dense(4, input_dim=4, activation=activation))
    model.add(Dense(1, kernel_initializer='normal'))
    
    optimizer = tf.keras.optimizers.RMSprop(learning_rate = learn_rate, rho = 0.99, momentum = momentum, epsilon=1e-09)
    
    # Compile model
    model.compile(loss='mse', optimizer=optimizer)
    return model

X = X_train
Y = y_train

# create model
model = KerasRegressor(build_fn=create_model, verbose=0)

# define the grid search parameters
batch_size = [10, 15, 20]
epochs = [1000, 1200, 1300]
activation = ['tanh', 'sigmoid', 'linear']
learn_rate = [0.00015, 0.0002, 0.00025]
momentum = [0, 0.00001]

param_grid = dict(batch_size=batch_size,
                  epochs=epochs,
                  activation=activation,
                  learn_rate=learn_rate,
                  momentum=momentum
                 )
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=5)
grid_result = grid.fit(X, Y)

# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: -0.000000 using {'activation': 'linear', 'batch_size': 10, 'epochs': 1000, 'learn_rate': 0.00015, 'momentum': 0}
# -0.000006 (0.000003) with: {'activation': 'tanh', 'batch_size': 10, 'epochs': 1000, 'learn_rate': 0.00015, 'momentum': 0}
# -0.000014 (0.000008) with: {'activation': 'tanh', 'batch_size': 10, 'epochs': 1000, 'learn_rate': 0.00015, 'momentum': 1e-05}
# -0.000005 (0.000002) with: {'activation': 'tanh', 'batch_size': 10, 'epochs': 1000, 'learn_rate': 0.0002, 'momentum': 0}
# -0.000004 (0.000003) with: {'activation': 'tanh', 'batch_size': 10, 'epochs': 1000, 'learn_rate': 0.0002, 'momentum': 1e-05}
# -0.000002 (0.000001) with: {'activation': 'tanh', 'batch_size': 10, 'epochs': 1000, 'learn_rate': 0.00025, 'momentum': 0}
# -0.000004 (0.000002) with: {'activation': 'tanh', 'batch_size': 10, 'epochs': 1000, 'learn_rate': 0.00025, 'momentum': 1e-05}
# -0.000008 (0.000005) with: {'activation': 'tanh', 'batch_size': 10, 'epochs': 1200, 'learn_rate': 0.00015, 'momentum': 0}
# -0.000007 (0.000005) with: {'activation': 'tanh', 'batch_size': 10, 'epochs': 1200, 'learn_rate': 0.00015, 'momentum': 1e-05}
# -0.000002 (0.000001) with: {'activation': 'tanh', 'batch_size': 10, 'epochs': 1200, 'learn_rate': 0.0002, 'momentum': 0}
# -0.000003 (0.000002) with: {'activation': 'tanh', 'batch_size': 10, 'epochs': 1200, 'learn_rate': 0.0002, 'momentum': 1e-05}
# -0.000001 (0.000001) with: {'activation': 'tanh', 'batch_size': 10, 'epochs': 1200, 'learn_rate': 0.00025, 'momentum': 0}
# -0.000002 (0.000001) with: {'activation': 'tanh', 'batch_size': 10, 'epochs': 1200, 'learn_rate': 0.00025, 'momentum': 1e-05}
# -0.000004 (0.000004) with: {'activation': 'tanh', 'batch_size': 10, 'epochs': 1300, 'learn_rate': 0.00015, 'momentum': 0}
# -0.000006 (0.000002) with: {'activation': 'tanh', 'batch_size': 10, 'epochs': 1300, 'learn_rate': 0.00015, 'momentum': 1e-05}
# -0.000001 (0.000001) with: {'activation': 'tanh', 'batch_size': 10, 'epochs': 1300, 'learn_rate': 0.0002, 'momentum': 0}
# -0.000002 (0.000001) with: {'activation': 'tanh', 'batch_size': 10, 'epochs': 1300, 'learn_rate': 0.0002, 'momentum': 1e-05}
# -0.000002 (0.000001) with: {'activation': 'tanh', 'batch_size': 10, 'epochs': 1300, 'learn_rate': 0.00025, 'momentum': 0}
# -0.000002 (0.000001) with: {'activation': 'tanh', 'batch_size': 10, 'epochs': 1300, 'learn_rate': 0.00025, 'momentum': 1e-05}
# -0.000044 (0.000032) with: {'activation': 'tanh', 'batch_size': 15, 'epochs': 1000, 'learn_rate': 0.00015, 'momentum': 0}
# -0.000037 (0.000027) with: {'activation': 'tanh', 'batch_size': 15, 'epochs': 1000, 'learn_rate': 0.00015, 'momentum': 1e-05}
# -0.000010 (0.000005) with: {'activation': 'tanh', 'batch_size': 15, 'epochs': 1000, 'learn_rate': 0.0002, 'momentum': 0}
# -0.000011 (0.000004) with: {'activation': 'tanh', 'batch_size': 15, 'epochs': 1000, 'learn_rate': 0.0002, 'momentum': 1e-05}
# -0.000006 (0.000004) with: {'activation': 'tanh', 'batch_size': 15, 'epochs': 1000, 'learn_rate': 0.00025, 'momentum': 0}
# -0.000006 (0.000003) with: {'activation': 'tanh', 'batch_size': 15, 'epochs': 1000, 'learn_rate': 0.00025, 'momentum': 1e-05}
# -0.000019 (0.000009) with: {'activation': 'tanh', 'batch_size': 15, 'epochs': 1200, 'learn_rate': 0.00015, 'momentum': 0}
# -0.000016 (0.000005) with: {'activation': 'tanh', 'batch_size': 15, 'epochs': 1200, 'learn_rate': 0.00015, 'momentum': 1e-05}
# -0.000005 (0.000002) with: {'activation': 'tanh', 'batch_size': 15, 'epochs': 1200, 'learn_rate': 0.0002, 'momentum': 0}
# -0.000005 (0.000003) with: {'activation': 'tanh', 'batch_size': 15, 'epochs': 1200, 'learn_rate': 0.0002, 'momentum': 1e-05}
# -0.000005 (0.000003) with: {'activation': 'tanh', 'batch_size': 15, 'epochs': 1200, 'learn_rate': 0.00025, 'momentum': 0}
# -0.000008 (0.000003) with: {'activation': 'tanh', 'batch_size': 15, 'epochs': 1200, 'learn_rate': 0.00025, 'momentum': 1e-05}
# -0.000011 (0.000006) with: {'activation': 'tanh', 'batch_size': 15, 'epochs': 1300, 'learn_rate': 0.00015, 'momentum': 0}
# -0.000013 (0.000005) with: {'activation': 'tanh', 'batch_size': 15, 'epochs': 1300, 'learn_rate': 0.00015, 'momentum': 1e-05}
# -0.000005 (0.000003) with: {'activation': 'tanh', 'batch_size': 15, 'epochs': 1300, 'learn_rate': 0.0002, 'momentum': 0}
# -0.000006 (0.000003) with: {'activation': 'tanh', 'batch_size': 15, 'epochs': 1300, 'learn_rate': 0.0002, 'momentum': 1e-05}
# -0.000004 (0.000002) with: {'activation': 'tanh', 'batch_size': 15, 'epochs': 1300, 'learn_rate': 0.00025, 'momentum': 0}
# -0.000004 (0.000003) with: {'activation': 'tanh', 'batch_size': 15, 'epochs': 1300, 'learn_rate': 0.00025, 'momentum': 1e-05}
# -0.000136 (0.000097) with: {'activation': 'tanh', 'batch_size': 20, 'epochs': 1000, 'learn_rate': 0.00015, 'momentum': 0}
# -0.000105 (0.000107) with: {'activation': 'tanh', 'batch_size': 20, 'epochs': 1000, 'learn_rate': 0.00015, 'momentum': 1e-05}
# -0.000011 (0.000006) with: {'activation': 'tanh', 'batch_size': 20, 'epochs': 1000, 'learn_rate': 0.0002, 'momentum': 0}
# -0.000010 (0.000004) with: {'activation': 'tanh', 'batch_size': 20, 'epochs': 1000, 'learn_rate': 0.0002, 'momentum': 1e-05}
# -0.000009 (0.000002) with: {'activation': 'tanh', 'batch_size': 20, 'epochs': 1000, 'learn_rate': 0.00025, 'momentum': 0}
# -0.000005 (0.000002) with: {'activation': 'tanh', 'batch_size': 20, 'epochs': 1000, 'learn_rate': 0.00025, 'momentum': 1e-05}
# -0.000034 (0.000023) with: {'activation': 'tanh', 'batch_size': 20, 'epochs': 1200, 'learn_rate': 0.00015, 'momentum': 0}
# -0.000034 (0.000037) with: {'activation': 'tanh', 'batch_size': 20, 'epochs': 1200, 'learn_rate': 0.00015, 'momentum': 1e-05}
# -0.000004 (0.000002) with: {'activation': 'tanh', 'batch_size': 20, 'epochs': 1200, 'learn_rate': 0.0002, 'momentum': 0}
# -0.000007 (0.000004) with: {'activation': 'tanh', 'batch_size': 20, 'epochs': 1200, 'learn_rate': 0.0002, 'momentum': 1e-05}
# -0.000008 (0.000006) with: {'activation': 'tanh', 'batch_size': 20, 'epochs': 1200, 'learn_rate': 0.00025, 'momentum': 0}
# -0.000007 (0.000002) with: {'activation': 'tanh', 'batch_size': 20, 'epochs': 1200, 'learn_rate': 0.00025, 'momentum': 1e-05}
# -0.000017 (0.000009) with: {'activation': 'tanh', 'batch_size': 20, 'epochs': 1300, 'learn_rate': 0.00015, 'momentum': 0}
# -0.000010 (0.000003) with: {'activation': 'tanh', 'batch_size': 20, 'epochs': 1300, 'learn_rate': 0.00015, 'momentum': 1e-05}
# -0.000011 (0.000008) with: {'activation': 'tanh', 'batch_size': 20, 'epochs': 1300, 'learn_rate': 0.0002, 'momentum': 0}
# -0.000006 (0.000003) with: {'activation': 'tanh', 'batch_size': 20, 'epochs': 1300, 'learn_rate': 0.0002, 'momentum': 1e-05}
# -0.000004 (0.000002) with: {'activation': 'tanh', 'batch_size': 20, 'epochs': 1300, 'learn_rate': 0.00025, 'momentum': 0}
# -0.000004 (0.000002) with: {'activation': 'tanh', 'batch_size': 20, 'epochs': 1300, 'learn_rate': 0.00025, 'momentum': 1e-05}
# -0.000007 (0.000003) with: {'activation': 'sigmoid', 'batch_size': 10, 'epochs': 1000, 'learn_rate': 0.00015, 'momentum': 0}
# -0.000007 (0.000002) with: {'activation': 'sigmoid', 'batch_size': 10, 'epochs': 1000, 'learn_rate': 0.00015, 'momentum': 1e-05}
# -0.000003 (0.000004) with: {'activation': 'sigmoid', 'batch_size': 10, 'epochs': 1000, 'learn_rate': 0.0002, 'momentum': 0}
# -0.000004 (0.000003) with: {'activation': 'sigmoid', 'batch_size': 10, 'epochs': 1000, 'learn_rate': 0.0002, 'momentum': 1e-05}
# -0.000002 (0.000001) with: {'activation': 'sigmoid', 'batch_size': 10, 'epochs': 1000, 'learn_rate': 0.00025, 'momentum': 0}
# -0.000003 (0.000001) with: {'activation': 'sigmoid', 'batch_size': 10, 'epochs': 1000, 'learn_rate': 0.00025, 'momentum': 1e-05}
# -0.000003 (0.000002) with: {'activation': 'sigmoid', 'batch_size': 10, 'epochs': 1200, 'learn_rate': 0.00015, 'momentum': 0}
# -0.000005 (0.000003) with: {'activation': 'sigmoid', 'batch_size': 10, 'epochs': 1200, 'learn_rate': 0.00015, 'momentum': 1e-05}
# -0.000002 (0.000000) with: {'activation': 'sigmoid', 'batch_size': 10, 'epochs': 1200, 'learn_rate': 0.0002, 'momentum': 0}
# -0.000002 (0.000001) with: {'activation': 'sigmoid', 'batch_size': 10, 'epochs': 1200, 'learn_rate': 0.0002, 'momentum': 1e-05}
# -0.000001 (0.000000) with: {'activation': 'sigmoid', 'batch_size': 10, 'epochs': 1200, 'learn_rate': 0.00025, 'momentum': 0}
# -0.000002 (0.000001) with: {'activation': 'sigmoid', 'batch_size': 10, 'epochs': 1200, 'learn_rate': 0.00025, 'momentum': 1e-05}
# -0.000003 (0.000001) with: {'activation': 'sigmoid', 'batch_size': 10, 'epochs': 1300, 'learn_rate': 0.00015, 'momentum': 0}
# -0.000003 (0.000002) with: {'activation': 'sigmoid', 'batch_size': 10, 'epochs': 1300, 'learn_rate': 0.00015, 'momentum': 1e-05}
# -0.000002 (0.000000) with: {'activation': 'sigmoid', 'batch_size': 10, 'epochs': 1300, 'learn_rate': 0.0002, 'momentum': 0}
# -0.000002 (0.000001) with: {'activation': 'sigmoid', 'batch_size': 10, 'epochs': 1300, 'learn_rate': 0.0002, 'momentum': 1e-05}
# -0.000001 (0.000001) with: {'activation': 'sigmoid', 'batch_size': 10, 'epochs': 1300, 'learn_rate': 0.00025, 'momentum': 0}
# -0.000001 (0.000000) with: {'activation': 'sigmoid', 'batch_size': 10, 'epochs': 1300, 'learn_rate': 0.00025, 'momentum': 1e-05}
# -0.000013 (0.000007) with: {'activation': 'sigmoid', 'batch_size': 15, 'epochs': 1000, 'learn_rate': 0.00015, 'momentum': 0}
# -0.000010 (0.000005) with: {'activation': 'sigmoid', 'batch_size': 15, 'epochs': 1000, 'learn_rate': 0.00015, 'momentum': 1e-05}
# -0.000006 (0.000002) with: {'activation': 'sigmoid', 'batch_size': 15, 'epochs': 1000, 'learn_rate': 0.0002, 'momentum': 0}
# -0.000009 (0.000002) with: {'activation': 'sigmoid', 'batch_size': 15, 'epochs': 1000, 'learn_rate': 0.0002, 'momentum': 1e-05}
# -0.000003 (0.000001) with: {'activation': 'sigmoid', 'batch_size': 15, 'epochs': 1000, 'learn_rate': 0.00025, 'momentum': 0}
# -0.000004 (0.000001) with: {'activation': 'sigmoid', 'batch_size': 15, 'epochs': 1000, 'learn_rate': 0.00025, 'momentum': 1e-05}
# -0.000010 (0.000008) with: {'activation': 'sigmoid', 'batch_size': 15, 'epochs': 1200, 'learn_rate': 0.00015, 'momentum': 0}
# -0.000005 (0.000002) with: {'activation': 'sigmoid', 'batch_size': 15, 'epochs': 1200, 'learn_rate': 0.00015, 'momentum': 1e-05}
# -0.000005 (0.000002) with: {'activation': 'sigmoid', 'batch_size': 15, 'epochs': 1200, 'learn_rate': 0.0002, 'momentum': 0}
# -0.000004 (0.000002) with: {'activation': 'sigmoid', 'batch_size': 15, 'epochs': 1200, 'learn_rate': 0.0002, 'momentum': 1e-05}
# -0.000004 (0.000001) with: {'activation': 'sigmoid', 'batch_size': 15, 'epochs': 1200, 'learn_rate': 0.00025, 'momentum': 0}
# -0.000004 (0.000002) with: {'activation': 'sigmoid', 'batch_size': 15, 'epochs': 1200, 'learn_rate': 0.00025, 'momentum': 1e-05}
# -0.000007 (0.000003) with: {'activation': 'sigmoid', 'batch_size': 15, 'epochs': 1300, 'learn_rate': 0.00015, 'momentum': 0}
# -0.000006 (0.000004) with: {'activation': 'sigmoid', 'batch_size': 15, 'epochs': 1300, 'learn_rate': 0.00015, 'momentum': 1e-05}
# -0.000003 (0.000001) with: {'activation': 'sigmoid', 'batch_size': 15, 'epochs': 1300, 'learn_rate': 0.0002, 'momentum': 0}
# -0.000005 (0.000001) with: {'activation': 'sigmoid', 'batch_size': 15, 'epochs': 1300, 'learn_rate': 0.0002, 'momentum': 1e-05}
# -0.000003 (0.000001) with: {'activation': 'sigmoid', 'batch_size': 15, 'epochs': 1300, 'learn_rate': 0.00025, 'momentum': 0}
# -0.000003 (0.000001) with: {'activation': 'sigmoid', 'batch_size': 15, 'epochs': 1300, 'learn_rate': 0.00025, 'momentum': 1e-05}
# -0.000025 (0.000022) with: {'activation': 'sigmoid', 'batch_size': 20, 'epochs': 1000, 'learn_rate': 0.00015, 'momentum': 0}
# -0.000014 (0.000008) with: {'activation': 'sigmoid', 'batch_size': 20, 'epochs': 1000, 'learn_rate': 0.00015, 'momentum': 1e-05}
# -0.000008 (0.000004) with: {'activation': 'sigmoid', 'batch_size': 20, 'epochs': 1000, 'learn_rate': 0.0002, 'momentum': 0}
# -0.000011 (0.000003) with: {'activation': 'sigmoid', 'batch_size': 20, 'epochs': 1000, 'learn_rate': 0.0002, 'momentum': 1e-05}
# -0.000004 (0.000001) with: {'activation': 'sigmoid', 'batch_size': 20, 'epochs': 1000, 'learn_rate': 0.00025, 'momentum': 0}
# -0.000009 (0.000002) with: {'activation': 'sigmoid', 'batch_size': 20, 'epochs': 1000, 'learn_rate': 0.00025, 'momentum': 1e-05}
# -0.000008 (0.000005) with: {'activation': 'sigmoid', 'batch_size': 20, 'epochs': 1200, 'learn_rate': 0.00015, 'momentum': 0}
# -0.000013 (0.000004) with: {'activation': 'sigmoid', 'batch_size': 20, 'epochs': 1200, 'learn_rate': 0.00015, 'momentum': 1e-05}
# -0.000006 (0.000003) with: {'activation': 'sigmoid', 'batch_size': 20, 'epochs': 1200, 'learn_rate': 0.0002, 'momentum': 0}
# -0.000009 (0.000006) with: {'activation': 'sigmoid', 'batch_size': 20, 'epochs': 1200, 'learn_rate': 0.0002, 'momentum': 1e-05}
# -0.000004 (0.000002) with: {'activation': 'sigmoid', 'batch_size': 20, 'epochs': 1200, 'learn_rate': 0.00025, 'momentum': 0}
# -0.000003 (0.000002) with: {'activation': 'sigmoid', 'batch_size': 20, 'epochs': 1200, 'learn_rate': 0.00025, 'momentum': 1e-05}
# -0.000008 (0.000003) with: {'activation': 'sigmoid', 'batch_size': 20, 'epochs': 1300, 'learn_rate': 0.00015, 'momentum': 0}
# -0.000006 (0.000003) with: {'activation': 'sigmoid', 'batch_size': 20, 'epochs': 1300, 'learn_rate': 0.00015, 'momentum': 1e-05}
# -0.000005 (0.000003) with: {'activation': 'sigmoid', 'batch_size': 20, 'epochs': 1300, 'learn_rate': 0.0002, 'momentum': 0}
# -0.000005 (0.000002) with: {'activation': 'sigmoid', 'batch_size': 20, 'epochs': 1300, 'learn_rate': 0.0002, 'momentum': 1e-05}
# -0.000003 (0.000002) with: {'activation': 'sigmoid', 'batch_size': 20, 'epochs': 1300, 'learn_rate': 0.00025, 'momentum': 0}
# -0.000004 (0.000002) with: {'activation': 'sigmoid', 'batch_size': 20, 'epochs': 1300, 'learn_rate': 0.00025, 'momentum': 1e-05}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 10, 'epochs': 1000, 'learn_rate': 0.00015, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 10, 'epochs': 1000, 'learn_rate': 0.00015, 'momentum': 1e-05}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 10, 'epochs': 1000, 'learn_rate': 0.0002, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 10, 'epochs': 1000, 'learn_rate': 0.0002, 'momentum': 1e-05}
# -0.000001 (0.000001) with: {'activation': 'linear', 'batch_size': 10, 'epochs': 1000, 'learn_rate': 0.00025, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 10, 'epochs': 1000, 'learn_rate': 0.00025, 'momentum': 1e-05}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 10, 'epochs': 1200, 'learn_rate': 0.00015, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 10, 'epochs': 1200, 'learn_rate': 0.00015, 'momentum': 1e-05}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 10, 'epochs': 1200, 'learn_rate': 0.0002, 'momentum': 0}
# -0.000001 (0.000001) with: {'activation': 'linear', 'batch_size': 10, 'epochs': 1200, 'learn_rate': 0.0002, 'momentum': 1e-05}
# -0.000001 (0.000001) with: {'activation': 'linear', 'batch_size': 10, 'epochs': 1200, 'learn_rate': 0.00025, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 10, 'epochs': 1200, 'learn_rate': 0.00025, 'momentum': 1e-05}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 10, 'epochs': 1300, 'learn_rate': 0.00015, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 10, 'epochs': 1300, 'learn_rate': 0.00015, 'momentum': 1e-05}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 10, 'epochs': 1300, 'learn_rate': 0.0002, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 10, 'epochs': 1300, 'learn_rate': 0.0002, 'momentum': 1e-05}
# -0.000001 (0.000001) with: {'activation': 'linear', 'batch_size': 10, 'epochs': 1300, 'learn_rate': 0.00025, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 10, 'epochs': 1300, 'learn_rate': 0.00025, 'momentum': 1e-05}
# -0.000001 (0.000001) with: {'activation': 'linear', 'batch_size': 15, 'epochs': 1000, 'learn_rate': 0.00015, 'momentum': 0}
# -0.000001 (0.000001) with: {'activation': 'linear', 'batch_size': 15, 'epochs': 1000, 'learn_rate': 0.00015, 'momentum': 1e-05}
# -0.000001 (0.000001) with: {'activation': 'linear', 'batch_size': 15, 'epochs': 1000, 'learn_rate': 0.0002, 'momentum': 0}
# -0.000001 (0.000001) with: {'activation': 'linear', 'batch_size': 15, 'epochs': 1000, 'learn_rate': 0.0002, 'momentum': 1e-05}
# -0.000001 (0.000000) with: {'activation': 'linear', 'batch_size': 15, 'epochs': 1000, 'learn_rate': 0.00025, 'momentum': 0}
# -0.000001 (0.000001) with: {'activation': 'linear', 'batch_size': 15, 'epochs': 1000, 'learn_rate': 0.00025, 'momentum': 1e-05}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 15, 'epochs': 1200, 'learn_rate': 0.00015, 'momentum': 0}
# -0.000001 (0.000000) with: {'activation': 'linear', 'batch_size': 15, 'epochs': 1200, 'learn_rate': 0.00015, 'momentum': 1e-05}
# -0.000001 (0.000000) with: {'activation': 'linear', 'batch_size': 15, 'epochs': 1200, 'learn_rate': 0.0002, 'momentum': 0}
# -0.000001 (0.000001) with: {'activation': 'linear', 'batch_size': 15, 'epochs': 1200, 'learn_rate': 0.0002, 'momentum': 1e-05}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 15, 'epochs': 1200, 'learn_rate': 0.00025, 'momentum': 0}
# -0.000001 (0.000001) with: {'activation': 'linear', 'batch_size': 15, 'epochs': 1200, 'learn_rate': 0.00025, 'momentum': 1e-05}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 15, 'epochs': 1300, 'learn_rate': 0.00015, 'momentum': 0}
# -0.000001 (0.000000) with: {'activation': 'linear', 'batch_size': 15, 'epochs': 1300, 'learn_rate': 0.00015, 'momentum': 1e-05}
# -0.000001 (0.000000) with: {'activation': 'linear', 'batch_size': 15, 'epochs': 1300, 'learn_rate': 0.0002, 'momentum': 0}
# -0.000001 (0.000000) with: {'activation': 'linear', 'batch_size': 15, 'epochs': 1300, 'learn_rate': 0.0002, 'momentum': 1e-05}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 15, 'epochs': 1300, 'learn_rate': 0.00025, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 15, 'epochs': 1300, 'learn_rate': 0.00025, 'momentum': 1e-05}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 20, 'epochs': 1000, 'learn_rate': 0.00015, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 20, 'epochs': 1000, 'learn_rate': 0.00015, 'momentum': 1e-05}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 20, 'epochs': 1000, 'learn_rate': 0.0002, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 20, 'epochs': 1000, 'learn_rate': 0.0002, 'momentum': 1e-05}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 20, 'epochs': 1000, 'learn_rate': 0.00025, 'momentum': 0}
# -0.000001 (0.000001) with: {'activation': 'linear', 'batch_size': 20, 'epochs': 1000, 'learn_rate': 0.00025, 'momentum': 1e-05}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 20, 'epochs': 1200, 'learn_rate': 0.00015, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 20, 'epochs': 1200, 'learn_rate': 0.00015, 'momentum': 1e-05}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 20, 'epochs': 1200, 'learn_rate': 0.0002, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 20, 'epochs': 1200, 'learn_rate': 0.0002, 'momentum': 1e-05}
# -0.000001 (0.000001) with: {'activation': 'linear', 'batch_size': 20, 'epochs': 1200, 'learn_rate': 0.00025, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 20, 'epochs': 1200, 'learn_rate': 0.00025, 'momentum': 1e-05}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 20, 'epochs': 1300, 'learn_rate': 0.00015, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 20, 'epochs': 1300, 'learn_rate': 0.00015, 'momentum': 1e-05}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 20, 'epochs': 1300, 'learn_rate': 0.0002, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 20, 'epochs': 1300, 'learn_rate': 0.0002, 'momentum': 1e-05}
# -0.000001 (0.000001) with: {'activation': 'linear', 'batch_size': 20, 'epochs': 1300, 'learn_rate': 0.00025, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 20, 'epochs': 1300, 'learn_rate': 0.00025, 'momentum': 1e-05}
# Wall time: 16min 1s

# %%
stop
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-4f76a9dad686> in <module>
# ----> 1 stop
#
# NameError: name 'stop' is not defined

# %% [markdown]
# ## Модель 1

# %%
def create_model():

    # create model
    model = Sequential()
    model.add(Dense(4, input_dim=4, activation='linear'))
    model.add(Dense(1, kernel_initializer='normal'))

    optimizer = tf.keras.optimizers.RMSprop(learning_rate = 0.00015, rho = 0.99, momentum = 0, epsilon=1e-09)
    
    # Compile model
    model.compile(loss='mse', optimizer=optimizer)
    return model

# %%
model = create_model()
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 4)                 20
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 25
# Trainable params: 25
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Обучение модели

EPOCHS = 1000
batch_size = 10

history = model.fit(
  X, Y,
  epochs=EPOCHS, batch_size = batch_size,verbose=0)

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail(10)
# Out:
#              loss  epoch
# 990  2.113076e-07    990
# 991  2.056237e-07    991
# 992  2.916639e-07    992
# 993  4.732588e-07    993
# 994  1.458580e-07    994
# 995  2.583893e-07    995
# 996  1.628077e-07    996
# 997  1.688799e-07    997
# 998  5.199726e-07    998
# 999  1.483384e-07    999

# %%
import statsmodels as statsmodels
import statsmodels.api as sm

RMSPE = statsmodels.tools.eval_measures.rmspe(y_test.values, model.predict(X_test))
RMSPE
# Out:
# array([0.00667847])

# %%
import statsmodels as statsmodels
import statsmodels.api as sm

RMSPE = statsmodels.tools.eval_measures.rmspe(y_train.values, model.predict(X_train))
RMSPE
# Out:
# array([0.00734339])
