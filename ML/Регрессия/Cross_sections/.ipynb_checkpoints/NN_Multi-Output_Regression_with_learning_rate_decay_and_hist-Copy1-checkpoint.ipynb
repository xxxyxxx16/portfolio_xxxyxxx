# %%
#загрузка данных
import pandas as pd

df = pd.read_excel('Input/Data.xlsx')
display(df.head(3))
display(df.describe())
# Out:
#    \rho(g/cm^3)  T_c(K)  T_f(K)  c_b(ppm)  3S_{tr1}(1)  3S_{tr2}(2)  \
# 0        0.7235   575.0  1027.0     600.0     0.661853     2.568298
# 1        0.7750   448.0  1043.0    1500.0     0.679602     2.874687
# 2        0.9125   370.5  1418.0     750.0     0.727336     3.668742
#
#    \Sigma_{a1}(3)  \Sigma_{a2}(4)  nuS_{f1}(5)  nuS_{f2}(6)  \Sigma_{f1}(7)  \
# 0        0.009376        0.085584     0.006677     0.133250        0.002620
# 1        0.009581        0.098339     0.006723     0.139256        0.002636
# 2        0.009908        0.102815     0.006844     0.153823        0.002681
#
#    \Sigma_{f2}(8)  \Sigma_{1->2}(9)  k_{inf}(10)  \sigma_{a2}^{Xe}  \
# 0        0.054750          0.017392     1.261041         1072970.0
# 1        0.057218          0.018726     1.174265         1141000.0
# 2        0.063203          0.022463     1.249619         1308480.0
#
#    \sigma_{a2}^{Sm}
# 0         35421.398
# 1         36147.801
# 2         39214.000
#        \rho(g/cm^3)      T_c(K)       T_f(K)     c_b(ppm)  3S_{tr1}(1)  \
# count    257.000000  257.000000   257.000000   257.000000   257.000000
# mean       0.773742  448.491808  1043.838306  1493.967349     0.679230
# std        0.158780   89.316810   430.718000   863.720860     0.053920
# min        0.502148  294.210910   298.859410    11.718750     0.586982
# 25%        0.637500  371.710910   673.859380   750.000000     0.631098
# 50%        0.772852  448.000000  1043.000000  1488.281000     0.678348
# 75%        0.910352  525.500000  1412.141000  2238.281000     0.725984
# max        1.047852  601.789120  1787.141000  2988.281000     0.774060
#
#        3S_{tr2}(2)  \Sigma_{a1}(3)  \Sigma_{a2}(4)  nuS_{f1}(5)  nuS_{f2}(6)  \
# count   257.000000      257.000000      257.000000   257.000000   257.000000
# mean      2.879487        0.009514        0.097856     0.006698     0.138663
# std       0.790229        0.000402        0.011233     0.000158     0.009800
# min       1.505131        0.008622        0.076091     0.006372     0.117360
# 25%       2.204620        0.009225        0.089572     0.006571     0.131596
# 50%       2.874687        0.009518        0.097073     0.006716     0.138722
# 75%       3.566347        0.009804        0.105296     0.006834     0.144896
# max       4.406140        0.010476        0.130769     0.006941     0.165624
#
#        \Sigma_{f1}(7)  \Sigma_{f2}(8)  \Sigma_{1->2}(9)  k_{inf}(10)  \
# count      257.000000      257.000000        257.000000   257.000000
# mean         0.002627        0.056974          0.018717     1.177139
# std          0.000058        0.004026          0.004395     0.086005
# min          0.002506        0.048221          0.011126     1.005264
# 25%          0.002581        0.054070          0.014993     1.106373
# 50%          0.002634        0.056998          0.018734     1.172133
# 75%          0.002677        0.059535          0.022463     1.245992
# max          0.002716        0.068052          0.026528     1.384922
#
#        \sigma_{a2}^{Xe}  \sigma_{a2}^{Sm}
# count      2.570000e+02        257.000000
# mean       1.124386e+06      35423.659751
# std        1.195160e+05       2841.132233
# min        8.587990e+05      29207.199000
# 25%        1.034060e+06      33246.301000
# 50%        1.124950e+06      35566.801000
# 75%        1.204050e+06      37580.500000
# max        1.427190e+06      41929.301000

# %%
# отнормируем все на max
from sklearn.preprocessing import MaxAbsScaler
transformer = MaxAbsScaler().fit(df)

df_norm = pd.DataFrame(data=transformer.transform(df), columns=list(df))
display(df_norm.head(3))
display(df_norm.describe())
# Out:
#    \rho(g/cm^3)    T_c(K)    T_f(K)  c_b(ppm)  3S_{tr1}(1)  3S_{tr2}(2)  \
# 0      0.690460  0.955484  0.574661  0.200784     0.855041     0.582891
# 1      0.739608  0.744447  0.583614  0.501961     0.877971     0.652427
# 2      0.870829  0.615664  0.793446  0.250980     0.939638     0.832643
#
#    \Sigma_{a1}(3)  \Sigma_{a2}(4)  nuS_{f1}(5)  nuS_{f2}(6)  \Sigma_{f1}(7)  \
# 0        0.894982        0.654467     0.961967     0.804532        0.964537
# 1        0.914623        0.752004     0.968602     0.840795        0.970656
# 2        0.945764        0.786234     0.986026     0.928747        0.986937
#
#    \Sigma_{f2}(8)  \Sigma_{1->2}(9)  k_{inf}(10)  \sigma_{a2}^{Xe}  \
# 0        0.804532          0.655592     0.910550          0.751806
# 1        0.840798          0.705893     0.847893          0.799473
# 2        0.928747          0.846762     0.902303          0.916823
#
#    \sigma_{a2}^{Sm}
# 0          0.844789
# 1          0.862113
# 2          0.935241
#        \rho(g/cm^3)      T_c(K)      T_f(K)    c_b(ppm)  3S_{tr1}(1)  \
# count    257.000000  257.000000  257.000000  257.000000   257.000000
# mean       0.738408    0.745264    0.584083    0.499942     0.877491
# std        0.151529    0.148419    0.241010    0.289036     0.069658
# min        0.479217    0.488894    0.167228    0.003922     0.758316
# 25%        0.608387    0.617676    0.377060    0.250980     0.815309
# 50%        0.737558    0.744447    0.583614    0.498039     0.876351
# 75%        0.868779    0.873229    0.790168    0.749020     0.937892
# max        1.000000    1.000000    1.000000    1.000000     1.000000
#
#        3S_{tr2}(2)  \Sigma_{a1}(3)  \Sigma_{a2}(4)  nuS_{f1}(5)  nuS_{f2}(6)  \
# count   257.000000      257.000000      257.000000   257.000000   257.000000
# mean      0.653517        0.908172        0.748311     0.964957     0.837214
# std       0.179347        0.038362        0.085899     0.022780     0.059168
# min       0.341598        0.823034        0.581877     0.918092     0.708590
# 25%       0.500352        0.880554        0.684965     0.946781     0.794547
# 50%       0.652427        0.908590        0.742327     0.967559     0.837570
# 75%       0.809404        0.935909        0.805206     0.984651     0.874847
# max       1.000000        1.000000        1.000000     1.000000     1.000000
#
#        \Sigma_{f1}(7)  \Sigma_{f2}(8)  \Sigma_{1->2}(9)  k_{inf}(10)  \
# count      257.000000      257.000000        257.000000   257.000000
# mean         0.967103        0.837214          0.705550     0.849968
# std          0.021385        0.059168          0.165667     0.062101
# min          0.922562        0.708590          0.419397     0.725864
# 25%          0.950142        0.794547          0.565171     0.798871
# 50%          0.969600        0.837570          0.706195     0.846353
# 75%          0.985457        0.874847          0.846762     0.899684
# max          1.000000        1.000000          1.000000     1.000000
#
#        \sigma_{a2}^{Xe}  \sigma_{a2}^{Sm}
# count        257.000000        257.000000
# mean           0.787832          0.844843
# std            0.083742          0.067760
# min            0.601741          0.696582
# 25%            0.724543          0.792913
# 50%            0.788227          0.848256
# 75%            0.843651          0.896283
# max            1.000000          1.000000

# %%
df_norm['3S_{tr1}(1)'] = df_norm['3S_{tr1}(1)']*0.1
df_norm['\Sigma_{a1}(3)'] = df_norm['\Sigma_{a1}(3)']*0.1
df_norm['nuS_{f1}(5)'] = df_norm['nuS_{f1}(5)']*0.1
df_norm['\Sigma_{f1}(7)'] = df_norm['\Sigma_{f1}(7)']*0.1

# %%
df_norm['\Sigma_{a2}(4)'] = df_norm['\Sigma_{a2}(4)']*1
df_norm['k_{inf}(10)'] = df_norm['k_{inf}(10)']*1
df_norm['\sigma_{a2}^{Xe}'] = df_norm['\sigma_{a2}^{Xe}']*1
df_norm['\sigma_{a2}^{Sm}'] = df_norm['\sigma_{a2}^{Sm}']*2

# %%
display(df_norm.describe())
# Out:
#        \rho(g/cm^3)      T_c(K)      T_f(K)    c_b(ppm)  3S_{tr1}(1)  \
# count    257.000000  257.000000  257.000000  257.000000   257.000000
# mean       0.738408    0.745264    0.584083    0.499942     0.087749
# std        0.151529    0.148419    0.241010    0.289036     0.006966
# min        0.479217    0.488894    0.167228    0.003922     0.075832
# 25%        0.608387    0.617676    0.377060    0.250980     0.081531
# 50%        0.737558    0.744447    0.583614    0.498039     0.087635
# 75%        0.868779    0.873229    0.790168    0.749020     0.093789
# max        1.000000    1.000000    1.000000    1.000000     0.100000
#
#        3S_{tr2}(2)  \Sigma_{a1}(3)  \Sigma_{a2}(4)  nuS_{f1}(5)  nuS_{f2}(6)  \
# count   257.000000      257.000000      257.000000   257.000000   257.000000
# mean      0.653517        0.090817        0.748311     0.096496     0.837214
# std       0.179347        0.003836        0.085899     0.002278     0.059168
# min       0.341598        0.082303        0.581877     0.091809     0.708590
# 25%       0.500352        0.088055        0.684965     0.094678     0.794547
# 50%       0.652427        0.090859        0.742327     0.096756     0.837570
# 75%       0.809404        0.093591        0.805206     0.098465     0.874847
# max       1.000000        0.100000        1.000000     0.100000     1.000000
#
#        \Sigma_{f1}(7)  \Sigma_{f2}(8)  \Sigma_{1->2}(9)  k_{inf}(10)  \
# count      257.000000      257.000000        257.000000   257.000000
# mean         0.096710        0.837214          0.705550     0.849968
# std          0.002139        0.059168          0.165667     0.062101
# min          0.092256        0.708590          0.419397     0.725864
# 25%          0.095014        0.794547          0.565171     0.798871
# 50%          0.096960        0.837570          0.706195     0.846353
# 75%          0.098546        0.874847          0.846762     0.899684
# max          0.100000        1.000000          1.000000     1.000000
#
#        \sigma_{a2}^{Xe}  \sigma_{a2}^{Sm}
# count        257.000000        257.000000
# mean           0.787832          1.689685
# std            0.083742          0.135520
# min            0.601741          1.393164
# 25%            0.724543          1.585827
# 50%            0.788227          1.696513
# 75%            0.843651          1.792565
# max            1.000000          2.000000

# %%
#разделим переменные на features и target
features = ['\\rho(g/cm^3)',
 'T_c(K)',
 'T_f(K)',
 'c_b(ppm)']

target = ['3S_{tr1}(1)',
 '3S_{tr2}(2)',
 '\\Sigma_{a1}(3)',
 '\\Sigma_{a2}(4)',
 'nuS_{f1}(5)',
 'nuS_{f2}(6)',
 '\\Sigma_{f1}(7)',
 '\\Sigma_{f2}(8)',
 '\\Sigma_{1->2}(9)',
 'k_{inf}(10)',
 '\\sigma_{a2}^{Xe}',
 '\\sigma_{a2}^{Sm}']

# %%
#перемешаем df
df_norm = df_norm.sample(frac=1, random_state=42)

# %%
#создание нейронной сети

import numpy
from sklearn.model_selection import GridSearchCV
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
import tensorflow as tf

def create_model():

    # create model
    model = Sequential()
    model.add(Dense(15, input_dim=4, activation='tanh'))
    model.add(Dense(13, activation='tanh'))
    model.add(Dense(12, kernel_initializer='normal'))
    
    lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.9,
    decay_steps=2500,
    decay_rate=0.95)
    
    optimizer = tf.keras.optimizers.SGD(learning_rate = lr_schedule, momentum = 0.75)
    
   
    # Compile model
    model.compile(loss='mse', optimizer=optimizer)
    return model

model = create_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 15)                75
# _________________________________________________________________
# dense_1 (Dense)              (None, 13)                208
# _________________________________________________________________
# dense_2 (Dense)              (None, 12)                168
# =================================================================
# Total params: 451
# Trainable params: 451
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Обучение модели

EPOCHS = 8000
batch_size = 20

history = model.fit(df_norm[features], df_norm[target], validation_split=0.3, epochs=EPOCHS, batch_size = batch_size,verbose=0)

hist = pd.DataFrame(history.history)
display(hist)
# Out:
#           loss  val_loss
# 0     0.136954  0.019871
# 1     0.011362  0.005875
# 2     0.005347  0.003954
# 3     0.003789  0.003778
# 4     0.003133  0.002390
# ...        ...       ...
# 7995  0.000003  0.000003
# 7996  0.000003  0.000003
# 7997  0.000003  0.000003
# 7998  0.000003  0.000003
# 7999  0.000003  0.000003
#
# [8000 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
# summarize history for loss
axes = plt.gca()
axes.set_xlim([EPOCHS*0.8,EPOCHS])
axes.set_ylim([hist['val_loss'].min()*0.9,hist['val_loss'].min()*2])
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
import statsmodels as statsmodels
import statsmodels.api as sm

# тестовые значения целевых функций
df_y_test_real = pd.DataFrame(data=df_norm[target].tail(78).values, columns=target)

# предсказанные значения на тестовой выборке
df_y_test_predict = pd.DataFrame(data=model.predict(df_norm[features].tail(78).values), columns=target)

RMSPE = statsmodels.tools.eval_measures.rmspe(df_y_test_real, df_y_test_predict)
RMSPE
# Out:
# array([0.02443711, 0.03789754, 0.03310192, 0.02675032, 0.02542329,
#        0.01441948, 0.02164558, 0.01512409, 0.02704228, 0.02185049,
#        0.02055558, 0.02340962])

# %%
pd.DataFrame(data=RMSPE, index = [target], columns = ['RMSPE'])
# Out:
#                      RMSPE
# 3S_{tr1}(1)       0.024437
# 3S_{tr2}(2)       0.037898
# \Sigma_{a1}(3)    0.033102
# \Sigma_{a2}(4)    0.026750
# nuS_{f1}(5)       0.025423
# nuS_{f2}(6)       0.014419
# \Sigma_{f1}(7)    0.021646
# \Sigma_{f2}(8)    0.015124
# \Sigma_{1->2}(9)  0.027042
# k_{inf}(10)       0.021850
# \sigma_{a2}^{Xe}  0.020556
# \sigma_{a2}^{Sm}  0.023410

# %%
X_test_time = df_norm[features].sample(n=1_000_000, replace=True)

# %%
X_test_time = X_test_time.to_numpy()

# %%
# %%time

model(X_test_time)
# Out:
# Wall time: 22 ms
# <tf.Tensor: shape=(1000000, 12), dtype=float32, numpy=
# array([[0.08543808, 0.583167  , 0.09054387, ..., 0.9240812 , 0.75824445,
#         1.7016225 ],
#        [0.08896583, 0.6802422 , 0.09431218, ..., 0.7723167 , 0.80045295,
#         1.6421909 ],
#        [0.08942571, 0.673798  , 0.0943758 , ..., 0.8017622 , 0.7421551 ,
#         1.6671753 ],
#        ...,
#        [0.0966943 , 0.87813336, 0.09142829, ..., 0.8620875 , 0.8612757 ,
#         1.855479  ],
#        [0.07679715, 0.379368  , 0.086561  , ..., 0.8248458 , 0.68135303,
#         1.476933  ],
#        [0.09639532, 0.846128  , 0.09743642, ..., 0.82572246, 0.7900728 ,
#         1.7740324 ]], dtype=float32)>
