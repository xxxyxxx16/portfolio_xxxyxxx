# %% [markdown]
# # Sigma_{1->2} в зависимости от плотности теплоносителя, температуры теплоносителя, температуры топлива и концентрации борной кислоты

# %% [markdown]
# ## 1. Загрузка данных

# %%
import pandas as pd

# %% [markdown]
# Загрузка данных

# %%
df = pd.read_excel('Input/Data.xlsx')
df.head(3)
# Out:
#    \rho(g/cm^3)  T_c(K)  T_f(K)  c_b(ppm)  3S_{tr1}(1)  3S_{tr2}(2)  \
# 0        0.7235   575.0  1027.0     600.0     0.661853     2.568298
# 1        0.7750   448.0  1043.0    1500.0     0.679602     2.874687
# 2        0.9125   370.5  1418.0     750.0     0.727336     3.668742
#
#    \Sigma_{a1}(3)  \Sigma_{a2}(4)  nuS_{f1}(5)  nuS_{f2}(6)  \Sigma_{f1}(7)  \
# 0        0.009376        0.085584     0.006677     0.133250        0.002620
# 1        0.009581        0.098339     0.006723     0.139256        0.002636
# 2        0.009908        0.102815     0.006844     0.153823        0.002681
#
#    \Sigma_{f2}(8)  \Sigma_{1->2}(9)  k_{inf}(10)  \sigma_{a2}^{Xe}  \
# 0        0.054750          0.017392     1.261041         1072970.0
# 1        0.057218          0.018726     1.174265         1141000.0
# 2        0.063203          0.022463     1.249619         1308480.0
#
#    \sigma_{a2}^{Sm}
# 0         35421.398
# 1         36147.801
# 2         39214.000

# %%
names = ['\\rho(g/cm^3)',
 'T_c(K)',
 'T_f(K)',
 'c_b(ppm)',
 '\Sigma_{1->2}(9)']

# %%
df = df[names]
df.head(3)
# Out:
#    \rho(g/cm^3)  T_c(K)  T_f(K)  c_b(ppm)  \Sigma_{1->2}(9)
# 0        0.7235   575.0  1027.0     600.0          0.017392
# 1        0.7750   448.0  1043.0    1500.0          0.018726
# 2        0.9125   370.5  1418.0     750.0          0.022463

# %% [markdown]
# ### 2 Нормализация признаков

# %%
features = ['\\rho(g/cm^3)',
 'T_c(K)',
 'T_f(K)',
 'c_b(ppm)']

# %%
df_features_norm = df.copy()

# %%
for i in range(len(features)):
    df_features_norm[features[i]] = (df[features[i]]-df[features[i]].mean())/df[features[i]].std()

# %%
df_features_norm
# Out:
#      \rho(g/cm^3)    T_c(K)    T_f(K)  c_b(ppm)  \Sigma_{1->2}(9)
# 0       -0.316426  1.416398 -0.039094 -1.035019          0.017392
# 1        0.007922 -0.005506 -0.001946  0.006984          0.018726
# 2        0.873902 -0.873204  0.868693 -0.861352          0.022463
# 3       -0.858058  0.862191 -0.872586  0.875321          0.015029
# 4       -0.425067 -0.439355  0.433373 -1.295520          0.016851
# ..            ...       ...       ...       ...               ...
# 252     -0.844527 -0.886762 -1.539169 -0.603564          0.015344
# 253      0.887433  0.848634  0.202111  1.133108          0.022440
# 254      0.021453 -0.019064  1.072750 -1.471900          0.018734
# 255     -1.710507  1.716332 -0.668529  0.264771          0.011311
# 256     -1.703741 -0.012286  0.535401 -0.746026          0.011207
#
# [257 rows x 5 columns]

# %%
df_features_norm.sample(frac=1)
# Out:
#      \rho(g/cm^3)    T_c(K)    T_f(K)  c_b(ppm)  \Sigma_{1->2}(9)
# 192     -1.656383 -1.049455  0.800674 -0.874919          0.011380
# 66       0.955088 -1.225707  0.678241  0.196932          0.022742
# 256     -1.703741 -0.012286  0.535401 -0.746026          0.011207
# 185      0.535629  0.767286 -0.478077 -0.902055          0.021223
# 33       0.170293  0.916423 -1.362320 -1.458333          0.019868
# ..            ...       ...       ...       ...               ...
# 202      1.591040 -1.266380 -1.158264  1.078837          0.025809
# 171     -0.005609  0.008051 -0.804567 -1.444765          0.018945
# 76      -0.560377 -0.574933  0.025262 -0.454320          0.016261
# 7       -1.291047  0.428343  1.304013  1.309489          0.012785
# 190      0.102639 -1.401958  0.827882  1.268786          0.018891
#
# [257 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df_features_norm[['\\rho(g/cm^3)', 'T_c(K)', 'T_f(K)', 'c_b(ppm)']],
                                                    df_features_norm[['\Sigma_{1->2}(9)']],
                                                    test_size=0.33,
                                                    random_state=42)

# %% [markdown]
# # Нейросетевые модели

# %%
# %%time

# Use scikit-learn to grid search the batch size and epochs
import numpy
from sklearn.model_selection import GridSearchCV
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor
import tensorflow as tf

# Function to create model, required for KerasRegressor
def create_model(activation='relu', learn_rate=0.01, momentum=0):
    # create model
    model = Sequential()
    model.add(Dense(4, input_dim=4, activation=activation))
    model.add(Dense(1, kernel_initializer='normal'))
    
    optimizer = tf.keras.optimizers.RMSprop(learning_rate = learn_rate, rho = 0.99, momentum = momentum, epsilon=1e-10)
    
    # Compile model
    model.compile(loss='mse', optimizer=optimizer)
    return model

X = X_train
Y = y_train

# create model
model = KerasRegressor(build_fn=create_model, verbose=0)

# define the grid search parameters
batch_size = [10, 15, 20]
epochs = [1000, 1200, 1300]
activation = ['tanh', 'sigmoid', 'linear']
learn_rate = [0.00001, 0.00005, 0.00009]
momentum = [0]

param_grid = dict(batch_size=batch_size,
                  epochs=epochs,
                  activation=activation,
                  learn_rate=learn_rate,
                  momentum=momentum
                 )
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=5)
grid_result = grid.fit(X, Y)

# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: -0.000000 using {'activation': 'linear', 'batch_size': 10, 'epochs': 1300, 'learn_rate': 1e-05, 'momentum': 0}
# -0.000005 (0.000004) with: {'activation': 'tanh', 'batch_size': 10, 'epochs': 1000, 'learn_rate': 1e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'tanh', 'batch_size': 10, 'epochs': 1000, 'learn_rate': 5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'tanh', 'batch_size': 10, 'epochs': 1000, 'learn_rate': 9e-05, 'momentum': 0}
# -0.000001 (0.000000) with: {'activation': 'tanh', 'batch_size': 10, 'epochs': 1200, 'learn_rate': 1e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'tanh', 'batch_size': 10, 'epochs': 1200, 'learn_rate': 5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'tanh', 'batch_size': 10, 'epochs': 1200, 'learn_rate': 9e-05, 'momentum': 0}
# -0.000002 (0.000002) with: {'activation': 'tanh', 'batch_size': 10, 'epochs': 1300, 'learn_rate': 1e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'tanh', 'batch_size': 10, 'epochs': 1300, 'learn_rate': 5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'tanh', 'batch_size': 10, 'epochs': 1300, 'learn_rate': 9e-05, 'momentum': 0}
# -0.000002 (0.000001) with: {'activation': 'tanh', 'batch_size': 15, 'epochs': 1000, 'learn_rate': 1e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'tanh', 'batch_size': 15, 'epochs': 1000, 'learn_rate': 5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'tanh', 'batch_size': 15, 'epochs': 1000, 'learn_rate': 9e-05, 'momentum': 0}
# -0.000006 (0.000006) with: {'activation': 'tanh', 'batch_size': 15, 'epochs': 1200, 'learn_rate': 1e-05, 'momentum': 0}
# -0.000001 (0.000000) with: {'activation': 'tanh', 'batch_size': 15, 'epochs': 1200, 'learn_rate': 5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'tanh', 'batch_size': 15, 'epochs': 1200, 'learn_rate': 9e-05, 'momentum': 0}
# -0.000018 (0.000023) with: {'activation': 'tanh', 'batch_size': 15, 'epochs': 1300, 'learn_rate': 1e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'tanh', 'batch_size': 15, 'epochs': 1300, 'learn_rate': 5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'tanh', 'batch_size': 15, 'epochs': 1300, 'learn_rate': 9e-05, 'momentum': 0}
# -0.000078 (0.000040) with: {'activation': 'tanh', 'batch_size': 20, 'epochs': 1000, 'learn_rate': 1e-05, 'momentum': 0}
# -0.000001 (0.000000) with: {'activation': 'tanh', 'batch_size': 20, 'epochs': 1000, 'learn_rate': 5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'tanh', 'batch_size': 20, 'epochs': 1000, 'learn_rate': 9e-05, 'momentum': 0}
# -0.000009 (0.000010) with: {'activation': 'tanh', 'batch_size': 20, 'epochs': 1200, 'learn_rate': 1e-05, 'momentum': 0}
# -0.000001 (0.000000) with: {'activation': 'tanh', 'batch_size': 20, 'epochs': 1200, 'learn_rate': 5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'tanh', 'batch_size': 20, 'epochs': 1200, 'learn_rate': 9e-05, 'momentum': 0}
# -0.000012 (0.000021) with: {'activation': 'tanh', 'batch_size': 20, 'epochs': 1300, 'learn_rate': 1e-05, 'momentum': 0}
# -0.000001 (0.000001) with: {'activation': 'tanh', 'batch_size': 20, 'epochs': 1300, 'learn_rate': 5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'tanh', 'batch_size': 20, 'epochs': 1300, 'learn_rate': 9e-05, 'momentum': 0}
# -0.000002 (0.000002) with: {'activation': 'sigmoid', 'batch_size': 10, 'epochs': 1000, 'learn_rate': 1e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'sigmoid', 'batch_size': 10, 'epochs': 1000, 'learn_rate': 5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'sigmoid', 'batch_size': 10, 'epochs': 1000, 'learn_rate': 9e-05, 'momentum': 0}
# -0.000007 (0.000008) with: {'activation': 'sigmoid', 'batch_size': 10, 'epochs': 1200, 'learn_rate': 1e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'sigmoid', 'batch_size': 10, 'epochs': 1200, 'learn_rate': 5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'sigmoid', 'batch_size': 10, 'epochs': 1200, 'learn_rate': 9e-05, 'momentum': 0}
# -0.000002 (0.000001) with: {'activation': 'sigmoid', 'batch_size': 10, 'epochs': 1300, 'learn_rate': 1e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'sigmoid', 'batch_size': 10, 'epochs': 1300, 'learn_rate': 5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'sigmoid', 'batch_size': 10, 'epochs': 1300, 'learn_rate': 9e-05, 'momentum': 0}
# -0.000036 (0.000047) with: {'activation': 'sigmoid', 'batch_size': 15, 'epochs': 1000, 'learn_rate': 1e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'sigmoid', 'batch_size': 15, 'epochs': 1000, 'learn_rate': 5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'sigmoid', 'batch_size': 15, 'epochs': 1000, 'learn_rate': 9e-05, 'momentum': 0}
# -0.000002 (0.000002) with: {'activation': 'sigmoid', 'batch_size': 15, 'epochs': 1200, 'learn_rate': 1e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'sigmoid', 'batch_size': 15, 'epochs': 1200, 'learn_rate': 5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'sigmoid', 'batch_size': 15, 'epochs': 1200, 'learn_rate': 9e-05, 'momentum': 0}
# -0.000008 (0.000010) with: {'activation': 'sigmoid', 'batch_size': 15, 'epochs': 1300, 'learn_rate': 1e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'sigmoid', 'batch_size': 15, 'epochs': 1300, 'learn_rate': 5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'sigmoid', 'batch_size': 15, 'epochs': 1300, 'learn_rate': 9e-05, 'momentum': 0}
# -0.000012 (0.000019) with: {'activation': 'sigmoid', 'batch_size': 20, 'epochs': 1000, 'learn_rate': 1e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'sigmoid', 'batch_size': 20, 'epochs': 1000, 'learn_rate': 5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'sigmoid', 'batch_size': 20, 'epochs': 1000, 'learn_rate': 9e-05, 'momentum': 0}
# -0.000007 (0.000009) with: {'activation': 'sigmoid', 'batch_size': 20, 'epochs': 1200, 'learn_rate': 1e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'sigmoid', 'batch_size': 20, 'epochs': 1200, 'learn_rate': 5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'sigmoid', 'batch_size': 20, 'epochs': 1200, 'learn_rate': 9e-05, 'momentum': 0}
# -0.000013 (0.000012) with: {'activation': 'sigmoid', 'batch_size': 20, 'epochs': 1300, 'learn_rate': 1e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'sigmoid', 'batch_size': 20, 'epochs': 1300, 'learn_rate': 5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'sigmoid', 'batch_size': 20, 'epochs': 1300, 'learn_rate': 9e-05, 'momentum': 0}
# -0.000022 (0.000036) with: {'activation': 'linear', 'batch_size': 10, 'epochs': 1000, 'learn_rate': 1e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 10, 'epochs': 1000, 'learn_rate': 5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 10, 'epochs': 1000, 'learn_rate': 9e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 10, 'epochs': 1200, 'learn_rate': 1e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 10, 'epochs': 1200, 'learn_rate': 5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 10, 'epochs': 1200, 'learn_rate': 9e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 10, 'epochs': 1300, 'learn_rate': 1e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 10, 'epochs': 1300, 'learn_rate': 5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 10, 'epochs': 1300, 'learn_rate': 9e-05, 'momentum': 0}
# -0.000008 (0.000011) with: {'activation': 'linear', 'batch_size': 15, 'epochs': 1000, 'learn_rate': 1e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 15, 'epochs': 1000, 'learn_rate': 5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 15, 'epochs': 1000, 'learn_rate': 9e-05, 'momentum': 0}
# -0.000014 (0.000028) with: {'activation': 'linear', 'batch_size': 15, 'epochs': 1200, 'learn_rate': 1e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 15, 'epochs': 1200, 'learn_rate': 5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 15, 'epochs': 1200, 'learn_rate': 9e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 15, 'epochs': 1300, 'learn_rate': 1e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 15, 'epochs': 1300, 'learn_rate': 5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 15, 'epochs': 1300, 'learn_rate': 9e-05, 'momentum': 0}
# -0.000091 (0.000101) with: {'activation': 'linear', 'batch_size': 20, 'epochs': 1000, 'learn_rate': 1e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 20, 'epochs': 1000, 'learn_rate': 5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 20, 'epochs': 1000, 'learn_rate': 9e-05, 'momentum': 0}
# -0.000049 (0.000061) with: {'activation': 'linear', 'batch_size': 20, 'epochs': 1200, 'learn_rate': 1e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 20, 'epochs': 1200, 'learn_rate': 5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 20, 'epochs': 1200, 'learn_rate': 9e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 20, 'epochs': 1300, 'learn_rate': 1e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 20, 'epochs': 1300, 'learn_rate': 5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 20, 'epochs': 1300, 'learn_rate': 9e-05, 'momentum': 0}
# Wall time: 7min 54s

# %%
.000000 using {'activation': 'linear', 'batch_size': 10, 'epochs': 1300, 'learn_rate': 1e-05, 'momentum': 0}
# Out:
#   File "<ipython-input-12-c278b2b7b51f>", line 1
#     -0.000000 using {'activation': 'linear', 'batch_size': 10, 'epochs': 1200, 'learn_rate': 1e-05, 'momentum': 0}
#               ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Модель 1

# %%
def create_model():

    # create model
    model = Sequential()
    model.add(Dense(4, input_dim=4, activation='linear'))
    model.add(Dense(1, kernel_initializer='normal'))

    optimizer = tf.keras.optimizers.RMSprop(learning_rate = 1e-05, rho = 0.99, momentum = 0, epsilon=1e-10)
    
    # Compile model
    model.compile(loss='mse', optimizer=optimizer)
    return model

# %%
model = create_model()
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 4)                 20
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 25
# Trainable params: 25
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Обучение модели

EPOCHS = 1300
batch_size = 10

history = model.fit(
  X, Y,
  epochs=EPOCHS, batch_size = batch_size,verbose=0)

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail(10)
# Out:
#               loss  epoch
# 1290  1.401195e-09   1290
# 1291  1.659193e-09   1291
# 1292  1.198149e-09   1292
# 1293  1.278925e-09   1293
# 1294  1.697241e-09   1294
# 1295  1.398832e-09   1295
# 1296  1.258775e-09   1296
# 1297  1.234071e-09   1297
# 1298  1.244645e-09   1298
# 1299  1.241448e-09   1299

# %%
import statsmodels as statsmodels
import statsmodels.api as sm

RMSPE = statsmodels.tools.eval_measures.rmspe(y_test.values, model.predict(X_test))
RMSPE
# Out:
# array([0.02420409])

# %%
import statsmodels as statsmodels
import statsmodels.api as sm

RMSPE = statsmodels.tools.eval_measures.rmspe(y_train.values, model.predict(X_train))
RMSPE
# Out:
# array([0.02228184])
