# %% [markdown]
# # nuS_{f1} в зависимости от плотности теплоносителя, температуры теплоносителя, температуры топлива и концентрации борной кислоты

# %% [markdown]
# ## 1. Загрузка данных

# %%
import pandas as pd

# %% [markdown]
# Загрузка данных

# %%
df = pd.read_excel('Input/Data.xlsx')
df.head(3)
# Out:
#    \rho(g/cm^3)  T_c(K)  T_f(K)  c_b(ppm)  3S_{tr1}(1)  3S_{tr2}(2)  \
# 0        0.7235   575.0  1027.0     600.0     0.661853     2.568298
# 1        0.7750   448.0  1043.0    1500.0     0.679602     2.874687
# 2        0.9125   370.5  1418.0     750.0     0.727336     3.668742
#
#    \Sigma_{a1}(3)  \Sigma_{a2}(4)  nuS_{f1}(5)  nuS_{f2}(6)  \Sigma_{f1}(7)  \
# 0        0.009376        0.085584     0.006677     0.133250        0.002620
# 1        0.009581        0.098339     0.006723     0.139256        0.002636
# 2        0.009908        0.102815     0.006844     0.153823        0.002681
#
#    \Sigma_{f2}(8)  \Sigma_{1->2}(9)  k_{inf}(10)  \sigma_{a2}^{Xe}  \
# 0        0.054750          0.017392     1.261041         1072970.0
# 1        0.057218          0.018726     1.174265         1141000.0
# 2        0.063203          0.022463     1.249619         1308480.0
#
#    \sigma_{a2}^{Sm}
# 0         35421.398
# 1         36147.801
# 2         39214.000

# %%
names = ['\\rho(g/cm^3)',
 'T_c(K)',
 'T_f(K)',
 'c_b(ppm)',
 'nuS_{f1}(5)']

# %%
df = df[names]
df.head(3)
# Out:
#    \rho(g/cm^3)  T_c(K)  T_f(K)  c_b(ppm)  nuS_{f1}(5)
# 0        0.7235   575.0  1027.0     600.0     0.006677
# 1        0.7750   448.0  1043.0    1500.0     0.006723
# 2        0.9125   370.5  1418.0     750.0     0.006844

# %% [markdown]
# ### 2 Нормализация признаков

# %%
features = ['\\rho(g/cm^3)',
 'T_c(K)',
 'T_f(K)',
 'c_b(ppm)']

# %%
df_features_norm = df.copy()

# %%
for i in range(len(features)):
    df_features_norm[features[i]] = (df[features[i]]-df[features[i]].mean())/df[features[i]].std()

# %%
df_features_norm
# Out:
#      \rho(g/cm^3)    T_c(K)    T_f(K)  c_b(ppm)  nuS_{f1}(5)
# 0       -0.316426  1.416398 -0.039094 -1.035019     0.006677
# 1        0.007922 -0.005506 -0.001946  0.006984     0.006723
# 2        0.873902 -0.873204  0.868693 -0.861352     0.006844
# 3       -0.858058  0.862191 -0.872586  0.875321     0.006571
# 4       -0.425067 -0.439355  0.433373 -1.295520     0.006659
# ..            ...       ...       ...       ...          ...
# 252     -0.844527 -0.886762 -1.539169 -0.603564     0.006578
# 253      0.887433  0.848634  0.202111  1.133108     0.006834
# 254      0.021453 -0.019064  1.072750 -1.471900     0.006730
# 255     -1.710507  1.716332 -0.668529  0.264771     0.006381
# 256     -1.703741 -0.012286  0.535401 -0.746026     0.006381
#
# [257 rows x 5 columns]

# %%
df_features_norm.sample(frac=1)
# Out:
#      \rho(g/cm^3)    T_c(K)    T_f(K)  c_b(ppm)  nuS_{f1}(5)
# 251     -0.411537  0.414785  1.508070  0.698940     0.006646
# 236     -0.519784 -0.778299  1.181580 -0.929190     0.006638
# 133      1.347485  0.713056  1.426445 -0.630700     0.006895
# 137      0.698000  0.062283 -1.403131  0.888889     0.006804
# 72      -0.993367 -1.008782 -1.280698 -0.020152     0.006548
# ..            ...       ...       ...       ...          ...
# 82       1.279830 -0.466471 -0.301228  1.390895     0.006879
# 227     -0.736279  0.740172 -0.342040 -0.277939     0.006600
# 170      1.726354 -1.727344  0.936712  0.291908     0.006933
# 94       0.197355 -0.249547  0.351751 -0.128694     0.006751
# 153      0.589753  1.689216  0.882296  0.563263     0.006799
#
# [257 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df_features_norm[['\\rho(g/cm^3)', 'T_c(K)', 'T_f(K)', 'c_b(ppm)']],
                                                    df_features_norm[['nuS_{f1}(5)']],
                                                    test_size=0.33,
                                                    random_state=42)

# %% [markdown]
# # Нейросетевые модели

# %%
# %%time

# Use scikit-learn to grid search the batch size and epochs
import numpy
from sklearn.model_selection import GridSearchCV
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor
import tensorflow as tf

# Function to create model, required for KerasRegressor
def create_model(activation='relu', learn_rate=0.01, momentum=0):
    # create model
    model = Sequential()
    model.add(Dense(4, input_dim=4, activation=activation))
    model.add(Dense(1, kernel_initializer='normal'))
    
    optimizer = tf.keras.optimizers.RMSprop(learning_rate = learn_rate, rho = 0.99, momentum = momentum, epsilon=1e-10)
    
    # Compile model
    model.compile(loss='mse', optimizer=optimizer)
    return model

X = X_train
Y = y_train

# create model
model = KerasRegressor(build_fn=create_model, verbose=0)

# define the grid search parameters
batch_size = [10, 15, 20]
epochs = [1000, 1200, 1300]
activation = ['tanh', 'sigmoid', 'linear']
learn_rate = [0.000015, 0.00002, 0.000025]
momentum = [0]

param_grid = dict(batch_size=batch_size,
                  epochs=epochs,
                  activation=activation,
                  learn_rate=learn_rate,
                  momentum=momentum
                 )
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=5)
grid_result = grid.fit(X, Y)

# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: -0.000000 using {'activation': 'linear', 'batch_size': 10, 'epochs': 1000, 'learn_rate': 1.5e-05, 'momentum': 0}
# -0.000002 (0.000003) with: {'activation': 'tanh', 'batch_size': 10, 'epochs': 1000, 'learn_rate': 1.5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'tanh', 'batch_size': 10, 'epochs': 1000, 'learn_rate': 2e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'tanh', 'batch_size': 10, 'epochs': 1000, 'learn_rate': 2.5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'tanh', 'batch_size': 10, 'epochs': 1200, 'learn_rate': 1.5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'tanh', 'batch_size': 10, 'epochs': 1200, 'learn_rate': 2e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'tanh', 'batch_size': 10, 'epochs': 1200, 'learn_rate': 2.5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'tanh', 'batch_size': 10, 'epochs': 1300, 'learn_rate': 1.5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'tanh', 'batch_size': 10, 'epochs': 1300, 'learn_rate': 2e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'tanh', 'batch_size': 10, 'epochs': 1300, 'learn_rate': 2.5e-05, 'momentum': 0}
# -0.000003 (0.000006) with: {'activation': 'tanh', 'batch_size': 15, 'epochs': 1000, 'learn_rate': 1.5e-05, 'momentum': 0}
# -0.000000 (0.000001) with: {'activation': 'tanh', 'batch_size': 15, 'epochs': 1000, 'learn_rate': 2e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'tanh', 'batch_size': 15, 'epochs': 1000, 'learn_rate': 2.5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'tanh', 'batch_size': 15, 'epochs': 1200, 'learn_rate': 1.5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'tanh', 'batch_size': 15, 'epochs': 1200, 'learn_rate': 2e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'tanh', 'batch_size': 15, 'epochs': 1200, 'learn_rate': 2.5e-05, 'momentum': 0}
# -0.000001 (0.000001) with: {'activation': 'tanh', 'batch_size': 15, 'epochs': 1300, 'learn_rate': 1.5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'tanh', 'batch_size': 15, 'epochs': 1300, 'learn_rate': 2e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'tanh', 'batch_size': 15, 'epochs': 1300, 'learn_rate': 2.5e-05, 'momentum': 0}
# -0.000012 (0.000022) with: {'activation': 'tanh', 'batch_size': 20, 'epochs': 1000, 'learn_rate': 1.5e-05, 'momentum': 0}
# -0.000002 (0.000004) with: {'activation': 'tanh', 'batch_size': 20, 'epochs': 1000, 'learn_rate': 2e-05, 'momentum': 0}
# -0.000031 (0.000062) with: {'activation': 'tanh', 'batch_size': 20, 'epochs': 1000, 'learn_rate': 2.5e-05, 'momentum': 0}
# -0.000001 (0.000001) with: {'activation': 'tanh', 'batch_size': 20, 'epochs': 1200, 'learn_rate': 1.5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'tanh', 'batch_size': 20, 'epochs': 1200, 'learn_rate': 2e-05, 'momentum': 0}
# -0.000001 (0.000002) with: {'activation': 'tanh', 'batch_size': 20, 'epochs': 1200, 'learn_rate': 2.5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'tanh', 'batch_size': 20, 'epochs': 1300, 'learn_rate': 1.5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'tanh', 'batch_size': 20, 'epochs': 1300, 'learn_rate': 2e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'tanh', 'batch_size': 20, 'epochs': 1300, 'learn_rate': 2.5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'sigmoid', 'batch_size': 10, 'epochs': 1000, 'learn_rate': 1.5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'sigmoid', 'batch_size': 10, 'epochs': 1000, 'learn_rate': 2e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'sigmoid', 'batch_size': 10, 'epochs': 1000, 'learn_rate': 2.5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'sigmoid', 'batch_size': 10, 'epochs': 1200, 'learn_rate': 1.5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'sigmoid', 'batch_size': 10, 'epochs': 1200, 'learn_rate': 2e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'sigmoid', 'batch_size': 10, 'epochs': 1200, 'learn_rate': 2.5e-05, 'momentum': 0}
# -0.000000 (0.000001) with: {'activation': 'sigmoid', 'batch_size': 10, 'epochs': 1300, 'learn_rate': 1.5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'sigmoid', 'batch_size': 10, 'epochs': 1300, 'learn_rate': 2e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'sigmoid', 'batch_size': 10, 'epochs': 1300, 'learn_rate': 2.5e-05, 'momentum': 0}
# -0.000002 (0.000003) with: {'activation': 'sigmoid', 'batch_size': 15, 'epochs': 1000, 'learn_rate': 1.5e-05, 'momentum': 0}
# -0.000001 (0.000002) with: {'activation': 'sigmoid', 'batch_size': 15, 'epochs': 1000, 'learn_rate': 2e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'sigmoid', 'batch_size': 15, 'epochs': 1000, 'learn_rate': 2.5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'sigmoid', 'batch_size': 15, 'epochs': 1200, 'learn_rate': 1.5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'sigmoid', 'batch_size': 15, 'epochs': 1200, 'learn_rate': 2e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'sigmoid', 'batch_size': 15, 'epochs': 1200, 'learn_rate': 2.5e-05, 'momentum': 0}
# -0.000001 (0.000001) with: {'activation': 'sigmoid', 'batch_size': 15, 'epochs': 1300, 'learn_rate': 1.5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'sigmoid', 'batch_size': 15, 'epochs': 1300, 'learn_rate': 2e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'sigmoid', 'batch_size': 15, 'epochs': 1300, 'learn_rate': 2.5e-05, 'momentum': 0}
# -0.000003 (0.000003) with: {'activation': 'sigmoid', 'batch_size': 20, 'epochs': 1000, 'learn_rate': 1.5e-05, 'momentum': 0}
# -0.000001 (0.000001) with: {'activation': 'sigmoid', 'batch_size': 20, 'epochs': 1000, 'learn_rate': 2e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'sigmoid', 'batch_size': 20, 'epochs': 1000, 'learn_rate': 2.5e-05, 'momentum': 0}
# -0.000002 (0.000003) with: {'activation': 'sigmoid', 'batch_size': 20, 'epochs': 1200, 'learn_rate': 1.5e-05, 'momentum': 0}
# -0.000001 (0.000001) with: {'activation': 'sigmoid', 'batch_size': 20, 'epochs': 1200, 'learn_rate': 2e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'sigmoid', 'batch_size': 20, 'epochs': 1200, 'learn_rate': 2.5e-05, 'momentum': 0}
# -0.000013 (0.000024) with: {'activation': 'sigmoid', 'batch_size': 20, 'epochs': 1300, 'learn_rate': 1.5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'sigmoid', 'batch_size': 20, 'epochs': 1300, 'learn_rate': 2e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'sigmoid', 'batch_size': 20, 'epochs': 1300, 'learn_rate': 2.5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 10, 'epochs': 1000, 'learn_rate': 1.5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 10, 'epochs': 1000, 'learn_rate': 2e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 10, 'epochs': 1000, 'learn_rate': 2.5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 10, 'epochs': 1200, 'learn_rate': 1.5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 10, 'epochs': 1200, 'learn_rate': 2e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 10, 'epochs': 1200, 'learn_rate': 2.5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 10, 'epochs': 1300, 'learn_rate': 1.5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 10, 'epochs': 1300, 'learn_rate': 2e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 10, 'epochs': 1300, 'learn_rate': 2.5e-05, 'momentum': 0}
# -0.000023 (0.000028) with: {'activation': 'linear', 'batch_size': 15, 'epochs': 1000, 'learn_rate': 1.5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 15, 'epochs': 1000, 'learn_rate': 2e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 15, 'epochs': 1000, 'learn_rate': 2.5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 15, 'epochs': 1200, 'learn_rate': 1.5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 15, 'epochs': 1200, 'learn_rate': 2e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 15, 'epochs': 1200, 'learn_rate': 2.5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 15, 'epochs': 1300, 'learn_rate': 1.5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 15, 'epochs': 1300, 'learn_rate': 2e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 15, 'epochs': 1300, 'learn_rate': 2.5e-05, 'momentum': 0}
# -0.000001 (0.000001) with: {'activation': 'linear', 'batch_size': 20, 'epochs': 1000, 'learn_rate': 1.5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 20, 'epochs': 1000, 'learn_rate': 2e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 20, 'epochs': 1000, 'learn_rate': 2.5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 20, 'epochs': 1200, 'learn_rate': 1.5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 20, 'epochs': 1200, 'learn_rate': 2e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 20, 'epochs': 1200, 'learn_rate': 2.5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 20, 'epochs': 1300, 'learn_rate': 1.5e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 20, 'epochs': 1300, 'learn_rate': 2e-05, 'momentum': 0}
# -0.000000 (0.000000) with: {'activation': 'linear', 'batch_size': 20, 'epochs': 1300, 'learn_rate': 2.5e-05, 'momentum': 0}
# Wall time: 8min 4s

# %%
 -0.000000 using {'activation': 'linear', 'batch_size': 10, 'epochs': 1000, 'learn_rate': 1.5e-05, 'momentum': 0
# Out:
#   File "<ipython-input-12-a28ca92b18f9>", line 1
#     Best: -0.000000 using {'activation': 'tanh', 'batch_size': 10, 'epochs': 1200, 'learn_rate': 0.00015, 'momentum': 0}
#                     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Модель 1

# %%
def create_model():

    # create model
    model = Sequential()
    model.add(Dense(4, input_dim=4, activation='linear'))
    model.add(Dense(1, kernel_initializer='normal'))

    optimizer = tf.keras.optimizers.RMSprop(learning_rate = 0.000005, rho = 0.99, momentum = 0, epsilon=1e-10)
    
    # Compile model
    model.compile(loss='mse', optimizer=optimizer)
    return model

# %%
model = create_model()
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 4)                 20
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 25
# Trainable params: 25
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Обучение модели

EPOCHS = 1200
batch_size = 10

history = model.fit(
  X, Y,
  epochs=EPOCHS, batch_size = batch_size,verbose=0)

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail(10)
# Out:
#               loss  epoch
# 1190  4.635143e-10   1190
# 1191  7.368399e-10   1191
# 1192  5.016136e-10   1192
# 1193  4.429959e-10   1193
# 1194  4.436452e-10   1194
# 1195  5.327028e-10   1195
# 1196  5.135720e-10   1196
# 1197  8.025891e-10   1197
# 1198  4.831471e-10   1198
# 1199  5.081132e-10   1199

# %%
import statsmodels as statsmodels
import statsmodels.api as sm

RMSPE = statsmodels.tools.eval_measures.rmspe(y_test.values, model.predict(X_test))
RMSPE
# Out:
# array([0.03768423])

# %%
import statsmodels as statsmodels
import statsmodels.api as sm

RMSPE = statsmodels.tools.eval_measures.rmspe(y_train.values, model.predict(X_train))
RMSPE
# Out:
# array([0.03486159])
