# %% [markdown]
# # \sigma_{a2}^{Xe} в зависимости от плотности теплоносителя, температуры теплоносителя, температуры топлива и концентрации борной кислоты

# %% [markdown]
# ## 1. Загрузка данных

# %%
import pandas as pd

# %% [markdown]
# Загрузка данных

# %%
df = pd.read_excel('Input/Data.xlsx')
df.head(3)
# Out:
#    \rho(g/cm^3)  T_c(K)  T_f(K)  c_b(ppm)  3S_{tr1}(1)  3S_{tr2}(2)  \
# 0        0.7235   575.0  1027.0     600.0     0.661853     2.568298
# 1        0.7750   448.0  1043.0    1500.0     0.679602     2.874687
# 2        0.9125   370.5  1418.0     750.0     0.727336     3.668742
#
#    \Sigma_{a1}(3)  \Sigma_{a2}(4)  nuS_{f1}(5)  nuS_{f2}(6)  \Sigma_{f1}(7)  \
# 0        0.009376        0.085584     0.006677     0.133250        0.002620
# 1        0.009581        0.098339     0.006723     0.139256        0.002636
# 2        0.009908        0.102815     0.006844     0.153823        0.002681
#
#    \Sigma_{f2}(8)  \Sigma_{1->2}(9)  k_{inf}(10)  \sigma_{a2}^{Xe}  \
# 0        0.054750          0.017392     1.261041         1072970.0
# 1        0.057218          0.018726     1.174265         1141000.0
# 2        0.063203          0.022463     1.249619         1308480.0
#
#    \sigma_{a2}^{Sm}
# 0         35421.398
# 1         36147.801
# 2         39214.000

# %%
names = ['\\rho(g/cm^3)',
 'T_c(K)',
 'T_f(K)',
 'c_b(ppm)',
 '\sigma_{a2}^{Xe}']

# %%
df = df[names]
df.head(3)
# Out:
#    \rho(g/cm^3)  T_c(K)  T_f(K)  c_b(ppm)  \sigma_{a2}^{Xe}
# 0        0.7235   575.0  1027.0     600.0         1072970.0
# 1        0.7750   448.0  1043.0    1500.0         1141000.0
# 2        0.9125   370.5  1418.0     750.0         1308480.0

# %% [markdown]
# ### 2 Нормализация признаков

# %%
features = ['\\rho(g/cm^3)',
 'T_c(K)',
 'T_f(K)',
 'c_b(ppm)']

# %%
df_features_norm = df.copy()

# %%
for i in range(len(features)):
    df_features_norm[features[i]] = (df[features[i]]-df[features[i]].mean())/df[features[i]].std()

# %%
df_features_norm
# Out:
#      \rho(g/cm^3)    T_c(K)    T_f(K)  c_b(ppm)  \sigma_{a2}^{Xe}
# 0       -0.316426  1.416398 -0.039094 -1.035019         1072970.0
# 1        0.007922 -0.005506 -0.001946  0.006984         1141000.0
# 2        0.873902 -0.873204  0.868693 -0.861352         1308480.0
# 3       -0.858058  0.862191 -0.872586  0.875321          981375.0
# 4       -0.425067 -0.439355  0.433373 -1.295520         1177500.0
# ..            ...       ...       ...       ...               ...
# 252     -0.844527 -0.886762 -1.539169 -0.603564         1114270.0
# 253      0.887433  0.848634  0.202111  1.133108         1111390.0
# 254      0.021453 -0.019064  1.072750 -1.471900         1211840.0
# 255     -1.710507  1.716332 -0.668529  0.264771          861248.0
# 256     -1.703741 -0.012286  0.535401 -0.746026          957896.0
#
# [257 rows x 5 columns]

# %%
df_features_norm.sample(frac=1)
# Out:
#      \rho(g/cm^3)    T_c(K)    T_f(K)  c_b(ppm)  \sigma_{a2}^{Xe}
# 93       1.063335  0.618151  1.222391  0.739642         1151630.0
# 9        0.657407  1.079116  1.086353 -1.078436         1178170.0
# 170      1.726354 -1.727344  0.936712  0.291908         1331730.0
# 166      0.643876 -1.076571 -1.022227 -1.661849         1351170.0
# 250      1.320423 -1.320611 -0.233210 -1.037732         1380760.0
# ..            ...       ...       ...       ...               ...
# 223     -1.548135  0.794403  1.127164 -1.634713          975454.0
# 12      -0.641563 -1.090129  1.521672  0.224069         1102190.0
# 165      1.509853  1.526522 -0.151587  0.943160         1113720.0
# 225      0.129701  1.607870  0.528600 -1.146274         1103680.0
# 47      -1.345171  0.699499 -1.144660  0.929592          933335.0
#
# [257 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df_features_norm[['\\rho(g/cm^3)', 'T_c(K)', 'T_f(K)', 'c_b(ppm)']],
                                                    df_features_norm[['\sigma_{a2}^{Xe}']],
                                                    test_size=0.33,
                                                    random_state=42)

# %% [markdown]
# # Нейросетевые модели

# %%
# %%time

# Use scikit-learn to grid search the batch size and epochs
import numpy
from sklearn.model_selection import GridSearchCV
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor
import tensorflow as tf

# Function to create model, required for KerasRegressor
def create_model(activation='relu', learn_rate=0.01, momentum=0):
    # create model
    model = Sequential()
    model.add(Dense(4, input_dim=4, activation=activation))
    model.add(Dense(1, kernel_initializer='normal'))
    
    optimizer = tf.keras.optimizers.RMSprop(learning_rate = learn_rate, rho = 0.99, momentum = momentum, epsilon=1e-10)
    
    # Compile model
    model.compile(loss='mse', optimizer=optimizer)
    return model

X = X_train
Y = y_train

# create model
model = KerasRegressor(build_fn=create_model, verbose=0)

# define the grid search parameters
batch_size = [10, 15, 20]
epochs = [700, 1000, 1300]
activation = ['tanh', 'sigmoid', 'linear']
learn_rate = [0.01, 0.05, 0.1, 0.3, 0.8]
momentum = [0]

param_grid = dict(batch_size=batch_size,
                  epochs=epochs,
                  activation=activation,
                  learn_rate=learn_rate,
                  momentum=momentum
                 )
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=5)
grid_result = grid.fit(X, Y)

# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: -273261830.400000 using {'activation': 'linear', 'batch_size': 20, 'epochs': 1000, 'learn_rate': 0.3, 'momentum': 0}
# -1281397332377.600098 (34734677279.225708) with: {'activation': 'tanh', 'batch_size': 10, 'epochs': 700, 'learn_rate': 0.01, 'momentum': 0}
# -1276931499622.399902 (34674647507.612701) with: {'activation': 'tanh', 'batch_size': 10, 'epochs': 700, 'learn_rate': 0.05, 'momentum': 0}
# -1271364504780.800049 (34601395765.978058) with: {'activation': 'tanh', 'batch_size': 10, 'epochs': 700, 'learn_rate': 0.1, 'momentum': 0}
# -1249198735360.000000 (34303475386.776836) with: {'activation': 'tanh', 'batch_size': 10, 'epochs': 700, 'learn_rate': 0.3, 'momentum': 0}
# -1194689717862.399902 (33579700646.069267) with: {'activation': 'tanh', 'batch_size': 10, 'epochs': 700, 'learn_rate': 0.8, 'momentum': 0}
# -1280924424601.600098 (34728878846.876732) with: {'activation': 'tanh', 'batch_size': 10, 'epochs': 1000, 'learn_rate': 0.01, 'momentum': 0}
# -1274575218278.399902 (34641491235.034119) with: {'activation': 'tanh', 'batch_size': 10, 'epochs': 1000, 'learn_rate': 0.05, 'momentum': 0}
# -1266660435558.399902 (34537051226.312042) with: {'activation': 'tanh', 'batch_size': 10, 'epochs': 1000, 'learn_rate': 0.1, 'momentum': 0}
# -1235269110988.800049 (34123488634.687634) with: {'activation': 'tanh', 'batch_size': 10, 'epochs': 1000, 'learn_rate': 0.3, 'momentum': 0}
# -1158473265971.199951 (33053342761.348507) with: {'activation': 'tanh', 'batch_size': 10, 'epochs': 1000, 'learn_rate': 0.8, 'momentum': 0}
# -1280451621683.199951 (34722098541.256523) with: {'activation': 'tanh', 'batch_size': 10, 'epochs': 1300, 'learn_rate': 0.01, 'momentum': 0}
# -1272219251507.199951 (34612214556.291977) with: {'activation': 'tanh', 'batch_size': 10, 'epochs': 1300, 'learn_rate': 0.05, 'momentum': 0}
# -1261965751091.199951 (34471896847.884262) with: {'activation': 'tanh', 'batch_size': 10, 'epochs': 1300, 'learn_rate': 0.1, 'momentum': 0}
# -1221375347916.800049 (33913107349.177166) with: {'activation': 'tanh', 'batch_size': 10, 'epochs': 1300, 'learn_rate': 0.3, 'momentum': 0}
# -1122889197158.399902 (32568588441.297852) with: {'activation': 'tanh', 'batch_size': 10, 'epochs': 1300, 'learn_rate': 0.8, 'momentum': 0}
# -1281711878963.199951 (34739395320.704857) with: {'activation': 'tanh', 'batch_size': 15, 'epochs': 700, 'learn_rate': 0.01, 'momentum': 0}
# -1278503341260.800049 (34695582083.867821) with: {'activation': 'tanh', 'batch_size': 15, 'epochs': 700, 'learn_rate': 0.05, 'momentum': 0}
# -1274500297523.199951 (34646540724.859612) with: {'activation': 'tanh', 'batch_size': 15, 'epochs': 700, 'learn_rate': 0.1, 'momentum': 0}
# -1258558691737.600098 (34427677047.186859) with: {'activation': 'tanh', 'batch_size': 15, 'epochs': 700, 'learn_rate': 0.3, 'momentum': 0}
# -1219105888665.600098 (33921329256.843990) with: {'activation': 'tanh', 'batch_size': 15, 'epochs': 700, 'learn_rate': 0.8, 'momentum': 0}
# -1281373503488.000000 (34734967358.668358) with: {'activation': 'tanh', 'batch_size': 15, 'epochs': 1000, 'learn_rate': 0.01, 'momentum': 0}
# -1276819773849.600098 (34672270065.268883) with: {'activation': 'tanh', 'batch_size': 15, 'epochs': 1000, 'learn_rate': 0.05, 'momentum': 0}
# -1271132140339.199951 (34598811802.236771) with: {'activation': 'tanh', 'batch_size': 15, 'epochs': 1000, 'learn_rate': 0.1, 'momentum': 0}
# -1248536480972.800049 (34287915107.229679) with: {'activation': 'tanh', 'batch_size': 15, 'epochs': 1000, 'learn_rate': 0.3, 'momentum': 0}
# -1192933143347.199951 (33501523490.132092) with: {'activation': 'tanh', 'batch_size': 15, 'epochs': 1000, 'learn_rate': 0.8, 'momentum': 0}
# -1281037146521.600098 (34730659308.135651) with: {'activation': 'tanh', 'batch_size': 15, 'epochs': 1300, 'learn_rate': 0.01, 'momentum': 0}
# -1275133506355.199951 (34650776754.799065) with: {'activation': 'tanh', 'batch_size': 15, 'epochs': 1300, 'learn_rate': 0.05, 'momentum': 0}
# -1267776015564.800049 (34551203404.931564) with: {'activation': 'tanh', 'batch_size': 15, 'epochs': 1300, 'learn_rate': 0.1, 'momentum': 0}
#
 'epochs': 1300, 'learn_rate': 0.8, 'momentum': 0}
# -1232114417664.000000 (33066994620.005825) with: {'activation': 'linear', 'batch_size': 15, 'epochs': 700, 'learn_rate': 0.01, 'momentum': 0}
# -350425330483.200012 (27351979440.485756) with: {'activation': 'linear', 'batch_size': 15, 'epochs': 700, 'learn_rate': 0.05, 'momentum': 0}
# -281306595.200000 (33633906.834598) with: {'activation': 'linear', 'batch_size': 15, 'epochs': 700, 'learn_rate': 0.1, 'momentum': 0}
# -293834380.800000 (54697054.086114) with: {'activation': 'linear', 'batch_size': 15, 'epochs': 700, 'learn_rate': 0.3, 'momentum': 0}
# -349647814.400000 (57794915.170863) with: {'activation': 'linear', 'batch_size': 15, 'epochs': 700, 'learn_rate': 0.8, 'momentum': 0}
# -1184378309836.800049 (31554258107.963177) with: {'activation': 'linear', 'batch_size': 15, 'epochs': 1000, 'learn_rate': 0.01, 'momentum': 0}
# -8004016128.000000 (2904066971.611528) with: {'activation': 'linear', 'batch_size': 15, 'epochs': 1000, 'learn_rate': 0.05, 'momentum': 0}
# -275623590.400000 (33222597.513987) with: {'activation': 'linear', 'batch_size': 15, 'epochs': 1000, 'learn_rate': 0.1, 'momentum': 0}
# -297983811.200000 (38729818.495437) with: {'activation': 'linear', 'batch_size': 15, 'epochs': 1000, 'learn_rate': 0.3, 'momentum': 0}
# -313483424.000000 (36634898.831175) with: {'activation': 'linear', 'batch_size': 15, 'epochs': 1000, 'learn_rate': 0.8, 'momentum': 0}
# -1122987553587.199951 (29952062376.677551) with: {'activation': 'linear', 'batch_size': 15, 'epochs': 1300, 'learn_rate': 0.01, 'momentum': 0}
# -285318073.600000 (29366288.802990) with: {'activation': 'linear', 'batch_size': 15, 'epochs': 1300, 'learn_rate': 0.05, 'momentum': 0}
# -277495971.200000 (30527025.597143) with: {'activation': 'linear', 'batch_size': 15, 'epochs': 1300, 'learn_rate': 0.1, 'momentum': 0}
# -287806179.200000 (36408015.801413) with: {'activation': 'linear', 'batch_size': 15, 'epochs': 1300, 'learn_rate': 0.3, 'momentum': 0}
# -360035340.800000 (111116151.462670) with: {'activation': 'linear', 'batch_size': 15, 'epochs': 1300, 'learn_rate': 0.8, 'momentum': 0}
# -1256200732672.000000 (33676365676.362652) with: {'activation': 'linear', 'batch_size': 20, 'epochs': 700, 'learn_rate': 0.01, 'momentum': 0}
# -727941146214.400024 (34588646289.487900) with: {'activation': 'linear', 'batch_size': 20, 'epochs': 700, 'learn_rate': 0.05, 'momentum': 0}
# -6909367091.200000 (1814398878.637881) with: {'activation': 'linear', 'batch_size': 20, 'epochs': 700, 'learn_rate': 0.1, 'momentum': 0}
# -282083670.400000 (31747083.773187) with: {'activation': 'linear', 'batch_size': 20, 'epochs': 700, 'learn_rate': 0.3, 'momentum': 0}
# -292754281.600000 (41242708.169270) with: {'activation': 'linear', 'batch_size': 20, 'epochs': 700, 'learn_rate': 0.8, 'momentum': 0}
# -1231740914892.800049 (32736633099.162197) with: {'activation': 'linear', 'batch_size': 20, 'epochs': 1000, 'learn_rate': 0.01, 'momentum': 0}
# -353052013363.200012 (31956799131.083256) with: {'activation': 'linear', 'batch_size': 20, 'epochs': 1000, 'learn_rate': 0.05, 'momentum': 0}
# -277688912.000000 (34837849.545566) with: {'activation': 'linear', 'batch_size': 20, 'epochs': 1000, 'learn_rate': 0.1, 'momentum': 0}
# -273261830.400000 (38236252.723928) with: {'activation': 'linear', 'batch_size': 20, 'epochs': 1000, 'learn_rate': 0.3, 'momentum': 0}
# -294899065.600000 (33933494.387852) with: {'activation': 'linear', 'batch_size': 20, 'epochs': 1000, 'learn_rate': 0.8, 'momentum': 0}
# -1199744430899.199951 (31713372431.917404) with: {'activation': 'linear', 'batch_size': 20, 'epochs': 1300, 'learn_rate': 0.01, 'momentum': 0}
# -60254751948.800003 (9473351332.263668) with: {'activation': 'linear', 'batch_size': 20, 'epochs': 1300, 'learn_rate': 0.05, 'momentum': 0}
# -277668441.600000 (34034336.306259) with: {'activation': 'linear', 'batch_size': 20, 'epochs': 1300, 'learn_rate': 0.1, 'momentum': 0}
# -278938457.600000 (31647605.874703) with: {'activation': 'linear', 'batch_size': 20, 'epochs': 1300, 'learn_rate': 0.3, 'momentum': 0}
# -279819430.400000 (46558503.470756) with: {'activation': 'linear', 'batch_size': 20, 'epochs': 1300, 'learn_rate': 0.8, 'momentum': 0}
# Wall time: 11min 27s

# %%
-273261830.400000 using {'activation': 'linear', 'batch_size': 20, 'epochs': 1000, 'learn_rate
# Out:
#   File "<ipython-input-12-fa1515a166b1>", line 1
#     -276296566.400000 using {'activation': 'linear', 'batch_size': 15, 'epochs': 1300, 'learn_rate': 0.1, 'momentum': 0}
#                       ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Модель 1

# %%
def create_model():

    # create model
    model = Sequential()
    model.add(Dense(4, input_dim=4, activation='linear'))
    model.add(Dense(1, kernel_initializer='normal'))

    optimizer = tf.keras.optimizers.RMSprop(learning_rate = 0.1, rho = 0.99, momentum = 0, epsilon=1e-10)
    
    # Compile model
    model.compile(loss='mse', optimizer=optimizer)
    return model

# %%
model = create_model()
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 4)                 20
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 25
# Trainable params: 25
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Обучение модели

EPOCHS = 1000
batch_size = 20

history = model.fit(
  X, Y,
  epochs=EPOCHS, batch_size = batch_size,verbose=0)

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail(10)
# Out:
#             loss  epoch
# 990  262579936.0    990
# 991  262479872.0    991
# 992  262498832.0    992
# 993  262818912.0    993
# 994  263857168.0    994
# 995  262948672.0    995
# 996  260270288.0    996
# 997  261070368.0    997
# 998  262019120.0    998
# 999  261591376.0    999

# %%
import statsmodels as statsmodels
import statsmodels.api as sm

RMSPE = statsmodels.tools.eval_measures.rmspe(y_test.values, model.predict(X_test))
RMSPE
# Out:
# array([0.18335834])

# %%
import statsmodels as statsmodels
import statsmodels.api as sm

RMSPE = statsmodels.tools.eval_measures.rmspe(y_train.values, model.predict(X_train))
RMSPE
# Out:
# array([0.14556523])
