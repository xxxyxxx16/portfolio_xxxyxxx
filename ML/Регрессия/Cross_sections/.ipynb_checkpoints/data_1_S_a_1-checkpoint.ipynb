# %% [markdown]
# # Cечения в зависимости от 4 параметров (плотности теплоносителя, температуры теплоносителя, температуры топлива и концентрации борной кислоты)

# %%
import pandas as pd

# %% [markdown]
# Загрузка данных

# %%
df = pd.read_excel('Data/data_1.xlsx')
df.head(3)
# Out:
#    \rho(g/cm^3)  T_c(K)  T_f(K)  c_b(ppm)  3S_{tr1}(1)  3S_{tr2}(2)  \
# 0        0.7235   575.0  1027.0     600.0     0.661853     2.568298
# 1        0.7750   448.0  1043.0    1500.0     0.679602     2.874687
# 2        0.9125   370.5  1418.0     750.0     0.727336     3.668742
#
#    \Sigma_{a1}(3)  \Sigma_{a2}(4)  nuS_{f1}(5)  nuS_{f2}(6)  \Sigma_{f1}(7)  \
# 0        0.009376        0.085584     0.006677     0.133250        0.002620
# 1        0.009581        0.098339     0.006723     0.139256        0.002636
# 2        0.009908        0.102815     0.006844     0.153823        0.002681
#
#    \Sigma_{f2}(8)  \Sigma_{1->2}(9)  k_{inf}(10)  \sigma_{a2}^{Xe}  \
# 0        0.054750          0.017392     1.261041         1072970.0
# 1        0.057218          0.018726     1.174265         1141000.0
# 2        0.063203          0.022463     1.249619         1308480.0
#
#    \sigma_{a2}^{Sm}
# 0         35421.398
# 1         36147.801
# 2         39214.000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 257 entries, 0 to 256
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   \rho(g/cm^3)      257 non-null    float64
#  1   T_c(K)            257 non-null    float64
#  2   T_f(K)            257 non-null    float64
#  3   c_b(ppm)          257 non-null    float64
#  4   3S_{tr1}(1)       257 non-null    float64
#  5   3S_{tr2}(2)       257 non-null    float64
#  6   \Sigma_{a1}(3)    257 non-null    float64
#  7   \Sigma_{a2}(4)    257 non-null    float64
#  8   nuS_{f1}(5)       257 non-null    float64
#  9   nuS_{f2}(6)       257 non-null    float64
#  10  \Sigma_{f1}(7)    257 non-null    float64
#  11  \Sigma_{f2}(8)    257 non-null    float64
#  12  \Sigma_{1->2}(9)  257 non-null    float64
#  13  k_{inf}(10)       257 non-null    float64
#  14  \sigma_{a2}^{Xe}  257 non-null    float64
#  15  \sigma_{a2}^{Sm}  257 non-null    float64
# dtypes: float64(16)
# memory usage: 32.2 KB

# %% [markdown]
# Проверка пропусков

# %%
df.isnull().sum()
# Out:
# \rho(g/cm^3)        0
# T_c(K)              0
# T_f(K)              0
# c_b(ppm)            0
# 3S_{tr1}(1)         0
# 3S_{tr2}(2)         0
# \Sigma_{a1}(3)      0
# \Sigma_{a2}(4)      0
# nuS_{f1}(5)         0
# nuS_{f2}(6)         0
# \Sigma_{f1}(7)      0
# \Sigma_{f2}(8)      0
# \Sigma_{1->2}(9)    0
# k_{inf}(10)         0
# \sigma_{a2}^{Xe}    0
# \sigma_{a2}^{Sm}    0
# dtype: int64

# %%
names = ['\\rho(g/cm^3)',
 'T_c(K)',
 'T_f(K)',
 'c_b(ppm)',
 '\\Sigma_{a1}(3)']

# %%
train_dataset = df[names].sample(frac=0.8,random_state=0)
test_dataset = df[names].drop(train_dataset.index)

# %%
train_dataset.head(3)
# Out:
#      \rho(g/cm^3)     T_c(K)      T_f(K)    c_b(ppm)  \Sigma_{a1}(3)
# 158      0.798633  405.61719   486.35941   855.46881        0.009191
# 83       0.701953  561.82812  1664.09400  1195.31200        0.009682
# 170      1.047852  294.21091  1447.29700  1746.09400        0.010267

# %%
test_dataset.head(3)
# Out:
#     \rho(g/cm^3)    T_c(K)    T_f(K)  c_b(ppm)  \Sigma_{a1}(3)
# 9       0.878125  544.8750  1511.750    562.50        0.009870
# 21      1.032812  477.0625  1746.125   2343.75        0.010476
# 25      0.860937  496.4375   339.875   1031.25        0.009183

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, ax = plt.subplots(figsize=(5,5)) # Sample figsize in inches
sns.heatmap(train_dataset[names].corr(), annot = True, fmt='.2g')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Линейная регрессия

# %%
import statsmodels.api as sm
import statsmodels as statsmodels

train_data = train_dataset[names[:-1]]
train_data = sm.add_constant(train_data)

train_data.head(3)
# Out:
#      const  \rho(g/cm^3)     T_c(K)      T_f(K)    c_b(ppm)
# 158    1.0      0.798633  405.61719   486.35941   855.46881
# 83     1.0      0.701953  561.82812  1664.09400  1195.31200
# 170    1.0      1.047852  294.21091  1447.29700  1746.09400

# %%
train_labels = train_dataset['\\Sigma_{a1}(3)']
train_labels.head(3)
# Out:
# 158    0.009191
# 83     0.009682
# 170    0.010267
# Name: \Sigma_{a1}(3), dtype: float64

# %%
model = sm.OLS(train_labels, train_data)

fit = model.fit()
g = fit.summary()
g
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         \Sigma_{a1}(3)   R-squared:                       0.982
# Model:                            OLS   Adj. R-squared:                  0.981
# Method:                 Least Squares   F-statistic:                     2684.
# Date:                Sun, 11 Oct 2020   Prob (F-statistic):          3.57e-173
# Time:                        13:18:47   Log-Likelihood:                 1729.5
# No. Observations:                 206   AIC:                            -3449.
# Df Residuals:                     201   BIC:                            -3432.
# Df Model:                           4
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.0073   3.03e-05    240.115      0.000       0.007       0.007
# \rho(g/cm^3)     0.0019   2.45e-05     79.231      0.000       0.002       0.002
# T_c(K)       -1.713e-08   4.27e-08     -0.401      0.689   -1.01e-07     6.7e-08
# T_f(K)        5.525e-07   9.11e-09     60.648      0.000    5.35e-07     5.7e-07
# c_b(ppm)      1.164e-07   4.46e-09     26.112      0.000    1.08e-07    1.25e-07
# ==============================================================================
# Omnibus:                       35.901   Durbin-Watson:                   2.254
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               50.291
# Skew:                          -1.047   Prob(JB):                     1.20e-11
# Kurtosis:                       4.213   Cond. No.                     1.85e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.85e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
g = fit.pvalues
g
# Out:
# const           4.032260e-249
# \rho(g/cm^3)    1.492454e-153
# T_c(K)           6.886047e-01
# T_f(K)          3.662547e-131
# c_b(ppm)         1.640938e-66
# dtype: float64

# %% [markdown]
# T_c(K) - не значим на 10-ом % урвоне значимости

# %%
features = ['\\rho(g/cm^3)', 'T_f(K)', 'c_b(ppm)']

# %%
train_data = train_dataset[features]
train_data = sm.add_constant(train_data)

train_data.head(3)
# Out:
#      const  \rho(g/cm^3)      T_f(K)    c_b(ppm)
# 158    1.0      0.798633   486.35941   855.46881
# 83     1.0      0.701953  1664.09400  1195.31200
# 170    1.0      1.047852  1447.29700  1746.09400

# %%
model = sm.OLS(train_labels, train_data)

fit = model.fit()
g = fit.summary()
g
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         \Sigma_{a1}(3)   R-squared:                       0.982
# Model:                            OLS   Adj. R-squared:                  0.981
# Method:                 Least Squares   F-statistic:                     3594.
# Date:                Sun, 11 Oct 2020   Prob (F-statistic):          5.94e-175
# Time:                        13:19:00   Log-Likelihood:                 1729.4
# No. Observations:                 206   AIC:                            -3451.
# Df Residuals:                     202   BIC:                            -3438.
# Df Model:                           3
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.0073   2.26e-05    321.523      0.000       0.007       0.007
# \rho(g/cm^3)     0.0019   2.44e-05     79.557      0.000       0.002       0.002
# T_f(K)        5.524e-07   9.09e-09     60.776      0.000    5.35e-07     5.7e-07
# c_b(ppm)      1.165e-07   4.45e-09     26.182      0.000    1.08e-07    1.25e-07
# ==============================================================================
# Omnibus:                       36.341   Durbin-Watson:                   2.255
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               51.170
# Skew:                          -1.056   Prob(JB):                     7.74e-12
# Kurtosis:                       4.227   Cond. No.                     1.62e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.62e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
p = fit.pvalues
p
# Out:
# const           1.114568e-275
# \rho(g/cm^3)    1.909580e-154
# T_f(K)          8.934611e-132
# c_b(ppm)         7.582079e-67
# dtype: float64

# %% [markdown]
# Все регрессоры значимы на 1-ом уровне значимости %.

# %%
ypred = fit.predict(train_data)
ypred
# Out:
# 158    0.009180
# 83     0.009682
# 170    0.010299
# 101    0.010378
# 150    0.009880
#          ...
# 151    0.009585
# 202    0.009838
# 31     0.008840
# 209    0.010077
# 127    0.008969
# Length: 206, dtype: float64

# %%
train_labels
# Out:
# 158    0.009191
# 83     0.009682
# 170    0.010267
# 101    0.010408
# 150    0.009951
#          ...
# 151    0.009539
# 202    0.009804
# 31     0.008841
# 209    0.010099
# 127    0.008912
# Name: \Sigma_{a1}(3), Length: 206, dtype: float64

# %% [markdown]
# \begin{align*}
# \text{MSE} = \frac{1}{N} \text{RSS} = \frac{1}{N} \sum (f_i -y_i)^2
# \end{align*}

# %%
MSE = statsmodels.tools.eval_measures.mse(train_labels, ypred)
MSE
# Out:
# 2.9888282856646884e-09

# %% [markdown]
# \begin{align*}
# \sigma = \sqrt{MSE}
# \end{align*}

# %% [markdown]
# Среднеквадратическое отклонение в абсолютных единицах

# %%
import math as math
sigma = math.sqrt(MSE)
sigma
# Out:
# 5.467017729681045e-05

# %%
train_labels.mean()
# Out:
# 0.009519196648058253

# %% [markdown]
# Среднеквадратическое отклонение в процентах для среднего значения.

# %%
sigma = sigma/train_labels.mean()

# %%
print("Среднеквадратическое отклонение: ", round(sigma, 5))
print("Среднеквадратическое отклонение: ", round(sigma*100, 3) , '%')
# Out:
# Среднеквадратическое отклонение:  0.00574
# Среднеквадратическое отклонение:  0.574 %

# %% [markdown]
# ## Deep learning

# %% [markdown]
# ### Нормализация признаков

# %%
features = ['\\rho(g/cm^3)',
 'T_c(K)',
 'T_f(K)',
 'c_b(ppm)']

# %%
df[features].describe()
# Out:
#        \rho(g/cm^3)      T_c(K)       T_f(K)     c_b(ppm)
# count    257.000000  257.000000   257.000000   257.000000
# mean       0.773742  448.491808  1043.838306  1493.967349
# std        0.158780   89.316810   430.718000   863.720860
# min        0.502148  294.210910   298.859410    11.718750
# 25%        0.637500  371.710910   673.859380   750.000000
# 50%        0.772852  448.000000  1043.000000  1488.281000
# 75%        0.910352  525.500000  1412.141000  2238.281000
# max        1.047852  601.789120  1787.141000  2988.281000

# %%
df_features_norm = df.copy()

for i in range(len(features)):
    df_features_norm[features[i]] = (df[features[i]]-df[features[i]].mean())/df[features[i]].std()

# %%
df_features_norm[features].describe()
# Out:
#        \rho(g/cm^3)        T_c(K)        T_f(K)      c_b(ppm)
# count  2.570000e+02  2.570000e+02  2.570000e+02  2.570000e+02
# mean  -3.697863e-16  5.978789e-16  7.084692e-17 -3.507786e-16
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.710507e+00 -1.727344e+00 -1.729621e+00 -1.716120e+00
# 25%   -8.580575e-01 -8.596467e-01 -8.589818e-01 -8.613516e-01
# 50%   -5.608782e-03 -5.506328e-03 -1.946298e-03 -6.583549e-03
# 75%    8.603710e-01  8.621915e-01  8.550901e-01  8.617525e-01
# max    1.726354e+00  1.716332e+00  1.725729e+00  1.730089e+00

# %% [markdown]
# ## Нейронная сеть

# %%
names
# Out:
# ['\\rho(g/cm^3)', 'T_c(K)', 'T_f(K)', 'c_b(ppm)', '\\Sigma_{a1}(3)']

# %%
df_features_norm = df_features_norm[names]
df_features_norm.head(3)
# Out:
#    \rho(g/cm^3)    T_c(K)    T_f(K)  c_b(ppm)  \Sigma_{a1}(3)
# 0     -0.316426  1.416398 -0.039094 -1.035019        0.009376
# 1      0.007922 -0.005506 -0.001946  0.006984        0.009581
# 2      0.873902 -0.873204  0.868693 -0.861352        0.009908

# %%
features
# Out:
# ['\\rho(g/cm^3)', 'T_c(K)', 'T_f(K)', 'c_b(ppm)']

# %%
df_features_norm[features].head(3)
# Out:
#    \rho(g/cm^3)    T_c(K)    T_f(K)  c_b(ppm)
# 0     -0.316426  1.416398 -0.039094 -1.035019
# 1      0.007922 -0.005506 -0.001946  0.006984
# 2      0.873902 -0.873204  0.868693 -0.861352

# %% [markdown]
# Разделим данные на обучающую и тестовую выборки

# %%
train_dataset = df_features_norm.sample(frac=0.8,random_state=0)
test_dataset = df_features_norm.drop(train_dataset.index)

# %%
train_dataset.head(3)
# Out:
#      \rho(g/cm^3)    T_c(K)    T_f(K)  c_b(ppm)  \Sigma_{a1}(3)
# 158      0.156763 -0.480029 -1.294301 -0.739242        0.009191
# 83      -0.452130  1.268925  1.440051 -0.345778        0.009682
# 170      1.726354 -1.727344  0.936712  0.291908        0.010267

# %%
test_dataset.head(3)
# Out:
#     \rho(g/cm^3)    T_c(K)    T_f(K)  c_b(ppm)  \Sigma_{a1}(3)
# 9       0.657407  1.079116  1.086353 -1.078436        0.009870
# 21      1.631631  0.319880  1.630502  0.983863        0.010476
# 25      0.549160  0.536805 -1.634395 -0.535726        0.009183

# %% [markdown]
# Отделим признаки от меток

# %%
train_labels = train_dataset.pop('\Sigma_{a1}(3)')
test_labels = test_dataset.pop('\Sigma_{a1}(3)')

# %%
train_dataset.head(2)
# Out:
#      \rho(g/cm^3)    T_c(K)    T_f(K)  c_b(ppm)
# 158      0.156763 -0.480029 -1.294301 -0.739242
# 83      -0.452130  1.268925  1.440051 -0.345778

# %%
train_labels.head(2)
# Out:
# 158    0.009191
# 83     0.009682
# Name: \Sigma_{a1}(3), dtype: float64

# %% [markdown]
# Модель

# %%
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers

def build_model():
  model = keras.Sequential([
    layers.Dense(4, activation='relu', input_shape=[len(train_dataset.keys())]),
    layers.Dense(4, activation='relu'),
    layers.Dense(1)
  ])

  optimizer = tf.keras.optimizers.RMSprop(0.001)

  model.compile(loss='mse',
                optimizer=optimizer,
                metrics=['mae', 'mse'])
  return model

# %%
model = build_model()

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 4)                 20
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 20
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 45
# Trainable params: 45
# Non-trainable params: 0
# _________________________________________________________________

# %%
normed_train_data = train_dataset

# %%
normed_train_data.head(3)
# Out:
#      \rho(g/cm^3)    T_c(K)    T_f(K)  c_b(ppm)
# 158      0.156763 -0.480029 -1.294301 -0.739242
# 83      -0.452130  1.268925  1.440051 -0.345778
# 170      1.726354 -1.727344  0.936712  0.291908

# %%
example_batch = normed_train_data[:10]
example_result = model.predict(example_batch)
example_result
# Out:
# array([[-0.00342079],
#        [-0.04724094],
#        [ 0.        ],
#        [-0.45653552],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.00276391],
#        [ 0.        ],
#        [-0.03192304],
#        [ 0.00799283]], dtype=float32)

# %% [markdown]
# Обучение модели

# %%
# Выведем прогресс обучения в виде точек после каждой завершенной эпохи
class PrintDot(keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs):
    if epoch % 100 == 0: print('')
    print('.', end='')

EPOCHS = 100

history = model.fit(
  normed_train_data, train_labels,
  epochs=EPOCHS, validation_split = 0.2, verbose=0,
  callbacks=[PrintDot()])
# Out:
# ....................................................................................................

# %% [markdown]
# Визуализируем процесс обучения модели используя статистику содержащуюся в объекте history

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
# Out:
#         loss       mae       mse  val_loss   val_mae   val_mse  epoch
# 95  0.000002  0.000897  0.000002  0.000066  0.002305  0.000066     95
# 96  0.000002  0.000734  0.000002  0.000068  0.002223  0.000068     96
# 97  0.000001  0.000654  0.000001  0.000062  0.002171  0.000062     97
# 98  0.000002  0.000981  0.000002  0.000062  0.002289  0.000062     98
# 99  0.000002  0.000784  0.000002  0.000060  0.002350  0.000060     99

# %%
def plot_history(history):
  hist = pd.DataFrame(history.history)
  hist['epoch'] = history.epoch

  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Abs Error')
  plt.plot(hist['epoch'], hist['mae'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mae'],
           label = 'Val Error')
  plt.ylim([0,0.1])
  plt.legend()

  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Square Error')
  plt.plot(hist['epoch'], hist['mse'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mse'],
           label = 'Val Error')
  plt.ylim([0,0.001])
  plt.legend()
  plt.show()


plot_history(history)

# %%
train_labels.head(10)
# Out:
# 158    0.009191
# 83     0.009682
# 170    0.010267
# 101    0.010408
# 150    0.009951
# 200    0.009514
# 118    0.009555
# 236    0.009563
# 63     0.009234
# 135    0.008740
# Name: \Sigma_{a1}(3), dtype: float64

# %%
model.predict(normed_train_data)[0:10]
# Out:
# array([[0.00918012],
#        [0.00864675],
#        [0.00918012],
#        [0.00918012],
#        [0.00918012],
#        [0.00864675],
#        [0.00918012],
#        [0.00864675],
#        [0.00864675],
#        [0.00918012]], dtype=float32)

# %% [markdown]
# Модель

# %%
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers

def build_model():
  model = keras.Sequential([
    layers.Dense(4, activation='relu', input_shape=[len(train_dataset.keys())]),
    layers.Dense(6, activation='relu'),
    layers.Dense(1)
  ])

  optimizer = tf.keras.optimizers.RMSprop(0.001)

  model.compile(loss='mse',
                optimizer=optimizer,
                metrics=['mae', 'mse'])
  return model

# %%
model = build_model()

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 4)                 20
# _________________________________________________________________
# dense_4 (Dense)              (None, 6)                 30
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 57
# Trainable params: 57
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Выведем прогресс обучения в виде точек после каждой завершенной эпохи
class PrintDot(keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs):
    if epoch % 100 == 0: print('')
    print('.', end='')

EPOCHS = 150

history = model.fit(
  normed_train_data, train_labels,
  epochs=EPOCHS, validation_split = 0.2, verbose=0,
  callbacks=[PrintDot()])
# Out:
# ....................................................................................................
# ..................................................

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
# Out:
#              loss       mae           mse      val_loss   val_mae  \
# 145  1.211421e-07  0.000284  1.211421e-07  4.373598e-07  0.000609
# 146  5.563911e-07  0.000675  5.563911e-07  5.940986e-07  0.000723
# 147  4.761509e-07  0.000615  4.761509e-07  2.290205e-07  0.000406
# 148  3.102860e-07  0.000471  3.102860e-07  7.689739e-07  0.000801
# 149  4.571955e-07  0.000587  4.571955e-07  4.186981e-07  0.000585
#
#           val_mse  epoch
# 145  4.373599e-07    145
# 146  5.940986e-07    146
# 147  2.290205e-07    147
# 148  7.689738e-07    148
# 149  4.186981e-07    149

# %%
def plot_history(history):
  hist = pd.DataFrame(history.history)
  hist['epoch'] = history.epoch

  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Abs Error')
  plt.plot(hist['epoch'], hist['mae'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mae'],
           label = 'Val Error')
  plt.ylim([0,0.1])
  plt.legend()

  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Square Error')
  plt.plot(hist['epoch'], hist['mse'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mse'],
           label = 'Val Error')
  plt.ylim([0,0.0001])
  plt.legend()
  plt.show()


plot_history(history)

# %%
train_labels.head(10)
# Out:
# 158    0.009191
# 83     0.009682
# 170    0.010267
# 101    0.010408
# 150    0.009951
# 200    0.009514
# 118    0.009555
# 236    0.009563
# 63     0.009234
# 135    0.008740
# Name: \Sigma_{a1}(3), dtype: float64

# %%
model.predict(normed_train_data)[0:10]
# Out:
# array([[0.00850425],
#        [0.00921905],
#        [0.00921905],
#        [0.00921905],
#        [0.00921905],
#        [0.00914169],
#        [0.00921905],
#        [0.00921905],
#        [0.00901034],
#        [0.00711579]], dtype=float32)

# %% [markdown]
# Модель

# %%
def build_model():
  model = keras.Sequential([
    layers.Dense(4, activation='tanh', input_shape=[len(train_dataset.keys())]),
    layers.Dense(4, activation='tanh'),
    layers.Dense(1)
  ])

  optimizer = tf.keras.optimizers.RMSprop(0.001)

  model.compile(loss='mse',
                optimizer=optimizer,
                metrics=['mae', 'mse'])
  return model

# %%
model = build_model()

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 4)                 20
# _________________________________________________________________
# dense_7 (Dense)              (None, 4)                 20
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 45
# Trainable params: 45
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Выведем прогресс обучения в виде точек после каждой завершенной эпохи
class PrintDot(keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs):
    if epoch % 100 == 0: print('')
    print('.', end='')

EPOCHS = 200

history = model.fit(
  normed_train_data, train_labels,
  epochs=EPOCHS, validation_split = 0.2, verbose=0,
  callbacks=[PrintDot()])
# Out:
# ....................................................................................................
# ....................................................................................................

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
# Out:
#          loss       mae       mse  val_loss   val_mae   val_mse  epoch
# 195  0.000006  0.001935  0.000006  0.000004  0.001681  0.000004    195
# 196  0.000002  0.001259  0.000002  0.000028  0.004419  0.000028    196
# 197  0.000008  0.001873  0.000008  0.000002  0.001272  0.000002    197
# 198  0.000001  0.000852  0.000001  0.000005  0.001942  0.000005    198
# 199  0.000007  0.002034  0.000007  0.000003  0.001243  0.000003    199

# %%
def plot_history(history):
  hist = pd.DataFrame(history.history)
  hist['epoch'] = history.epoch

  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Abs Error')
  plt.plot(hist['epoch'], hist['mae'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mae'],
           label = 'Val Error')
  plt.ylim([0,0.1])
  plt.legend()

  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Square Error')
  plt.plot(hist['epoch'], hist['mse'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mse'],
           label = 'Val Error')
  plt.ylim([0,0.001])
  plt.legend()
  plt.show()


plot_history(history)

# %% [markdown]
# Модель

# %%
def build_model():
  model = keras.Sequential([
    layers.Dense(4, activation='tanh', input_shape=[len(train_dataset.keys())]),
    layers.Dense(4, activation='tanh'),
    layers.Dense(1)
  ])

  optimizer = tf.keras.optimizers.RMSprop(0.0001)

  model.compile(loss='mse',
                optimizer=optimizer,
                metrics=['mae', 'mse'])
  return model

# %%
model = build_model()

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_9 (Dense)              (None, 4)                 20
# _________________________________________________________________
# dense_10 (Dense)             (None, 4)                 20
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 5
# =================================================================
# Total params: 45
# Trainable params: 45
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Выведем прогресс обучения в виде точек после каждой завершенной эпохи
class PrintDot(keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs):
    if epoch % 100 == 0: print('')
    print('.', end='')

EPOCHS = 1500

history = model.fit(
  normed_train_data, train_labels,
  epochs=EPOCHS, validation_split = 0.2, verbose=0,
  callbacks=[PrintDot()])
# Out:
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
# Out:
#               loss       mae           mse      val_loss   val_mae  \
# 1495  3.962658e-07  0.000490  3.962658e-07  4.246181e-07  0.000514
# 1496  4.596795e-07  0.000543  4.596794e-07  4.703117e-07  0.000543
# 1497  4.006962e-07  0.000476  4.006962e-07  3.919101e-07  0.000482
# 1498  3.873102e-07  0.000471  3.873102e-07  1.030395e-06  0.000841
# 1499  6.126300e-07  0.000582  6.126300e-07  5.206847e-07  0.000564
#
#            val_mse  epoch
# 1495  4.246181e-07   1495
# 1496  4.703117e-07   1496
# 1497  3.919101e-07   1497
# 1498  1.030395e-06   1498
# 1499  5.206847e-07   1499

# %%
def plot_history(history):
  hist = pd.DataFrame(history.history)
  hist['epoch'] = history.epoch

  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Abs Error')
  plt.plot(hist['epoch'], hist['mae'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mae'],
           label = 'Val Error')
  plt.ylim([0,0.01])
  plt.xlim([1000,1500])  
  plt.legend()

  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Square Error')
  plt.plot(hist['epoch'], hist['mse'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mse'],
           label = 'Val Error')
  plt.ylim([0,0.0001])
  plt.xlim([1000,1500])  
  plt.legend()
  plt.show()


plot_history(history)

# %%
def build_model():
  model = keras.Sequential([
    layers.Dense(4, activation='tanh', input_shape=[len(train_dataset.keys())]),
    layers.Dense(4, activation='tanh'),
    layers.Dense(1)
  ])

  optimizer = tf.keras.optimizers.RMSprop(0.00005)

  model.compile(loss='mse',
                optimizer=optimizer,
                metrics=['mae', 'mse'])
  return model

# %%
model = build_model()

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 4)                 20
# _________________________________________________________________
# dense_13 (Dense)             (None, 4)                 20
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 5
# =================================================================
# Total params: 45
# Trainable params: 45
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Выведем прогресс обучения в виде точек после каждой завершенной эпохи
class PrintDot(keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs):
    if epoch % 100 == 0: print('')
    print('.', end='')

EPOCHS = 5000

history = model.fit(
  normed_train_data, train_labels,
  epochs=EPOCHS, validation_split = 0.2, verbose=0,
  callbacks=[PrintDot()])
# Out:
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
# Out:
#           loss       mae       mse  val_loss   val_mae   val_mse  epoch
# 4995  0.000001  0.000884  0.000001  0.000001  0.000964  0.000001   4995
# 4996  0.000001  0.000849  0.000001  0.000001  0.000927  0.000001   4996
# 4997  0.000001  0.000893  0.000001  0.000001  0.000962  0.000001   4997
# 4998  0.000001  0.000894  0.000001  0.000001  0.000905  0.000001   4998
# 4999  0.000001  0.000877  0.000001  0.000001  0.000936  0.000001   4999

# %%
def plot_history(history):
  hist = pd.DataFrame(history.history)
  hist['epoch'] = history.epoch

  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Abs Error')
  plt.plot(hist['epoch'], hist['mae'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mae'],
           label = 'Val Error')
  plt.ylim([0,0.01])
  plt.xlim([3500,5000])  
  plt.legend()

  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Square Error')
  plt.plot(hist['epoch'], hist['mse'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mse'],
           label = 'Val Error')
  plt.ylim([0,0.00001])
  plt.xlim([3500,5000])  
  plt.legend()
  plt.show()


plot_history(history)

# %% [markdown]
# Модель

# %%
def build_model():
  model = keras.Sequential([
    layers.Dense(5, activation='tanh', input_shape=[len(train_dataset.keys())]),
    layers.Dense(5, activation='tanh'),
    layers.Dense(1)
  ])

  optimizer = tf.keras.optimizers.RMSprop(0.0001)

  model.compile(loss='mse',
                optimizer=optimizer,
                metrics=['mae', 'mse'])
  return model

# %%
model = build_model()

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_15 (Dense)             (None, 5)                 25
# _________________________________________________________________
# dense_16 (Dense)             (None, 5)                 30
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 6
# =================================================================
# Total params: 61
# Trainable params: 61
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Выведем прогресс обучения в виде точек после каждой завершенной эпохи
class PrintDot(keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs):
    if epoch % 100 == 0: print('')
    print('.', end='')

EPOCHS = 5000

history = model.fit(
  normed_train_data, train_labels,
  epochs=EPOCHS, validation_split = 0.2, verbose=0,
  callbacks=[PrintDot()])
# Out:
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
# Out:
#               loss       mae           mse      val_loss   val_mae  \
# 4995  2.212155e-07  0.000396  2.212155e-07  2.174320e-07  0.000363
# 4996  1.296202e-07  0.000278  1.296202e-07  1.011301e-06  0.000886
# 4997  3.337528e-07  0.000384  3.337528e-07  1.025672e-07  0.000269
# 4998  1.499333e-07  0.000323  1.499333e-07  3.593845e-07  0.000518
# 4999  1.833672e-07  0.000316  1.833672e-07  1.389992e-06  0.000999
#
#            val_mse  epoch
# 4995  2.174320e-07   4995
# 4996  1.011301e-06   4996
# 4997  1.025672e-07   4997
# 4998  3.593845e-07   4998
# 4999  1.389992e-06   4999

# %%
def plot_history(history):
  hist = pd.DataFrame(history.history)
  hist['epoch'] = history.epoch

  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Abs Error')
  plt.plot(hist['epoch'], hist['mae'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mae'],
           label = 'Val Error')
  plt.ylim([0,0.001])
  plt.xlim([4600,5000])  
  plt.legend()

  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Square Error')
  plt.plot(hist['epoch'], hist['mse'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mse'],
           label = 'Val Error')
  plt.ylim([0,0.000001])
  plt.xlim([4600,5000])  
  plt.legend()
  plt.show()


plot_history(history)

# %% [markdown]
# Модель

# %%
def build_model():
  model = keras.Sequential([
    layers.Dense(5, activation='tanh', input_shape=[len(train_dataset.keys())]),
    layers.Dense(5, activation='tanh'),
    layers.Dense(1)
  ])

  optimizer = tf.keras.optimizers.RMSprop(0.000075)

  model.compile(loss='mse',
                optimizer=optimizer,
                metrics=['mae', 'mse'])
  return model

model = build_model()
display(model.summary())

# Выведем прогресс обучения в виде точек после каждой завершенной эпохи
class PrintDot(keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs):
    if epoch % 100 == 0: print('')
    print('.', end='')

EPOCHS = 2500

history = model.fit(
  normed_train_data, train_labels,
  epochs=EPOCHS, validation_split = 0.2, verbose=0,
  callbacks=[PrintDot()])

hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_18 (Dense)             (None, 5)                 25
# _________________________________________________________________
# dense_19 (Dense)             (None, 5)                 30
# _________________________________________________________________
# dense_20 (Dense)             (None, 1)                 6
# =================================================================
# Total params: 61
# Trainable params: 61
# Non-trainable params: 0
# _________________________________________________________________
# None
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
#           loss       mae       mse  val_loss   val_mae   val_mse  epoch
# 2495  0.000002  0.000980  0.000002  0.000002  0.001040  0.000002   2495
# 2496  0.000002  0.000924  0.000002  0.000002  0.001200  0.000002   2496
# 2497  0.000002  0.000983  0.000002  0.000002  0.001057  0.000002   2497
# 2498  0.000002  0.000991  0.000002  0.000003  0.001215  0.000003   2498
# 2499  0.000002  0.000989  0.000002  0.000002  0.001088  0.000002   2499

# %%
def plot_history(history):
  hist = pd.DataFrame(history.history)
  hist['epoch'] = history.epoch

  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Abs Error')
  plt.plot(hist['epoch'], hist['mae'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mae'],
           label = 'Val Error')
  plt.ylim([0,0.01])
  plt.xlim([int(EPOCHS*0.8),EPOCHS]) 
  plt.legend()

  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Square Error')
  plt.plot(hist['epoch'], hist['mse'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mse'],
           label = 'Val Error')
  plt.ylim([0,0.00001])
  plt.xlim([int(EPOCHS*0.8),EPOCHS])  
  plt.legend()
  plt.show()


plot_history(history)

# %% [markdown]
# Модель

# %%
def build_model():
  model = keras.Sequential([
    layers.Dense(4, activation='relu', input_shape=[len(train_dataset.keys())]),
    layers.Dense(4, activation='relu'),
    layers.Dense(4, activation='tanh'),
    layers.Dense(1)
  ])

  optimizer = tf.keras.optimizers.RMSprop(0.000075)

  model.compile(loss='mse',
                optimizer=optimizer,
                metrics=['mae', 'mse'])
  return model

model = build_model()
display(model.summary())

# Выведем прогресс обучения в виде точек после каждой завершенной эпохи
class PrintDot(keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs):
    if epoch % 100 == 0: print('')
    print('.', end='')

EPOCHS = 2500

history = model.fit(
  normed_train_data, train_labels,
  epochs=EPOCHS, validation_split = 0.2, verbose=0,
  callbacks=[PrintDot()])

hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_21 (Dense)             (None, 4)                 20
# _________________________________________________________________
# dense_22 (Dense)             (None, 4)                 20
# _________________________________________________________________
# dense_23 (Dense)             (None, 4)                 20
# _________________________________________________________________
# dense_24 (Dense)             (None, 1)                 5
# =================================================================
# Total params: 65
# Trainable params: 65
# Non-trainable params: 0
# _________________________________________________________________
# None
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
#               loss       mae           mse      val_loss   val_mae  \
# 2495  6.457961e-08  0.000207  6.457960e-08  1.156646e-07  0.000268
# 2496  9.560357e-08  0.000254  9.560357e-08  1.630283e-07  0.000316
# 2497  6.822139e-08  0.000214  6.822138e-08  3.261987e-07  0.000465
# 2498  1.106247e-07  0.000267  1.106247e-07  1.551905e-07  0.000300
# 2499  7.275033e-08  0.000219  7.275032e-08  1.090249e-07  0.000256
#
#            val_mse  epoch
# 2495  1.156646e-07   2495
# 2496  1.630283e-07   2496
# 2497  3.261987e-07   2497
# 2498  1.551905e-07   2498
# 2499  1.090249e-07   2499

# %%
def plot_history(history):
  hist = pd.DataFrame(history.history)
  hist['epoch'] = history.epoch

  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Abs Error')
  plt.plot(hist['epoch'], hist['mae'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mae'],
           label = 'Val Error')
  plt.ylim([0,0.01])
  plt.xlim([int(EPOCHS*0.8),EPOCHS]) 
  plt.legend()

  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Square Error')
  plt.plot(hist['epoch'], hist['mse'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mse'],
           label = 'Val Error')
  plt.ylim([0,0.000001])
  plt.xlim([int(EPOCHS*0.8),EPOCHS])  
  plt.legend()
  plt.show()


plot_history(history)

# %% [markdown]
# Модель

# %%
def build_model():
  model = keras.Sequential([
    layers.Dense(4, activation='relu', input_shape=[len(train_dataset.keys())]),
    layers.Dense(3, activation='relu'),
    layers.Dense(2, activation='tanh'),
    layers.Dense(1)
  ])

  optimizer = tf.keras.optimizers.RMSprop(0.000075)

  model.compile(loss='mse',
                optimizer=optimizer,
                metrics=['mae', 'mse'])
  return model

model = build_model()
display(model.summary())

# Выведем прогресс обучения в виде точек после каждой завершенной эпохи
class PrintDot(keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs):
    if epoch % 100 == 0: print('')
    print('.', end='')

EPOCHS = 750

history = model.fit(
  normed_train_data, train_labels,
  epochs=EPOCHS, validation_split = 0.2, verbose=0,
  callbacks=[PrintDot()])

hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_25 (Dense)             (None, 4)                 20
# _________________________________________________________________
# dense_26 (Dense)             (None, 3)                 15
# _________________________________________________________________
# dense_27 (Dense)             (None, 2)                 8
# _________________________________________________________________
# dense_28 (Dense)             (None, 1)                 3
# =================================================================
# Total params: 46
# Trainable params: 46
# Non-trainable params: 0
# _________________________________________________________________
# None
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ..................................................
#              loss       mae           mse      val_loss   val_mae  \
# 745  1.022070e-07  0.000252  1.022070e-07  1.343702e-07  0.000287
# 746  1.021004e-07  0.000247  1.021004e-07  2.186549e-07  0.000374
# 747  1.293489e-07  0.000286  1.293489e-07  1.449650e-07  0.000288
# 748  1.048576e-07  0.000255  1.048576e-07  1.824990e-07  0.000343
# 749  1.128617e-07  0.000264  1.128617e-07  1.188034e-07  0.000260
#
#           val_mse  epoch
# 745  1.343702e-07    745
# 746  2.186549e-07    746
# 747  1.449650e-07    747
# 748  1.824990e-07    748
# 749  1.188033e-07    749

# %%
def plot_history(history):
  hist = pd.DataFrame(history.history)
  hist['epoch'] = history.epoch

  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Abs Error')
  plt.plot(hist['epoch'], hist['mae'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mae'],
           label = 'Val Error')
  plt.ylim([0,0.001])
  plt.xlim([int(EPOCHS*0.75),EPOCHS]) 
  plt.legend()

  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Square Error')
  plt.plot(hist['epoch'], hist['mse'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mse'],
           label = 'Val Error')
  plt.ylim([0,0.000001])
  plt.xlim([int(EPOCHS*0.75),EPOCHS])  
  plt.legend()
  plt.show()


plot_history(history)

# %% [markdown]
# Модель

# %%
def build_model():
  model = keras.Sequential([
    layers.Dense(4, activation='relu', input_shape=[len(train_dataset.keys())]),
    layers.Dense(3, activation='relu'),
    layers.Dense(2, activation='tanh'),
    layers.Dense(1)
  ])

  optimizer = tf.keras.optimizers.RMSprop(0.0001)

  model.compile(loss='mse',
                optimizer=optimizer,
                metrics=['mae', 'mse'])
  return model

model = build_model()
display(model.summary())

# Выведем прогресс обучения в виде точек после каждой завершенной эпохи
class PrintDot(keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs):
    if epoch % 100 == 0: print('')
    print('.', end='')

EPOCHS = 250

history = model.fit(
    normed_train_data, train_labels,
    batch_size=10,
    epochs=EPOCHS,
    validation_split = 0.2,
    verbose=0,
    callbacks=[PrintDot()])

hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_29 (Dense)             (None, 4)                 20
# _________________________________________________________________
# dense_30 (Dense)             (None, 3)                 15
# _________________________________________________________________
# dense_31 (Dense)             (None, 2)                 8
# _________________________________________________________________
# dense_32 (Dense)             (None, 1)                 3
# =================================================================
# Total params: 46
# Trainable params: 46
# Non-trainable params: 0
# _________________________________________________________________
# None
# ....................................................................................................
# ....................................................................................................
# ..................................................
#              loss       mae           mse      val_loss   val_mae  \
# 245  7.424281e-07  0.000535  7.424281e-07  5.545084e-07  0.000514
# 246  7.080833e-07  0.000516  7.080832e-07  5.941289e-07  0.000566
# 247  7.374468e-07  0.000526  7.374468e-07  5.901160e-07  0.000574
# 248  7.231518e-07  0.000555  7.231518e-07  5.405885e-07  0.000532
# 249  6.913775e-07  0.000519  6.913776e-07  5.644456e-07  0.000495
#
#           val_mse  epoch
# 245  5.545084e-07    245
# 246  5.941289e-07    246
# 247  5.901160e-07    247
# 248  5.405885e-07    248
# 249  5.644456e-07    249

# %%
def plot_history(history):
  hist = pd.DataFrame(history.history)
  hist['epoch'] = history.epoch

  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Abs Error')
  plt.plot(hist['epoch'], hist['mae'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mae'],
           label = 'Val Error')
  plt.ylim([0,0.01])
  plt.xlim([int(EPOCHS*0.75),EPOCHS]) 
  plt.legend()

  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Square Error')
  plt.plot(hist['epoch'], hist['mse'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mse'],
           label = 'Val Error')
  plt.ylim([0,0.00001])
  plt.xlim([int(EPOCHS*0.75),EPOCHS])  
  plt.legend()
  plt.show()


plot_history(history)

# %% [markdown]
# Модель

# %%
def build_model():
  model = keras.Sequential([
    layers.Dense(4, activation='relu', input_shape=[len(train_dataset.keys())]),
    layers.Dense(3, activation='relu'),
    layers.Dense(2, activation='tanh'),
    layers.Dense(1)
  ])

  optimizer = tf.keras.optimizers.RMSprop(0.0001)

  model.compile(loss='mse',
                optimizer=optimizer,
                metrics=['mae', 'mse'])
  return model

model = build_model()
display(model.summary())

# Выведем прогресс обучения в виде точек после каждой завершенной эпохи
class PrintDot(keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs):
    if epoch % 100 == 0: print('')
    print('.', end='')

EPOCHS = 500

history = model.fit(
    normed_train_data, train_labels,
    batch_size= 5,
    epochs=EPOCHS,
    validation_split = 0.2,
    verbose=0,
    callbacks=[PrintDot()])

hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_41 (Dense)             (None, 4)                 20
# _________________________________________________________________
# dense_42 (Dense)             (None, 3)                 15
# _________________________________________________________________
# dense_43 (Dense)             (None, 2)                 8
# _________________________________________________________________
# dense_44 (Dense)             (None, 1)                 3
# =================================================================
# Total params: 46
# Trainable params: 46
# Non-trainable params: 0
# _________________________________________________________________
# None
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
#              loss       mae           mse      val_loss   val_mae  \
# 495  2.839783e-08  0.000135  2.839783e-08  3.521010e-08  0.000153
# 496  2.667142e-08  0.000132  2.667142e-08  2.820736e-08  0.000142
# 497  2.760551e-08  0.000130  2.760551e-08  2.559214e-08  0.000127
# 498  2.590478e-08  0.000134  2.590479e-08  2.333658e-08  0.000116
# 499  2.688736e-08  0.000130  2.688736e-08  2.509750e-08  0.000131
#
#           val_mse  epoch
# 495  3.521010e-08    495
# 496  2.820736e-08    496
# 497  2.559214e-08    497
# 498  2.333658e-08    498
# 499  2.509750e-08    499

# %%
def plot_history(history):
  hist = pd.DataFrame(history.history)
  hist['epoch'] = history.epoch

  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Abs Error')
  plt.plot(hist['epoch'], hist['mae'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mae'],
           label = 'Val Error')
  plt.ylim([0,0.001])
  plt.xlim([int(EPOCHS*0.75),EPOCHS]) 
  plt.legend()

  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Square Error')
  plt.plot(hist['epoch'], hist['mse'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mse'],
           label = 'Val Error')
  plt.ylim([0,0.0000001])
  plt.xlim([int(EPOCHS*0.3),EPOCHS])  
  plt.legend()
  plt.show()


plot_history(history)

# %%
model.predict(normed_train_data)[0:10]
# Out:
# array([[0.00968292],
#        [0.00968292],
#        [0.00968292],
#        [0.01061327],
#        [0.00973827],
#        [0.00968292],
#        [0.00968292],
#        [0.00968292],
#        [0.00968292],
#        [0.00818044]], dtype=float32)

# %%
train_labels.head(10)
# Out:
# 158    0.009191
# 83     0.009682
# 170    0.010267
# 101    0.010408
# 150    0.009951
# 200    0.009514
# 118    0.009555
# 236    0.009563
# 63     0.009234
# 135    0.008740
# Name: \Sigma_{a1}(3), dtype: float64

# %% [markdown]
# Модель

# %%
# RMSprop
# rho - Discounting factor for the history/coming gradient. Defaults to 0.9.

def build_model():
  model = keras.Sequential([
    layers.Dense(4, activation='relu', input_shape=[len(train_dataset.keys())]),
    layers.Dense(3, activation='relu'),
    layers.Dense(2, activation='tanh'),
    layers.Dense(1)
  ])

  optimizer = tf.keras.optimizers.RMSprop(learning_rate = 0.0001, rho = 0.98)

  model.compile(loss='mse',
                optimizer=optimizer,
                metrics=['mae', 'mse'])
  return model

model = build_model()
display(model.summary())

# Выведем прогресс обучения в виде точек после каждой завершенной эпохи
class PrintDot(keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs):
    if epoch % 100 == 0: print('')
    print('.', end='')

EPOCHS = 500

history = model.fit(
    normed_train_data, train_labels,
    batch_size= 10,
    epochs=EPOCHS,
    validation_split = 0.2,
    verbose=0,
    callbacks=[PrintDot()])

hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
# Out:
# Model: "sequential_19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_69 (Dense)             (None, 4)                 20
# _________________________________________________________________
# dense_70 (Dense)             (None, 3)                 15
# _________________________________________________________________
# dense_71 (Dense)             (None, 2)                 8
# _________________________________________________________________
# dense_72 (Dense)             (None, 1)                 3
# =================================================================
# Total params: 46
# Trainable params: 46
# Non-trainable params: 0
# _________________________________________________________________
# None
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
#              loss       mae           mse      val_loss   val_mae  \
# 495  1.892743e-07  0.000347  1.892743e-07  1.875308e-07  0.000377
# 496  1.593641e-07  0.000325  1.593641e-07  2.299294e-07  0.000423
# 497  1.748205e-07  0.000337  1.748205e-07  2.443334e-07  0.000438
# 498  1.691091e-07  0.000335  1.691091e-07  2.169396e-07  0.000414
# 499  2.032231e-07  0.000374  2.032231e-07  2.287069e-07  0.000423
#
#           val_mse  epoch
# 495  1.875307e-07    495
# 496  2.299294e-07    496
# 497  2.443334e-07    497
# 498  2.169396e-07    498
# 499  2.287070e-07    499

# %%
def plot_history(history):
  hist = pd.DataFrame(history.history)
  hist['epoch'] = history.epoch

  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Abs Error')
  plt.plot(hist['epoch'], hist['mae'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mae'],
           label = 'Val Error')
  plt.ylim([0,0.01])
  plt.xlim([int(EPOCHS*0.0),EPOCHS]) 
  plt.legend()

  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Square Error')
  plt.plot(hist['epoch'], hist['mse'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mse'],
           label = 'Val Error')
  plt.ylim([0,0.0001])
  plt.xlim([int(EPOCHS*0.0),EPOCHS])  
  plt.legend()
  plt.show()


plot_history(history)

# %%
model.predict(normed_train_data)[0:10]
# Out:
# array([[0.0093493 ],
#        [0.00927036],
#        [0.0093493 ],
#        [0.00945218],
#        [0.0093493 ],
#        [0.00931146],
#        [0.0093493 ],
#        [0.00936689],
#        [0.00977696],
#        [0.00932223]], dtype=float32)

# %% [markdown]
# Модель

# %%
# RMSprop
# rho - Discounting factor for the history/coming gradient. Defaults to 0.9.

def build_model():
  model = keras.Sequential([
    layers.Dense(4, activation='relu', input_shape=[len(train_dataset.keys())]),
    layers.Dense(3, activation='relu'),
    layers.Dense(2, activation='tanh'),
    layers.Dense(1)
  ])

  optimizer = tf.keras.optimizers.RMSprop(learning_rate = 0.00009, rho = 0.98)

  model.compile(loss='mse',
                optimizer=optimizer,
                metrics=['mae', 'mse'])
  return model

model = build_model()
display(model.summary())

# Выведем прогресс обучения в виде точек после каждой завершенной эпохи
class PrintDot(keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs):
    if epoch % 100 == 0: print('')
    print('.', end='')

EPOCHS = 500

history = model.fit(
    normed_train_data, train_labels,
    batch_size= 10,
    epochs=EPOCHS,
    validation_split = 0.2,
    verbose=0,
    callbacks=[PrintDot()])

hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
# Out:
# Model: "sequential_20"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_73 (Dense)             (None, 4)                 20
# _________________________________________________________________
# dense_74 (Dense)             (None, 3)                 15
# _________________________________________________________________
# dense_75 (Dense)             (None, 2)                 8
# _________________________________________________________________
# dense_76 (Dense)             (None, 1)                 3
# =================================================================
# Total params: 46
# Trainable params: 46
# Non-trainable params: 0
# _________________________________________________________________
# None
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
#              loss       mae           mse      val_loss   val_mae  \
# 495  1.302188e-07  0.000286  1.302189e-07  4.498150e-07  0.000487
# 496  1.331328e-07  0.000286  1.331328e-07  3.327369e-07  0.000399
# 497  1.271284e-07  0.000276  1.271284e-07  3.532472e-07  0.000416
# 498  1.347450e-07  0.000285  1.347451e-07  3.630746e-07  0.000435
# 499  1.317668e-07  0.000286  1.317668e-07  3.901824e-07  0.000444
#
#           val_mse  epoch
# 495  4.498150e-07    495
# 496  3.327369e-07    496
# 497  3.532472e-07    497
# 498  3.630746e-07    498
# 499  3.901824e-07    499

# %%
def plot_history(history):
  hist = pd.DataFrame(history.history)
  hist['epoch'] = history.epoch

  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Abs Error')
  plt.plot(hist['epoch'], hist['mae'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mae'],
           label = 'Val Error')
  plt.ylim([0,0.01])
  plt.xlim([int(EPOCHS*0.0),EPOCHS]) 
  plt.legend()

  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Square Error')
  plt.plot(hist['epoch'], hist['mse'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mse'],
           label = 'Val Error')
  plt.ylim([0,0.0001])
  plt.xlim([int(EPOCHS*0.0),EPOCHS])  
  plt.legend()
  plt.show()


plot_history(history)

# %%
model.predict(normed_train_data)[0:10]
# Out:
# array([[0.00879572],
#        [0.00945624],
#        [0.00992335],
#        [0.00945624],
#        [0.00945624],
#        [0.00945624],
#        [0.00944013],
#        [0.00945624],
#        [0.00945624],
#        [0.00945624]], dtype=float32)

# %% [markdown]
# Модель

# %%
# RMSprop
# rho - Discounting factor for the history/coming gradient. Defaults to 0.9.

def build_model():
  model = keras.Sequential([
    layers.Dense(4, activation='relu', input_shape=[len(train_dataset.keys())]),
    layers.Dense(3, activation='relu'),
    layers.Dense(2, activation='tanh'),
    layers.Dense(1)
  ])

  optimizer = tf.keras.optimizers.RMSprop(learning_rate = 0.001, rho = 0.9)

  model.compile(loss='mse',
                optimizer=optimizer,
                metrics=['mae', 'mse'])
  return model

model = build_model()
display(model.summary())

# Выведем прогресс обучения в виде точек после каждой завершенной эпохи
class PrintDot(keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs):
    if epoch % 100 == 0: print('')
    print('.', end='')

EPOCHS = 500

history = model.fit(
    normed_train_data, train_labels,
    batch_size= 10,
    epochs=EPOCHS,
    validation_split = 0.2,
    verbose=0,
    callbacks=[PrintDot()])

hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
# Out:
# Model: "sequential_22"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_81 (Dense)             (None, 4)                 20
# _________________________________________________________________
# dense_82 (Dense)             (None, 3)                 15
# _________________________________________________________________
# dense_83 (Dense)             (None, 2)                 8
# _________________________________________________________________
# dense_84 (Dense)             (None, 1)                 3
# =================================================================
# Total params: 46
# Trainable params: 46
# Non-trainable params: 0
# _________________________________________________________________
# None
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
#              loss       mae           mse      val_loss   val_mae  \
# 495  6.869438e-07  0.000766  6.869438e-07  1.350970e-07  0.000343
# 496  6.703445e-07  0.000753  6.703445e-07  1.896678e-07  0.000398
# 497  6.438167e-07  0.000738  6.438166e-07  9.733659e-07  0.000978
# 498  7.381208e-07  0.000839  7.381209e-07  5.006669e-07  0.000679
# 499  5.046376e-07  0.000633  5.046376e-07  4.247375e-07  0.000638
#
#           val_mse  epoch
# 495  1.350970e-07    495
# 496  1.896678e-07    496
# 497  9.733659e-07    497
# 498  5.006669e-07    498
# 499  4.247375e-07    499

# %%
def plot_history(history):
  hist = pd.DataFrame(history.history)
  hist['epoch'] = history.epoch

  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Abs Error')
  plt.plot(hist['epoch'], hist['mae'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mae'],
           label = 'Val Error')
  plt.ylim([0,0.01])
  plt.xlim([int(EPOCHS*0.0),EPOCHS]) 
  plt.legend()

  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Square Error')
  plt.plot(hist['epoch'], hist['mse'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mse'],
           label = 'Val Error')
  plt.ylim([0,0.00001])
  plt.xlim([int(EPOCHS*0.0),EPOCHS])  
  plt.legend()
  plt.show()


plot_history(history)

# %%
model.predict(normed_train_data)[0:10]
# Out:
# array([[0.00976941],
#        [0.01038575],
#        [0.01081321],
#        [0.01102025],
#        [0.01051043],
#        [0.01005696],
#        [0.01008279],
#        [0.00992914],
#        [0.0098308 ],
#        [0.00976941]], dtype=float32)

# %%
train_labels.head(10)
# Out:
# 158    0.009191
# 83     0.009682
# 170    0.010267
# 101    0.010408
# 150    0.009951
# 200    0.009514
# 118    0.009555
# 236    0.009563
# 63     0.009234
# 135    0.008740
# Name: \Sigma_{a1}(3), dtype: float64

# %% [markdown]
# Модель

# %%
# RMSprop
# rho - Discounting factor for the history/coming gradient. Defaults to 0.9.

def build_model():
  model = keras.Sequential([
    layers.Dense(4, activation='tanh', input_shape=[len(train_dataset.keys())]),
    layers.Dense(3, activation='tanh'),
    layers.Dense(2, activation='tanh'),
    layers.Dense(1)
  ])

  optimizer = tf.keras.optimizers.RMSprop(learning_rate = 0.001, rho = 0.9)

  model.compile(loss='mse',
                optimizer=optimizer,
                metrics=['mae', 'mse'])
  return model

model = build_model()
display(model.summary())

# Выведем прогресс обучения в виде точек после каждой завершенной эпохи
class PrintDot(keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs):
    if epoch % 100 == 0: print('')
    print('.', end='')

EPOCHS = 500

history = model.fit(
    normed_train_data, train_labels,
    batch_size= 10,
    epochs=EPOCHS,
    validation_split = 0.2,
    verbose=0,
    callbacks=[PrintDot()])

hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
# Out:
# Model: "sequential_24"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_89 (Dense)             (None, 4)                 20
# _________________________________________________________________
# dense_90 (Dense)             (None, 3)                 15
# _________________________________________________________________
# dense_91 (Dense)             (None, 2)                 8
# _________________________________________________________________
# dense_92 (Dense)             (None, 1)                 3
# =================================================================
# Total params: 46
# Trainable params: 46
# Non-trainable params: 0
# _________________________________________________________________
# None
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
#          loss       mae       mse      val_loss   val_mae       val_mse  epoch
# 495  0.000001  0.001196  0.000001  1.348549e-06  0.001153  1.348549e-06    495
# 496  0.000001  0.001198  0.000001  1.529326e-06  0.001219  1.529326e-06    496
# 497  0.000002  0.001106  0.000002  2.642004e-07  0.000467  2.642004e-07    497
# 498  0.000001  0.001112  0.000001  2.152218e-06  0.001465  2.152218e-06    498
# 499  0.000002  0.001247  0.000002  1.410075e-06  0.001183  1.410075e-06    499

# %%
def plot_history(history):
  hist = pd.DataFrame(history.history)
  hist['epoch'] = history.epoch

  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Abs Error')
  plt.plot(hist['epoch'], hist['mae'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mae'],
           label = 'Val Error')
  plt.ylim([0,0.01])
  plt.xlim([int(EPOCHS*0.0),EPOCHS]) 
  plt.legend()

  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Square Error')
  plt.plot(hist['epoch'], hist['mse'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mse'],
           label = 'Val Error')
  plt.ylim([0,0.00001])
  plt.xlim([int(EPOCHS*0.0),EPOCHS])  
  plt.legend()
  plt.show()


plot_history(history)

# %% [markdown]
# Модель

# %%
# RMSprop
# rho - Discounting factor for the history/coming gradient. Defaults to 0.9.

def build_model():
  model = keras.Sequential([
    layers.Dense(5, activation='tanh', input_shape=[len(train_dataset.keys())]),
    layers.Dense(4, activation='tanh'),
    layers.Dense(3, activation='tanh'),
    layers.Dense(1)
  ])

  optimizer = tf.keras.optimizers.RMSprop(learning_rate = 0.001, rho = 0.99)

  model.compile(loss='mse',
                optimizer=optimizer,
                metrics=['mae', 'mse'])
  return model

model = build_model()
display(model.summary())

# Выведем прогресс обучения в виде точек после каждой завершенной эпохи
class PrintDot(keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs):
    if epoch % 100 == 0: print('')
    print('.', end='')

EPOCHS = 500

history = model.fit(
    normed_train_data, train_labels,
    batch_size= 10,
    epochs=EPOCHS,
    validation_split = 0.2,
    verbose=0,
    callbacks=[PrintDot()])

hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
# Out:
# Model: "sequential_26"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_97 (Dense)             (None, 5)                 25
# _________________________________________________________________
# dense_98 (Dense)             (None, 4)                 24
# _________________________________________________________________
# dense_99 (Dense)             (None, 3)                 15
# _________________________________________________________________
# dense_100 (Dense)            (None, 1)                 4
# =================================================================
# Total params: 68
# Trainable params: 68
# Non-trainable params: 0
# _________________________________________________________________
# None
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
#              loss       mae           mse      val_loss   val_mae  \
# 495  6.706539e-08  0.000209  6.706539e-08  3.216565e-07  0.000541
# 496  7.115544e-06  0.002317  7.115545e-06  2.067799e-06  0.001416
# 497  6.075951e-07  0.000591  6.075950e-07  3.228651e-08  0.000134
# 498  2.982859e-08  0.000140  2.982859e-08  1.110426e-07  0.000298
# 499  3.555532e-06  0.001578  3.555532e-06  6.169848e-06  0.002460
#
#           val_mse  epoch
# 495  3.216565e-07    495
# 496  2.067799e-06    496
# 497  3.228651e-08    497
# 498  1.110426e-07    498
# 499  6.169848e-06    499

# %%
def plot_history(history):
  hist = pd.DataFrame(history.history)
  hist['epoch'] = history.epoch

  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Abs Error')
  plt.plot(hist['epoch'], hist['mae'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mae'],
           label = 'Val Error')
  plt.ylim([0,0.01])
  plt.xlim([int(EPOCHS*0.0),EPOCHS]) 
  plt.legend()

  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Square Error')
  plt.plot(hist['epoch'], hist['mse'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mse'],
           label = 'Val Error')
  plt.ylim([0,0.0001])
  plt.xlim([int(EPOCHS*0.0),EPOCHS])  
  plt.legend()
  plt.show()


plot_history(history)

# %%
model.predict(normed_train_data)[0:10]
# Out:
# array([[0.01195848],
#        [0.01210304],
#        [0.01183271],
#        [0.01190774],
#        [0.01182064],
#        [0.01201208],
#        [0.01210825],
#        [0.01205909],
#        [0.01197052],
#        [0.01238389]], dtype=float32)
