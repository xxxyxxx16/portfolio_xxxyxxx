# %% [markdown]
# # 1. Эксперимент #

# %% [markdown]
# Цель работы - освоение алгоритмов классификации на наборе данных, полученных методом Монте Карло. Набор данных представляет собой 3 класса. Каждый класс имеет два признака - время замедления нейтрона и число столкновений.

# %% [markdown]
# ## Блок нейтронной физики ##

# %%
import pandas as pd
import random as rd
import math as math
import scipy.constants as const # Модуль физико-математических констант
import numpy as np

# отключим предупреждения Anaconda
import warnings
warnings.simplefilter('ignore')

N_A = const.Avogadro

# %% [markdown]
# ### Функция жизни нейтрона: ###

# %%
# Для одинаковой генерации данных
rd.seed(42)

def life_of_neutron(Ein, Eout, dens, A1, A2, Mol_m, Sigma, alpha_1, alpha_2, sigma_1, sigma_2, x1, x2):
    
    Energy = Ein
    colision = 0 # Число столкновений
    time = 0 # Время полета
    a = 0 # Угол полета
    b = 0 # Изменение угла полета
    l = 0 # Длина пролета
    V = 0 # Скорость
    elder = 0 #Возраст
    while Energy > Eout: #Пока энергия нейтрона лежит в области > ... ЭВ
        l = -1*math.log(rd.random())/Sigma/100 # В метрах
        V = (2*Energy*1.6*(10**(-19))/(1.6749*10**(-27)))**0.5 # В м/с
        time += l/V
        colision += 1
        
        #Разыгрывание на каком ядре произошло рассеяние
        x = rd.random()
        if x < (x1*sigma_1/(x1*sigma_1 + x2*sigma_2)):# Рассеяние на первом ядре
            E1 = Energy
            E2 = Energy*alpha_1
            Energy = rd.uniform(E1, E2)
            b = math.acos

            
        else:# Рассеяние на втором ядре
            E1 = Energy
            E2 = Energy*alpha_2
            Energy = rd.uniform(E1, E2)

    return colision, time

# %% [markdown]
# ### Входные данные по материалам: ###

# %%
df = pd.DataFrame({'Material': ['Water', 'Heavy Plexiglass', 'Heavy Water'],
                   'Density g/cm^3': [1.0, 1.6, 1.1],
                    'A_1' : [1, 12, 2],
                    'A_2' : [16, 2, 16],
                    'Molar mass g/mol' : [18, 28, 20],
                    'Chemical formula' : ['H2O', 'C2D2', 'D2O'],
                    'sigma_1 b' : [30.0, 4.9, 3.5],
                    'sigma_2 b' : [4.0, 3.5, 4.0],
                    'x1' : [2, 2, 2],
                    'x2' : [1, 2, 1],
                    
              })

df
# Out:
#            Material  Density g/cm^3  A_1  A_2  Molar mass g/mol  \
# 0             Water             1.0    1   16                18
# 1  Heavy Plexiglass             1.6   12    2                28
# 2       Heavy Water             1.1    2   16                20
#
#   Chemical formula  sigma_1 b  sigma_2 b  x1  x2
# 0              H2O       30.0        4.0   2   1
# 1             C2D2        4.9        3.5   2   2
# 2              D2O        3.5        4.0   2   1

# %% [markdown]
# ### Расчет макросечения: ###

# %%
df['\u03A3, 1/cm'] = 0.0
for k in df.index:
    df['Σ, 1/cm'][k] = (df['x1'][k]*df['sigma_1 b'][k]+df['x2'][k]*df['sigma_2 b'][k]
                       )*N_A*df['Density g/cm^3'][k]/df['Molar mass g/mol'][k]/10**(24)
display(df)
# Out:
#            Material  Density g/cm^3  A_1  A_2  Molar mass g/mol  \
# 0             Water             1.0    1   16                18
# 1  Heavy Plexiglass             1.6   12    2                28
# 2       Heavy Water             1.1    2   16                20
#
#   Chemical formula  sigma_1 b  sigma_2 b  x1  x2   Σ, 1/cm
# 0              H2O       30.0        4.0   2   1  2.141206
# 1             C2D2        4.9        3.5   2   2  0.578126
# 2              D2O        3.5        4.0   2   1  0.364340

# %% [markdown]
# ### Расчет ступеньки замедления: ###

# %%
df['\u0251_1'] = 0.0
df['\u0251_2'] = 0.0
for k in df.index:
    df['\u0251_1'][k] = ((df['A_1'][k]-1)/(df['A_1'][k]+1))**2
    df['\u0251_2'][k] = ((df['A_2'][k]-1)/(df['A_2'][k]+1))**2
display(df)
# Out:
#            Material  Density g/cm^3  A_1  A_2  Molar mass g/mol  \
# 0             Water             1.0    1   16                18
# 1  Heavy Plexiglass             1.6   12    2                28
# 2       Heavy Water             1.1    2   16                20
#
#   Chemical formula  sigma_1 b  sigma_2 b  x1  x2   Σ, 1/cm       ɑ_1       ɑ_2
# 0              H2O       30.0        4.0   2   1  2.141206  0.000000  0.778547
# 1             C2D2        4.9        3.5   2   2  0.578126  0.715976  0.111111
# 2              D2O        3.5        4.0   2   1  0.364340  0.111111  0.778547

# %% [markdown]
# ### Создание DataFrame для записи данных ###

# %%
df1 = pd.DataFrame({'time, 10^(-5) c': [],
                   'colisions': [],
                    'Material' : [],
                    'target' : [] 
              })
df1
# Out:
# Empty DataFrame
# Columns: [time, 10^(-5) c, colisions, Material, target]
# Index: []

# %% [markdown]
# ### Эксперимент методом Монте-Карло ###

# %%
Estart = 1_000_000 #1Мэв
Eend = 1 #1 Эв
Colision = [0, 0, 0, 0]
Time = [0, 0, 0, 0]
number_of_event = 300
counter = 0 # Счетчик для записи в DataFrame
for k in df.index: #Цикл по материалам
    for i in range(0, number_of_event*(k+1)): #Колличество событий для каждого материала
        colision, time = life_of_neutron(Estart, Eend, df['Density g/cm^3'][k],
                                          df['A_1'][k], df['A_2'][k],
                                          df['Molar mass g/mol'][k], df['Σ, 1/cm'][k],
                                          df['ɑ_1'][k], df['ɑ_2'][k],
                                          df['sigma_1 b'][k], df['sigma_2 b'][k],
                                          df['x1'][k], df['x2'][k],)
        df1.loc[counter] = {'Material': df['Material'][k], 'time, 10^(-5) c': time*100_000, 'colisions': colision, 'target': k}
        Colision[k]+=colision
        Time[k]+=time
        counter+=1

# %% [markdown]
# # 2. Визуализация экспериментальных данных  #

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#графики в svg выглядят более четкими
# %config InlineBackend.figure_format = 'svg'

import matplotlib as mpl
mpl.rcParams["xtick.bottom"] = True

flatui = ['#ff005d','#404e5c','#3fcbb6']
sns.palplot(sns.color_palette(flatui))

sns.set(font_scale = 1.5,
       style='white',
       palette=flatui,
       )

sns.set_style("ticks", {"xtick.bottom": True})

# %% [markdown]
# Распределение столкновений

# %%
sns.boxplot(y="colisions", x="target",
            data=df1)
# Out:
# <AxesSubplot:xlabel='target', ylabel='colisions'>

# %% [markdown]
# Распределение времени

# %%
sns.boxplot(y="time, 10^(-5) c", x="target",
            data=df1)
# Out:
# <AxesSubplot:xlabel='target', ylabel='time, 10^(-5) c'>

# %% [markdown]
# Карта распрделений

# %%
df1['colisions'] = df1['colisions']/100
df1.rename(columns={'colisions': 'colisions, 10^2'}, inplace=True)

# %%
sns.set(font_scale = 1.5,
       style='white',
       )

g = sns.PairGrid(df1[['time, 10^(-5) c','colisions, 10^2', 'Material']],
                 hue='Material',
                 height=5.5,
                 palette= flatui,
                 despine = False,
                 hue_kws={
                     "marker": ["o", "o", "o"]
                 })

g.map_diag(sns.distplot, norm_hist = True, bins = np.linspace(0.0, 2.4, num=(6*4*10), endpoint=True))
g.map_upper(sns.kdeplot, shade=False, shade_lowest=False)
g.map_lower(plt.scatter, s = 20, alpha=0.4, linewidth=1.0, edgecolor="black")
g.fig.set_size_inches(10, 10)


plt.legend(loc='upper center', bbox_to_anchor=(1, 1.25), ncol=3) #vertical legend

# Подписи к осям
g.axes[0,0].yaxis.set_label_text(r'$\rho (t) $')
g.axes[0,0].xaxis.set_label_text('$t, 10^{-5} c$')
g.axes[1,1].yaxis.set_label_text(r'$\rho (colisions) $')
g.axes[1,1].xaxis.set_label_text('$colisions, 10^{2}$')
g.axes[1,0].yaxis.set_label_text('$colisions, 10^{2}$')
g.axes[1,0].xaxis.set_label_text('$t, 10^{-5} c$')
g.axes[0,1].yaxis.set_label_text('$t, 10^{-5} c$')
g.axes[0,1].xaxis.set_label_text('$colisions, 10^{2}$')

# Тики видны на y
g.axes[0,0].yaxis.set_tick_params(labelleft=False)
g.axes[1,1].yaxis.set_tick_params(labelleft=False)
g.axes[1,0].yaxis.set_tick_params(labelleft=True, bottom = True, direction = 'in')
g.axes[0,1].yaxis.set_tick_params(labelleft=True, bottom = True, direction = 'in')

# Тики видны на x
g.axes[0,0].xaxis.set_tick_params(labelleft=True, bottom = True, direction = 'in')
g.axes[1,1].xaxis.set_tick_params(labelleft=True, bottom = True, direction = 'in')
g.axes[1,0].xaxis.set_tick_params(labelleft=True, bottom = True, direction = 'in')
g.axes[0,1].xaxis.set_tick_params(labelleft=True, bottom = True, direction = 'in')

#Лимиты тиков на x
g.axes[1,0].set_xlim(0, 2.5)
g.axes[0,1].set_xlim(0, 0.6)

#Лимиты тиков на y
g.axes[1,0].set_ylim(0.00001, 0.6)
g.axes[0,0].set_ylim(0.00001, 2.5)

plt.subplots_adjust(hspace=0.5, wspace=0.2)

# %% [markdown]
# # 3 Кластеризация

# %%
from sklearn import model_selection

# %%
X = df1[['time, 10^(-5) c', 'colisions, 10^2']]
X
# Out:
#       time, 10^(-5) c  colisions, 10^2
# 0            0.060134             0.18
# 1            0.015265             0.11
# 2            0.058799             0.17
# 3            0.047027             0.14
# 4            0.018141             0.10
# ...               ...              ...
# 1795         1.073471             0.37
# 1796         0.457777             0.28
# 1797         1.017680             0.35
# 1798         0.532127             0.29
# 1799         0.393834             0.27
#
# [1800 rows x 2 columns]

# %%
from sklearn.cluster import KMeans

# %%
est = KMeans(n_clusters=3,n_jobs=5)
est.fit(X)
# Out:
# KMeans(n_clusters=3, n_jobs=5)

# %%
labels = est.labels_
labels
# Out:
# array([1, 1, 1, ..., 2, 0, 1])

# %%
X['target'] = labels
X
# Out:
#       time, 10^(-5) c  colisions, 10^2  target
# 0            0.060134             0.18       1
# 1            0.015265             0.11       1
# 2            0.058799             0.17       1
# 3            0.047027             0.14       1
# 4            0.018141             0.10       1
# ...               ...              ...     ...
# 1795         1.073471             0.37       2
# 1796         0.457777             0.28       0
# 1797         1.017680             0.35       2
# 1798         0.532127             0.29       0
# 1799         0.393834             0.27       1
#
# [1800 rows x 3 columns]

# %%
sns.set(font_scale = 1.5,
       style='white',
       )

gg = sns.PairGrid(X,
                 hue='target',
                 height=5.5,
                 palette= flatui,
                 despine = False,
                 hue_kws={
                     "marker": ["o", "o", "o"]
                 })

gg.map_diag(sns.distplot, norm_hist = True, bins = np.linspace(0.0, 2.4, num=(6*4*10), endpoint=True))
gg.map_upper(sns.kdeplot, shade=False, shade_lowest=False)
gg.map_lower(plt.scatter, s = 20, alpha=0.4, linewidth=1.0, edgecolor="black")
gg.fig.set_size_inches(10, 10)


plt.legend(loc='upper center', bbox_to_anchor=(1, 1.25), ncol=3) #vertical legend

# Подписи к осям
gg.axes[0,0].yaxis.set_label_text(r'$\rho (t) $')
gg.axes[0,0].xaxis.set_label_text('$t, 10^{-5} c$')
gg.axes[1,1].yaxis.set_label_text(r'$\rho (colisions) $')
gg.axes[1,1].xaxis.set_label_text('$colisions, 10^{2}$')
gg.axes[1,0].yaxis.set_label_text('$colisions, 10^{2}$')
gg.axes[1,0].xaxis.set_label_text('$t, 10^{-5} c$')
gg.axes[0,1].yaxis.set_label_text('$t, 10^{-5} c$')
gg.axes[0,1].xaxis.set_label_text('$colisions, 10^{2}$')

# Тики видны на y
gg.axes[0,0].yaxis.set_tick_params(labelleft=False)
gg.axes[1,1].yaxis.set_tick_params(labelleft=False)
gg.axes[1,0].yaxis.set_tick_params(labelleft=True, bottom = True, direction = 'in')
gg.axes[0,1].yaxis.set_tick_params(labelleft=True, bottom = True, direction = 'in')

# Тики видны на x
gg.axes[0,0].xaxis.set_tick_params(labelleft=True, bottom = True, direction = 'in')
gg.axes[1,1].xaxis.set_tick_params(labelleft=True, bottom = True, direction = 'in')
gg.axes[1,0].xaxis.set_tick_params(labelleft=True, bottom = True, direction = 'in')
gg.axes[0,1].xaxis.set_tick_params(labelleft=True, bottom = True, direction = 'in')

#Лимиты тиков на x
gg.axes[1,0].set_xlim(0, 2.5)
gg.axes[0,1].set_xlim(0, 0.6)

#Лимиты тиков на y
gg.axes[1,0].set_ylim(0.00001, 0.6)
gg.axes[0,0].set_ylim(0.00001, 2.5)

plt.subplots_adjust(hspace=0.5, wspace=0.2)

# %%
flatui = ['#ff005d','#404e5c','#3fcbb6', '#FFA500']

# %%
X = df1[['time, 10^(-5) c', 'colisions, 10^2']]
X
# Out:
#       time, 10^(-5) c  colisions, 10^2
# 0            0.060134             0.18
# 1            0.015265             0.11
# 2            0.058799             0.17
# 3            0.047027             0.14
# 4            0.018141             0.10
# ...               ...              ...
# 1795         1.073471             0.37
# 1796         0.457777             0.28
# 1797         1.017680             0.35
# 1798         0.532127             0.29
# 1799         0.393834             0.27
#
# [1800 rows x 2 columns]

# %%
from sklearn.cluster import KMeans

# %%
est = KMeans(n_clusters=4,n_jobs=5)
est.fit(X)
# Out:
# KMeans(n_clusters=4, n_jobs=5)

# %%
labels = est.labels_
labels
# Out:
# array([1, 1, 1, ..., 3, 0, 0])

# %%
X['target'] = labels
X
# Out:
#       time, 10^(-5) c  colisions, 10^2  target
# 0            0.060134             0.18       1
# 1            0.015265             0.11       1
# 2            0.058799             0.17       1
# 3            0.047027             0.14       1
# 4            0.018141             0.10       1
# ...               ...              ...     ...
# 1795         1.073471             0.37       3
# 1796         0.457777             0.28       0
# 1797         1.017680             0.35       3
# 1798         0.532127             0.29       0
# 1799         0.393834             0.27       0
#
# [1800 rows x 3 columns]

# %%
sns.set(font_scale = 1.5,
       style='white',
       )

ggg = sns.PairGrid(X,
                 hue='target',
                 height=5.5,
                 palette= flatui,
                 despine = False,
                 hue_kws={
                     "marker": ["o", "o", "o", "o"]
                 })

ggg.map_diag(sns.distplot, norm_hist = True, bins = np.linspace(0.0, 2.4, num=(6*4*10), endpoint=True))
ggg.map_upper(sns.kdeplot, shade=False, shade_lowest=False)
ggg.map_upper(sns.kdeplot, shade=False, shade_lowest=False)
ggg.map_lower(plt.scatter, s = 20, alpha=0.4, linewidth=1.0, edgecolor="black")
ggg.fig.set_size_inches(10, 10)


plt.legend(loc='upper center', bbox_to_anchor=(1, 1.25), ncol=3) #vertical legend

# Подписи к осям
ggg.axes[0,0].yaxis.set_label_text(r'$\rho (t) $')
ggg.axes[0,0].xaxis.set_label_text('$t, 10^{-5} c$')
ggg.axes[1,1].yaxis.set_label_text(r'$\rho (colisions) $')
ggg.axes[1,1].xaxis.set_label_text('$colisions, 10^{2}$')
ggg.axes[1,0].yaxis.set_label_text('$colisions, 10^{2}$')
ggg.axes[1,0].xaxis.set_label_text('$t, 10^{-5} c$')
ggg.axes[0,1].yaxis.set_label_text('$t, 10^{-5} c$')
ggg.axes[0,1].xaxis.set_label_text('$colisions, 10^{2}$')

# Тики видны на y
ggg.axes[0,0].yaxis.set_tick_params(labelleft=False)
ggg.axes[1,1].yaxis.set_tick_params(labelleft=False)
ggg.axes[1,0].yaxis.set_tick_params(labelleft=True, bottom = True, direction = 'in')
ggg.axes[0,1].yaxis.set_tick_params(labelleft=True, bottom = True, direction = 'in')

# Тики видны на x
ggg.axes[0,0].xaxis.set_tick_params(labelleft=True, bottom = True, direction = 'in')
ggg.axes[1,1].xaxis.set_tick_params(labelleft=True, bottom = True, direction = 'in')
ggg.axes[1,0].xaxis.set_tick_params(labelleft=True, bottom = True, direction = 'in')
ggg.axes[0,1].xaxis.set_tick_params(labelleft=True, bottom = True, direction = 'in')

#Лимиты тиков на x
ggg.axes[1,0].set_xlim(0, 2.5)
ggg.axes[0,1].set_xlim(0, 0.6)

#Лимиты тиков на y
ggg.axes[1,0].set_ylim(0.00001, 0.6)
ggg.axes[0,0].set_ylim(0.00001, 2.5)

plt.subplots_adjust(hspace=0.5, wspace=0.2)
